# %%
# %%HTML
# <style>
# div.prompt {display:none}
# </style>
# // hide input prompt
# $(document).ready(function() {
#     $('div.prompt').css('display', 'none');
# });
# Out:
# <style>
# div.prompt {display:none}
# </style>
# // hide input prompt
# $(document).ready(function() {
#     $('div.prompt').css('display', 'none');
# });

# %% [markdown]
# Beautiful Soup Documentation
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
with open('wtest1.html','w') as f:
    f.write(html_doc)

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, 'html.parser')
soup
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
#p 태그의 첫번째 데이터

soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
# a태그의 첫번째 데이터
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find('a')
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.a['class']
# Out:
# ['sister']

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
# 클래스가 시스터인것을 다 찾아라.
soup.find_all(class_='sister')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id = 'link3')
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.find('p')
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.find(class_='story')
# Out:
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>

# %%
soup.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
for link in soup.find_all('a'):
    print(link.get('href')) # 각 링크에서 href만 뽑아준다.
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
soup.find_all() # HTML에 있는 모든 내용이 출력
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>,
#  <div></div>,
#  <p class="title"><b>The Dormouse's story</b></p>,
#  <b>The Dormouse's story</b>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %% [markdown]
# ### string vs. get_text() vs. text
# - BeautifulSoup 객체에서 text 속성, get_text() 메서드, string 속성은 모두 HTML 또는 XML 문서에서 텍스트 데이터를 추출하는 데 사용
# - text 속성은 해당 태그에서 모든 텍스트 데이터를 가져오며,
# - get_text() 메서드도 동일한 결과를 반환합니다.
# - string 속성은 해당 태그에서 첫 번째로 발견된 문자열 데이터만 가져옵니다.

# %%
html = '''
<html>
<body>
<div>
Hello,world!
</div>
<div>
<p>
Hello,<b>world!</b>
</p>
</div>        
</body>
</html>
'''

# %%
with open('bt_test.html','w') as f:
    f.write(html)

# %%
with open('bt_test.html','r') as f:
    html = f.read()
    print(html)
# Out:
# <html>
# <body>
# <div>
# Hello,world!
# </div>
# <div>
# <p>
# Hello,<b>world!</b>
# </p>
# </div>
# </body>
# </html>

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html,'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <div>
#    Hello,world!
#   </div>
#   <div>
#    <p>
#     Hello,
#     <b>
#      world!
#     </b>
#    </p>
#   </div>
#  </body>
# </html>

# %%
print(soup.div.text)
# Out:
# Hello,world!

# %%
print(soup.div.get_text())
# Out:
# Hello,world!

# %%
print(soup.div.string)
# Out:
# Hello,world!

# %%
#text속성 
print(soup.p.text)
# Out:
# Hello,world!

# %%
# get_text() 메서드
print(soup.p.get_text())
# Out:
# Hello,world!

# %%
print(soup.p.get_text)
# Out:
# <bound method PageElement.get_text of <p>
# Hello,<b>world!</b>
# </p>>

# %%
print(soup.p.string)
print(soup.p.b.string) #<b>처럼 태그에 감싸져 있으면 값이 출력된다. Hello는 태그에 감싸져 있지 않기때문에 NONE이 나옴
# Out:
# None
# world!

# %%
soup.b.string
# Out:
# 'world!'

# %%
# body에 있는 모든 텍스트

# %%
import re
bs = soup.body.text
print(bs)
# Out:
# Hello,world!
#
#
#
# Hello,world!

# %%
# Q. 정규 표현식을 사용하여 아래와 같이 출력하세요. 
Hello,world!
Hello,world!

# %%
bs1 = re.finditer('.+', bs) #.은 계횡제외하고 찾아줌
print(bs1) #객체를 찾아줌
for i in bs1:
    print(i.group())
# Out:
# <callable_iterator object at 0x000002229619E2F0>
# Hello,world!
# Hello,world!

# %%
texts = re.findall('[^\s]+',bs)
for t in texts:
    print(t)
# print(re.findall('[A-Za-z!]+',bs))
# Out:
# Hello,world!
# Hello,world!

# %%
# Q. 아래와 같이 출력하세요 .
Hello,world! Hello,world!

# %%
a= bs.strip()
b= re.sub(r'\n','',a)
b
# Out:
# 'Hello,world!Hello,world!'

# %%
for t in texts:
    re.sub(r'\n','',t)
    print(t,end=' ')
# Out:
# Hello,world! Hello,world!

# %%
text=re.findall('[^\s]+',bs)
for t in text:
    print(t,end=' ')
# Out:
# Hello,world! Hello,world!

# %%
bs = soup.body.text
bs = re.findall('.+',bs)
print(' '.join(bs))
# Out:
# Hello,world! Hello,world!

# %%
li = ''
for t in text:
    li += t
    li += ' '
print(li)
# Out:
# Hello,world! Hello,world!

# %%
from bs4 import BeautifulSoup

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>
<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

soup = BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
bs = str(soup)
print(bs,type(bs))
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html> <class 'str'>

# %%
#영어 텍스트만 출력

p = re.findall('[a-zA-Z]+',bs) # 정규표현식
m = ' '.join(p)
m
# Out:
# 'html head title The Dormouse s story title head body div div p class title b The Dormouse s story b p p class story Once upon a time there were three little sisters and their names were a class sister href http example com elsie id link Elsie a a class sister href http example com lacie id link Lacie a and a class sister href http example com tillie id link Tillie a and they lived at the bottom of a well p p class story p body html'

# %%
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
print(soup.get_text())
print(soup.text) # 둘 다 결과는 동일하다.
# Out:
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
#
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
texts= soup.find_all('body')
li = ''
for t in texts:
    li += t.text
li
# Out:
# "\n\nThe Dormouse's story\nOnce upon a time there were three little sisters; and their names were\nElsie,\nLacie and\nTillie;\nand they lived at the bottom of a well.\n...\n"

# %%
# 개행을 정규표현식으로 제거
re.sub('\n','',li)
# Out:
# "The Dormouse's storyOnce upon a time there were three little sisters; and their names wereElsie,Lacie andTillie;and they lived at the bottom of a well...."

# %%
# 개행을 정규표현식으로 제거
import re
texts = re.findall('[^\s]+',soup.text)
li = ''
for text in texts:
    li += text
    li += ' '
print(li)
# Out:
# The Dormouse's story The Dormouse's story Once upon a time there were three little sisters; and their names were Elsie, Lacie and Tillie; and they lived at the bottom of a well. ...

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
print(soup.title.string) # 태그로 감싼 맨 처음 것이 출력
# Out:
# The Dormouse's story

# %% [markdown]
# bs
#
# https://hi-guten-tag.tistory.com/8

# %% [markdown]
# #### html.parser vs. lxml
# - 파이썬에서 HTML 및 XML 문서를 파싱(parsing)하는 라이브러리
# - html.parser는 HTML 문서를 파싱하는 데에 적합한 파서. 파이썬의 기본 라이브러리로 제공되며 파이썬 내부적으로 구현되어 있으며, 외부 종속성이 없으므로 파이썬과 함께 설치되는 패키지만 사용할 수 있습니다.
# - lxml은 C 언어로 작성된 파이썬 외부 라이브러리로서 HTML 및 XML 문서를 파싱하는 데에 적합하며, 파서 성능이 매우 우수합니다.
# - HTML 문서를 파싱하는 경우에는 html.parser를 사용하는 것이 간단하고 편리하며, 대부분의 경우에는 충분한 성능을 제공합니다. 그러나 대용량의 XML 문서나 매우 복잡한 HTML 문서를 파싱해야 하는 경우에는 lxml을 사용하는 것이 더 효율적입니다.

# %% [markdown]
# ### urllib + bs

# %%
# lxml은 파이썬에서 XML과 HTML 문서를 파싱하고 조작하기 위한 빠르고 유연한 라이브러리 

# !pip install lxml #설치 안되어있으면 이거로 설치

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs)
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 11:41:17 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833189?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833189.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833189?sid=100">민주당 1.0%p 내린  44.7%…국민의힘 35.2%[리얼미터]</a>
# <div class="cluster_text_lede">더불어민주당의 지지율이 직전 조사보다 1.0% 포인트 하락한 44.7%로 나타났다. 국민의힘은 0.7% 포인트 오른 35.2%를 기록했다. 여론조사기관  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011833189',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005476254',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005476254?sid=100">尹대통령 국정운영 긍정평가 34.5%…전주比 1.9%p↑[리얼미터]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269875',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100">윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739236',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001739236?sid=100">'국빈 방미' 통했나? 尹 지지율 4주 만에 반등…1.9%p 오른 34.5%</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=003&amp;aid=0011833189"><span class="cluster_foot_more_icon_num">37</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765101?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/079/2023/05/01/3765101.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/079/0003765101?sid=100">미국의 '핵 공유 아니다 선긋기'… "왜 그랬을까?"</a>
# <div class="cluster_text_lede">■ 방송 : CBS 라디오 &lt;김현정의 뉴스쇼&gt; FM 98.1 (07:20~09:00) ■ 진행 : 김광일 기자 (김현정 앵커 대신) ■ 대담 : 박원곤  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news079,0003765101',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">노컷뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879485',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879485?sid=100"> 윤 대통령, 방미 마치고 귀국...여야, 엇갈린 평가[뉴스라이더]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879321',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879321?sid=100">尹, 5박 7일 국빈 방미 마치고 귀국...성과와 과제는?</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879411',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879411?sid=100">윤 대통령, 국빈 방미 마치고 귀국...여야, 방미 평가 ·간호법 대치</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281620_00000245&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=079&amp;aid=0003765101"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913675?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913675.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913675?sid=100">'설화' 김재원 한 달 만에 최고위 복귀…"심려끼쳐 대단히 죄송"</a>
# <div class="cluster_text_lede">앞으로 당과 나라 위해 필요한 일 찾아서 열심히 하겠다" 연이은 '설화'로 논란을 빚은 국민의힘 김재원 최고위원이 1일 '근신' 기간을 마치고 한 달 만 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913675',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137334',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137334?sid=100">‘한 달 근신’ 김재원 “국민 여러분께 대단히 죄송…당·나라 위한 일 하겠다”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881763',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881763?sid=100">'자숙 끝' 김재원 "심려 끼쳐 대단히 죄송"…한달 만에 최고위 복귀</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news021,0002569431',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">문화일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/021/0002569431?sid=100">최고위 복귀 김재원, ‘자진사퇴’엔 “아직 생각 안해봐”</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913675"><span class="cluster_foot_more_icon_num">36</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407112?sid=100">尹 "업그레이드된 한미동맹, 청년·미래세대에 기회의 플랫폼"</a>
# <div class="cluster_text_lede">윤석열 대통령이 1일 이번 미국 국빈방문을 "업그레이드 되고 확장된 한미동맹"이라고 평가하며 "청년 미래 세대에게 기회의 플랫폼이 돼야 한다"고 했다. 이날 윤 대통령은 방미 귀국 이후 처음으로 주재한 수석 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407112',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005253026',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005253026?sid=100">尹 "확장된 한미동맹, 미래세대 기회 플랫폼 돼야"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011476070',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011476070?sid=100">윤 대통령 “업그레이드 한미동맹, 청년 기회의 플랫폼 돼야”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004881806',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004881806?sid=100">尹대통령 "업그레이드된 한미동맹, 청년세대 기회의 플랫폼 돼야"</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011110_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=448&amp;aid=0000407112"><span class="cluster_foot_more_icon_num">12</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913820?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913820.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913820?sid=100">윤재옥 "野, 거대 노총 눈치만 살펴…'노란봉투법' 철회하라"</a>
# <div class="cluster_text_lede">박광온 신임 원내대표엔 "입법 폭주 멈추고 의회 정치 복원 힘쓰자" 국민의힘 윤재옥 원내대표는 근로자의 날인 1일 "더불어민주당과 정의당은 거대 노총 눈 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913820',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879522?sid=100">與 "노동현장 불법·부조리 바로잡아야...앞장서 노력"</a>
# <div class="cluster_text_lede">국민의힘은 제133주년 세계 노동절을 맞아 노동현장의 불법 부조리를 바로잡고 사용자의 부당으로부터 선량한 근로자가 피해받지 않도록 주저하지 않겠다고 밝혔습니다. 김기현 원내대표는 오늘(1일) 최고위원회의에서 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879522',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011050_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913820"><span class="cluster_foot_more_icon_num">7</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760988?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3760988.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003760988?sid=100">“한미동맹은 미래 세대 위한 유산”</a>
# <div class="cluster_text_lede">尹대통령, 귀국후 트위터에 올려 하버드대에선 “워싱턴 선언은 업그레이드된 제2의 방위조약” 윤석열 대통령이 5박 7일 미국 국빈 방문을 마치고 30일 서 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news023,0003760988',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879480?sid=100">이종섭 국방장관 "워싱턴 선언, 제2한미상호방위조약"</a>
# <div class="cluster_text_lede">이종섭 국방부 장관은 확장억제 강화를 골자로 한 '워싱턴 선언'에 대해 제2의 한미상호방위조약으로 불러도 될 정도로 의미가 크다고 평가했습니다. 이 장관은 언론 기고문에서 이번 선언은 재래식 무기를 기반으로 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879480',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304290630_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=023&amp;aid=0003760988"><span class="cluster_foot_more_icon_num">8</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779728?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2023/05/01/6779728.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/421/0006779728?sid=100">태영호 "尹 영어실력, 토익 960점대…5·18 광수 개입, 터무니없는 얘기"</a>
# <div class="cluster_text_lede">북한 외교관 출신인 태영호 국민의힘 최고위원은 윤석열 대통령의 영어실력이 상당했다고 평가했다. 특히 억양과 필요한 부분에서의 강약조절 등 기술적 측면은  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0006779728',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴스1</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137327?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/01/2137327.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137327?sid=100">與윤리위 심의 위기 놓인 태영호 “제 생각 변함없다”</a>
# <div class="cluster_text_lede">국민의힘 윤리위원회가 1일 첫 회의를 열어 설화(舌禍)를 일으킨 당 지도부 인사에 대한 징계 여부를 논의할 것으로 알려진 가운데, 역사 왜곡성 발언으로  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137327',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010920_00000073&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=421&amp;aid=0006779728"><span class="cluster_foot_more_icon_num">5</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357643?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/081/2023/04/30/3357643.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/081/0003357643?sid=100">‘워싱턴 선언’ 들고 온 尹… 한일·한미일 연쇄회담 예고</a>
# <div class="cluster_text_lede">윤석열 대통령이 5박 7일간의 미국 국빈 방문을 마치고 30일 오후 귀국했다. 윤 대통령의 이번 방미는 한미 간 새로운 확장억제 강화 방안인 ‘워싱턴 선 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news081,0003357643',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울신문</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839331?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2023/04/30/4839331.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839331?sid=100">대통령실 "한미상호방위조약, 핵 포함하는 개념으로 업그레이드"</a>
# <div class="cluster_text_lede">대통령실은 윤석열 대통령의 국빈 방문을 통해 "한미상호방위조약을 핵이 포함된 상호방위 개념으로 업그레이드했다"고 평가했다. 대통령실은 30일 오후 윤 대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839331',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304280010_00001014&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=081&amp;aid=0003357643"><span class="cluster_foot_more_icon_num">22</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475958?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/04/30/5475958.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005475958?sid=100">'아픈손가락' 김재원 잘라낼까…내일 與윤리위 첫 회의 주목</a>
# <div class="cluster_text_lede">‘김기현 지도부’에서 새로 출범한 국민의힘 중앙당 윤리위원회가 내일(5월 1일) 첫 회의를 연다. 잇단 설화로 논란을 일으킨 김재원·태영호 국민의힘 최고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news018,0005475958',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">이데일리</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054450?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/055/2023/05/01/1054450.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0001054450?sid=100">국민의힘, 윤리위 첫 회의…김재원 · 태영호 징계 논의 여부 주목</a>
# <div class="cluster_text_lede">▲ 국민의힘 김재원, 태영호(오른쪽) 최고위원 국민의힘 김기현 대표 체제에서 새로 출범한 중앙당 윤리위원회가 오늘(1일) 오전 중앙당사에서 첫 회의를 엽 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news055,0001054450',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">SBS</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=018&amp;aid=0005475958"><span class="cluster_foot_more_icon_num">46</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913532?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913532.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913532?sid=100">북, 美전략핵잠 한반도 전개 '적법' 판단에 "황당무계한 궤변"</a>
# <div class="cluster_text_lede">북한은 1일 한미 '워싱턴 선언'에 담긴 미국 전략 핵잠수함(SSBN)의 한국 기항은 법적으로 아무런 문제가 없다는 당국의 판단에 대해 "황당무계한 궤변 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913532',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005160?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/014/2023/05/01/5005160.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/014/0005005160?sid=100">美 전략핵잠수함 한반도 전개 '적법' 판단에 北 "황당무계한 궤변"</a>
# <div class="cluster_text_lede">북한 선전매체 조선중앙통신은 5월 1일 "미 전략핵잠수함의 조선반도 전개가 '조선반도의 비핵화에 관한 공동선언'에 위반되지 않으며 법적으로 아무런 문제도 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news014,0005005160',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">파이낸셜뉴스</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000018&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913532"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913816?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/001/2023/05/01/13913816.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/001/0013913816?sid=100">野김민석 "간호법, 尹공약…거부권 행사하면 굉장히 독특한 분"</a>
# <div class="cluster_text_lede">전대 돈봉투 의혹엔 "檢수사 진도 나가면 정치적 조치도 하게 될것" 더불어민주당 김민석 정책위의장은 1일 윤석열 대통령이 지난달 27일 야당이 국회 본회 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news001,0013913816',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">연합뉴스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407110?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/448/2023/05/01/407110.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000407110?sid=100">김민석 "간호법, 尹대통령 공약…거부권 행사하면 독특한 분"</a>
# <div class="cluster_text_lede">더불어민주당 김민석 정책위의장은 1일 윤석열 대통령의 간호법 거부권 행사 가능성에 대해 "(거부권을 행사한다면) 굉장히 독특한 분이라고 봐야 한다"고 주 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news448,0000407110',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">TV조선</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011000_00000034&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=001&amp;aid=0013913816"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475706?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/04/30/11475706.jpg?type=ofullfill132_90" width="132"/>
# <strong class="r_ico r_vod_medium">동영상기사</strong>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011
'설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안 해봐"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/214/0001269875?sid=100" title="윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]">윤 대통령 지지율 1.9%p 오른 34.5%‥4주 만에 반등 [리얼미터]</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913799?sid=100" title='박광온 "사람 중심으로 국정운영 바꿔야…학부모 주4일제 검토"'>박광온 "사람 중심으로 국정운영 바꿔야…학부모 주4일제 검토"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913648?sid=104" title="'中·대만 대리전' 파라과이 대선서 '親美·親대만' 페냐 당선(종합)">'中·대만 대리전' 파라과이 대선서 '親美·親대만' 페냐 당선(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765136?sid=104" title="퍼스트리퍼블릭 붕괴 수순…Fed 고민 깊어져">퍼스트리퍼블릭 붕괴 수순…Fed 고민 깊어져</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/001/0013913873?sid=101" title="'41% 급감' 반도체에 수출 7개월째 감소…적자 3조원대로 좁혀져(종합)">'41% 급감' 반도체에 수출 7개월째 감소…적자 3조원대로 좁혀져(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002290751?sid=101" title="삼성전자, 5월 가정의 달 맞아 '2023형 TV 슈퍼빅세일' 진행">삼성전자, 5월 가정의 달 맞아 '2023형 TV 슈퍼빅세일' 진행</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006780047?sid=101" title="오늘 국회서 ‘전세사기 특별법’ 심사…지원대상 요건 조정 등에 이목 집중">오늘 국회서 ‘전세사기 특별법’ 심사…지원대상 요건 조정 등에 이목 집중</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/138/0002147587?sid=105" title="‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까">‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185262?sid=105" title="'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시">'노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765126?sid=102" title="檢, '돈봉투 의혹' 송영길 캠프 지역본부장 등 추가 압수수색(종합)">檢, '돈봉투 의혹' 송영길 캠프 지역본부장 등 추가 압수수색(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765120?sid=102" title="'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용">'강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003357755?sid=102" title="컵라면 먹던 초등생 ‘묻지마 폭행’ 10대 구속기소">컵라면 먹던 초등생 ‘묻지마 폭행’ 10대 구속기소</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011833398?sid=103" title="조계종, 전국 65개 사찰 관람료 4일부터 면제">조계종, 전국 65개 사찰 관람료 4일부터 면제</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004185244?sid=103" title='팰리세이드 5%·캐스퍼 70만원 할인…"현대차 SUV 사려면 5월에"'>팰리세이드 5%·캐스퍼 70만원 할인…"현대차 SUV 사려면 5월에"</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
text1= bs.find('p')
print(text1,'\n')

text2= bs.find('p').string
print(text2,'\n')

text3= bs.find('p').get_text()
print(text3)
# Out:
# <p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>
#
# None
#
# AiRS추천으로 구성된 뉴스를 제공합니다.

# %%
texts = bs.find_all('p')
for t in texts:
    print(t.text) #for문을 안쓰면 에러남 . 각각 하나에 대해서 텍스트를 뽑아줘야 하므로 for문 사용
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 10시~오전 11시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %% [markdown]
# ### bs4에서 headers는
#
# headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
#
# - HTTP 요청을 보낼 때 요청 헤더를 설정하는 데 사용됩니다.
# - 일반적으로 웹 사이트에서 데이터를 스크래핑하려면, 해당 웹 사이트에서 HTTP 요청을 받을 때 자신이 웹 브라우저인 것처럼 보이도록 요청 헤더를 설정해야 합니다.
# - 이를 통해 웹 사이트는 봇이나 크롤러와 같은 자동화된 스크래핑 도구에서 요청을 보내는 것으로 인식하는 것을 방지할 수 있습니다.

# %% [markdown]
# #### 인코딩 에러를 해결
# chardet.detect(response.content)['encoding']은 response.content의 인코딩 방식을 자동으로 감지하여 반환하며 이 값을 encoding 변수에 저장한 후, response.content를 이 encoding 방식으로 디코딩하여 html 변수에 저장하고 출력

# %%
import requests
import chardet

# HTTP 요청에서 사용될 헤더 정보를 설정합니다.
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

# 웹사이트에서 스크래핑할 URL을 지정합니다.
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

# 지정된 url에 HTTP GET 요청을 전달
response = requests.get(url, headers=headers)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 출력합니다.
if response.status_code == 200:
#     encoding = chardet.detect(response.content)['encoding']
#     print(response.content.decode(encoding)) # 웹사이트의 HTML 코드를 포함하는 이진(binary) 데이터를 반환
     print(response.text) # 웹사이트의 HTML 코드를 문자열 형태로 반환
else:
    print("HTTP request failed.")
# Out:
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <meta name="referrer" contents="always">
# <meta http-equiv="refresh" content="600" />
# <meta name="viewport" content="width=1106" />
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta property="og:title"       content="정치 : 네이버 뉴스">
# <meta property="og:type"        content="website">
# <meta property="og:url"         content="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100">
# <meta property="og:image"       content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
# <meta property="og:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
# <meta property="og:article:author"	content="네이버"/>
#
# <meta name="twitter:card"		content="summary">
# <meta name="twitter:title"		content="정치 : 네이버 뉴스">
# <meta name="twitter:site"       content="네이버 뉴스">
# <meta name="twitter:creator"    content="네이버 뉴스">
# <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
# <meta name="twitter:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">
#
#
#
#
#
#
#
# <title>정치 홈 : 네이버 뉴스	</title>
# <link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" />
#
#
#
#
#
#
#
#
#
#
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css"/>
# 		<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css"/>
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" charset="euc-kr"></script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" charset="utf-8"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 16:27:18 KST 2023";
# </script>
#
#
#
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" charset="euc-kr"></script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
#
#
# </head>
#
# <body>
# 	<div id="wrap">
# 		<!-- 광고적용 태그 추가 -->
# 		<div id="da_base"></div>
# 		<div id="da_stake"></div>
#
#
#
# <div id="header" class="header">
#
# 	<div id="u_skip">
# 		<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# 		<a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# 	</div>
#
#
# 	<div class="snb_area">
# 		<div class="snb_inner">
#
# <div class="gnb_area">
#    <div class="gnb_wrap">
#
#       <div id="gnb" class="gnb_dark_type2"></div>
#
#    </div>
#    <div class="gnb_search is_hidden _search_content">
#    </div>
#    <div id="gnb_search_tool" class="gnb_tool">
#       <a href="javascript:;" class="tool_button _search_content_toggle_btn nclicks(gnb.sch)"><span class="icon_search">검색</span></a>
#    </div>
# </div>
#
#
#
# <div id="snb_wrap">
#     <h1>
#         <a href="https://www.naver.com/" class="h_logo nclicks(gnb.naver)"><span class="blind">NAVER</span></a>
#         <a href="/" class="h_news nclicks(gnb.news)"><span class="blind">뉴스</span></a>
#     </h1>
#     <ul class="snb_related_service">
#         <li><span class="snb_bdr"></span><a href="https://entertain.naver.com/home" class="entertain nclicks(gnb.enter)">TV연예</a></li>
#         <li><span class="snb_bdr"></span><a href="https://sports.news.naver.com" class="sports nclicks(gnb.sports)">스포츠</a></li>
#         <li><span class="snb_bdr"></span><a href="https://weather.naver.com" class="weather nclicks(gnb.weather)">날씨</a></li>
#         <li><span class="snb_bdr"></span><a href="https://contents.premium.naver.com" class="premium nclicks(gnb.premium)">프리미엄</a></li>
#     </ul>
# </div>
# 		</div>
# 	</div>
# 	<div class="lnb_area">
# 		<div class="lnb_inner">
#
#
#
#
#
#
#
# <div class="lnb_both">
# 	<div class="lnb_left">
# 		<div id="lnb" class="lnb_menu">
# 			<ul>
# 				<li><a href="/" class="nclicks(lnb.pcmedia)"><span class="tx">언론사별</span> </a></li>
# 				<li class="on"><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lnb.pol)"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=101" class="nclicks(lnb.eco)"><span class="tx">경제</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=102" class="nclicks(lnb.soc)"><span class="tx">사회</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=103" class="nclicks(lnb.lif)"><span class="tx">생활/문화</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=105" class="nclicks(lnb.sci)"><span class="tx">IT/과학</span> </a></li>
# 				<li><a href="/main/main.naver?mode=LSD&mid=shm&sid1=104" class="nclicks(lnb.wor)"><span class="tx">세계</span> </a></li>
# 				<li><a href="/main/ranking/popularDay.naver?mid=etc&sid1=111" class="nclicks(lnb.rankin)"><span class="tx">랭킹</span> </a></li>
# 				<li><a href="/newspaper/home" class="nclicks(lnb.paper)"><span class="tx">신문보기</span> </a></li>
# 				<li><a href="/opinion/home" class="nclicks(lnb.opi)"><span class="tx">오피니언</span> </a></li>
# 				<li><a href="/main/tv/index.naver?mid=tvh" class="nclicks(lnb.tv)"><span class="tx">TV</span> </a></li>
# 				<li><a href="/main/factcheck/main.naver" class="nclicks(lnb.fact)"><span class="tx">팩트체크</span> </a></li>
#
# 			</ul>
# 		</div>
# 	</div>
# 	<div class="lnb_right">
# 		<div class="lnb_extra">
#
#
# 			<div class="lnb_extra_menu">
# 				<ul class="lnb_extra_menu_list">
# 					<li class="lnb_extra_menu_item"><a href="https://news.naver.com/main/officeList.naver" class="lnb_extra_menu_link nclicks(nct.right3)" title="전체 언론사">전체 언론사</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newsstand.naver.com/" class="lnb_extra_menu_link nclicks(STA.newsstand)" title="뉴스스탠드" target="_blank">뉴스스탠드</a></li>
# 					<li class="lnb_extra_menu_item"><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="lnb_extra_menu_link nclicks(nct.right4)" title="라이브러리" target="_blank">라이브러리</a></li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# </div>
#
# 		</div>
# 	</div>
#
#
#
#     <div class="lnb">
#
#
#
#
#         <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
#
#         <ul class="lnb_side" tabindex="0">
#             <li><a href="https://news.naver.com/main/officeList.naver" class="nclicks(slb.allmedia)" title="전체 언론사">전체 언론사</a></li>
#             <li><a href="https://newsstand.naver.com/" class="nclicks(slb.newsstand)" title="뉴스스탠드" target="_blank" >뉴스스탠드</a></li>
#             <li><a href="https://newslibrary.naver.com/search/searchByDate.nhn" class="nclicks(slb.library)" title="라이브러리" target="_blank">라이브러리</a></li>
#         </ul>
#     </div>
#
# </div>
# 		<hr>
#
# 		<table cellpadding="0" cellspacing="0" class="container">
# 			<caption class="blind">기사목록</caption>
# 			<colgroup>
# 				<col class="col_snb">
# 				<col class="col_content">
# 				<col class="col_aside">
# 			</colgroup>
# 			<tr>
# 				<td class="snb">
# 					<div id="snb" class="snb">
#
#
#
#
#
#
#
#
#
# <h2 class="h2"><a href="/main/main.naver?mode=LSD&mid=shm&sid1=100" class="nclicks(lmn_pol.home)">정치</a></h2>
# <ul class="nav">
#
#
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=264" class="snb_s11 nclicks(lmn_pol.mnl,,1)">대통령실 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=265" class="snb_s12 nclicks(lmn_pol.mnl,,2)">국회/정당 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=268" class="snb_s13 nclicks(lmn_pol.mnl,,3)">북한 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=266" class="snb_s14 nclicks(lmn_pol.mnl,,4)">행정 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=267" class="snb_s15 nclicks(lmn_pol.mnl,,5)">국방/외교 </a></li>
# <li><a href="/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=269" class="snb_s16 nclicks(lmn_pol.mnl,,6)">정치일반 </a></li>
# </ul>
#
#
#
# <div class="snb_banner">
#  <a href="https://media.naver.com/channel/setting?back=main" class="nclicks(lmn_pol.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71" height="74" alt="언론사 구독하기" /></a>
# </div>
# <div class="snb_banner">
#  <a href="https://contents.premium.naver.com/" class="nclicks(lmn_pol.pmb,,1)"><img src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71" height="74" alt="네이버 프리미엄콘텐츠" /></a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 					</div>
# 				</td>
# 				<td class="content">
# 					<div id="main_content" class="content">
# 						<div class="list_body section_index">
#
#         <div class="cluster">
#                 <div class="cluster_title">
#                     <span class="cluster_title_inner"><a href="#biF7L" class="cluster_title_icon_link _news_cluster_layer_btn "><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
#
#                     <div class="cluster_title_layer _news_cluster_layer is_hidden">
#                         <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
#                         <div class="cluster_title_layer_image"></div>
#                         <button type="button" class="cluster_title_layer_close _news_cluster_layer_close_btn">닫기</button>
#                     </div>
#                 </div>
#         </div>
#
#
#             <div class="_persist">
#                 <div class="cluster">
#
#
#
#
#
#
#
#
#
#
#                                 <div class="cluster_group _cluster_content" >
#
#                                     <div class="cluster_body">
#                                         <ul class="cluster_list">
#
#
#
#
#                                                         <li class="cluster_item">
#
#
#
#                                                                 <div class="cluster_thumb">
#                                                                     <div class="cluster_thumb_inner">
#                                                                         <a href="https://n.news.naver.com/mnews/article/057/0001739264?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                                             <img src="https://imgnews.pstatic.net/image/origin/057/2023/05/01/1739264.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                                         </a>
#                                                                     </div>
#                                                                 </div>
#
#                                                             <div class="cluster_text">
#                                                                 <a href="https://n.news.naver.com/mnews/article/057/0001739264?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">박광온 "사람 중심으로 국정운영 바꿔야…학부모 주4일제 검토"</a>
#                                                                 <div class="cluster_text_lede">더불어민주당 박광온 원내대표는 오늘(1일) &#034;지금 윤석열 대통령과 정부가 해야 할 일은 분명하다. 국정운영 기조를 사람 중심으로 대전환해야 한다&#034;고 강조 …</div>
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001739264',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">MBN</div>
#                                                                 </div>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277010',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                                     <div class="cluster_text_press">중앙일보</div>
#                                                                 </div>
#                                                                 <a href="https://n.news.naver.com/mnews/article/025/0003277010?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">野 박광온, 노동절 맞아 "학부모 위한 주4일제 적극적 검토"</a>
#                                                             </div>
#                                                         </li>
#
#
#
#
#
#
#
#                                                         <li class="cluster_item as_line">
#                                                             <div class="cluster_text">
#                                                                 <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001
params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                     <div class="cluster_text_press">SBS</div>
#                                                 </div>
#                                             </div>
#                                         </li>
#
#
#                                         <li class="cluster_item">
#
#
#
#                                                 <div class="cluster_thumb">
#                                                     <div class="cluster_thumb_inner">
#                                                         <a href="https://n.news.naver.com/mnews/article/023/0003761052?sid=100" class="cluster_thumb_link nclicks(cls_pol.clsart)">
#
#                                                             <img src="https://imgnews.pstatic.net/image/origin/023/2023/05/01/3761052.jpg?type=ofullfill132_90" width="132" height="90" alt="" onError="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;">
#
#                                                         </a>
#                                                     </div>
#                                                 </div>
#
#                                             <div class="cluster_text">
#                                                 <a href="https://n.news.naver.com/mnews/article/023/0003761052?sid=100" class="cluster_text_headline nclicks(cls_pol.clsart)">국민의힘, 김재원·태영호 징계절차 개시...“8일 수위 결정”</a>
#                                                 <div class="cluster_text_lede">국민의힘 중앙당 윤리위원회는 1일 김재원·태영호 최고위원에 대한 징계 절차를 개시했다. 두 최고위원은 최근 잇단 ‘설화(舌禍)’로 논란을 일으켰다. 황정 …</div>
#                     <div class="cluster_text_info _rcount"    data-comment="{gno:'news023,0003761052',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
#                                                     <div class="cluster_text_press">조선일보</div>
#                                                 </div>
#                                             </div>
#                                         </li>
#
#                                     </ul>
#                                 </div>
#
#                                     <div class="cluster_foot">
#                                         <div class="cluster_foot_inner">
#                                             <a href="/main/clusterArticles.naver?id=c_202304281030_00001855&mode=LSD&mid=shm&sid1=100&oid=055&aid=0001054502" class="cluster_foot_more nclicks(cls_pol.clstitle)"><span class="cluster_foot_more_icon_num">93</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
#                                         </div>
#                                     </div>
#
#                             </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             <div class="cluster_group _cluster_content" >
#
#                                 <div class="cluster_body">
#                                     <ul class="cluster_list">
#
#
#                                         <li class="cluster_item">
#
#
#                                             <div class="cluster_text">
# ...
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/665/0000000883?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/665/2023/05/01/883.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/665/0000000883?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">전동킥보드의 변명 &#034;내가 오토바이로 보여?&#034; [추적+]</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=665"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png" width="16" height="16" alt=""></span>더스쿠프</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#
#
#
#             <li>
#
#
#
#                         <a href="https://n.news.naver.com/mnews/ranking/article/145/0000018626?ntype=RANKING&sid=001" class="ranking_thumb nclicks('rig.renws2')">
#                             <img src="https://mimgnews.pstatic.net/image/origin/145/2023/05/01/18626.jpg?type=nf88_60" width="88" height="60" alt="" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';">
#
#                         </a>
#
#
#
#                 <div class="list_text_wrap">
#                     <div class="list_text">
#                         <div class="list_text_inner">
#                             <a href="https://n.news.naver.com/mnews/ranking/article/145/0000018626?ntype=RANKING&sid=001" class="list_tit nclicks('rig.renws2')">10명 중 3명, 한국 경제 ‘최대 위기’로 진단</a>
#
#                                 <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16" height="16" alt=""></span>레이디경향</a>
#
#                         </div>
#                     </div>
#                 </div>
#             </li>
#
#     </ul>
#
#
#
#
#
#
#     <button type="button" class="refresh_button nclicks('rig.renws2new') _refreshButton">더보기</button>
#
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
#
#
#
#                     <div class="side_ad" id="glad_ad_sidebox"></div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <div class="section" style="margin-bottom:20px; white-space:nowrap;" id="right_dailyList">
#  <h4>분야별 주요뉴스</h4>
#  <div class="classfy sd" style="display:block">
#   <ul class="list_txt">
#    <li> <a href="https://n.news.naver.com/mnews/article/025/0003277045?sid=100" class="nclicks(rig.secteco)" title="여당, 실언 김재원&middot;태영호 징계절차…&quot;칼 뽑았다, 질질 안끈다&quot;">여당, 실언 김재원&middot;태영호 징계절차…&quot;칼 뽑았다, 질질 안끈다&quot;</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/003/0011834023?sid=100" class="nclicks(rig.secteco)" title="박광온, 민주 4기 원내대표단 인선…송기헌 운영수석 등(종합2보)">박광온, 민주 4기 원내대표단 인선…송기헌 운영수석 등(종합2보)</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/123/0002304052?sid=100" class="nclicks(rig.secteco)" title="윤 대통령, 노동절에 &quot;기득권 고용세습 뿌리 뽑을 것&quot;">윤 대통령, 노동절에 &quot;기득권 고용세습 뿌리 뽑을 것&quot;</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/437/0000341336?sid=104" class="nclicks(rig.secteco)" title="일본 지지통신 &quot;기시다 총리, 7~8일 방한 뜻 굳혀&quot;">일본 지지통신 &quot;기시다 총리, 7~8일 방한 뜻 굳혀&quot;</a> </li>
#    <li> <a href="https://n.news.naver.com/mnews/article/081/0003357837?sid=104" class="nclicks(rig.secteco)" title="“양육비 비싼 나라 1위 한국”…中연구소가 내놓은 해결방안은">“양육비 비싼 나라 1위 한국”…中연구소가 내놓은 해결방안은</a> </li>
#   </ul>
#   <ul class="list_txt">
#    <ul class="list_txt">
#     <li> <a href="https://n.news.naver.com/mnews/article/008/0004881901?sid=101" class="nclicks(rig.secteco)" title="반도체 수출 40% 급감 '직격탄'...&quot;무역적자 폭은 줄고 있어&quot;">반도체 수출 40% 급감 '직격탄'...&quot;무역적자 폭은 줄고 있어&quot;</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/008/0004881898?sid=101" class="nclicks(rig.secteco)" title="무차입 공매도 76건 조사한 금감원... &quot;주가 급등락 종목 중점 점검&quot;">무차입 공매도 76건 조사한 금감원... &quot;주가 급등락 종목 중점 점검&quot;</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/366/0000898089?sid=101" class="nclicks(rig.secteco)" title="1년간 중대재해로 4명 숨진 세아베스틸…사고 후에도 위험요인 방치">1년간 중대재해로 4명 숨진 세아베스틸…사고 후에도 위험요인 방치</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/018/0005476552?sid=105" class="nclicks(rig.secteco)" title="5G요금 절약법…4.3만원 50GB 알뜰폰, 4.6만원 80GB 다이렉트">5G요금 절약법…4.3만원 50GB 알뜰폰, 4.6만원 80GB 다이렉트</a> </li>
#     <li> <a href="https://n.news.naver.com/mnews/article/020/0003494733?sid=105" class="nclicks(rig.secteco)" title="KAIST “유전자 가위로 코로나 바이러스 싹둑…증식 99.9% 억제”">KAIST “유전자 가위로 코로나 바이러스 싹둑…증식 99.9% 억제”</a> </li>
#    </ul>
#    <ul class="list_txt">
#     <ul class="list_txt">
#      <li> <a href="https://n.news.naver.com/mnews/article/079/0003765240?sid=102" class="nclicks(rig.secteco)" title="엠폭스 주말에도 5명 추가확진&middot;누적 47명…전원 국내 감염">엠폭스 주말에도 5명 추가확진&middot;누적 47명…전원 국내 감염</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/015/0004839454?sid=102" class="nclicks(rig.secteco)" title="부르지도 않았는데…'돈 봉투 의혹' 송영길 &quot;내일 검찰 출두&quot;">부르지도 않았는데…'돈 봉투 의혹' 송영길 &quot;내일 검찰 출두&quot;</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/079/0003765251?sid=102" class="nclicks(rig.secteco)" title="&quot;정당한 노조활동 했는데…&quot; 건설노조 간부, 분신 전 검찰 겨냥 글 남겨">&quot;정당한 노조활동 했는데…&quot; 건설노조 간부, 분신 전 검찰 겨냥 글 남겨</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/031/0000743921?sid=103" class="nclicks(rig.secteco)" title="&quot;난 안 볼건데 왜 돈 내&quot;…말 많던 사찰 입장료, 61년만에 폐지">&quot;난 안 볼건데 왜 돈 내&quot;…말 많던 사찰 입장료, 61년만에 폐지</a> </li>
#      <li> <a href="https://n.news.naver.com/mnews/article/025/0003277052?sid=103" class="nclicks(rig.secteco)" title="&quot;7년만에 수퍼 엘니뇨 우려&quot;…한달 빠른 5월부터 덮친다">&quot;7년만에 수퍼 엘니뇨 우려&quot;…한달 빠른 5월부터 덮친다</a> </li>
#     </ul>
#    </ul>
#   </ul>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://media.naver.com/channel/settings" class="nclicks(rig.banner)"> <img src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300" alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <a href="https://news.naver.com/main/assembly/index.naver" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300" height="60" border="0" alt="내일을 여는 국민의 국회" class="banner" /> </a>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <div class="banner">
#   <a href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" class="nclicks(rig.banner)" target="_blank"> <img src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300" alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" /> </a>
#  </div>
# </div>
#
#
#
#
#
#
#
#
#
#                 <div class="section">
#  <h4> <a href="https://news.naver.com/main/ombudsman/index.naver" class="nclicks(rig.text)"> 서비스 안내 </a> </h4>
#  <ul class="list_txt">
#   <li> <a href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb" class="nclicks(rig.text)"> 고침 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb" class="nclicks(rig.text)"> 정정&middot;반론&middot;추후 보도 기사 모음 </a> </li>
#   <li> <a href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb" class="nclicks(rig.text)"> 불공정 선거 보도 기사 모음 </a> </li>
#  </ul>
#  <a href="https://news.naver.com/main/ombudsman/index.naver" class="more_link nclicks(rig.text)"><span class="blind">서비스 안내</span>더보기</a>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
#
# 					</div>
# 				</td>
# 			</tr>
# 		</table>
# 	</div>
#
# 	<hr>
# <div class="index">
#
#
#
# <div class="index_inner">
#
# 	<div class="floating_btn" >
# 		<div class="floating_inner">
# 			<a href="javascript:history.back();" class="floating_btn_back"><span class="blind">이젠 페이지</span></a>
# 			<a href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;" class="floating_btn_top"><span class="blind">맨위로</span></a>
# 		</div>
# 	</div>
# 	<div id="index.press_category" class="index_tab">
# 		<a id="index.press.btn" href="#" class="spr stit nclicks(fot.press)">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.press.area" class="index_content is_hidden"></div>
# 		<a id="index.category.btn" href="#" class="spr stit2 nclicks(fot.section)">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# 		<div id="index.category.area" class="index_content02 is_hidden"></div>
# 	</div>
# </div>
#
#
# </div>
# <hr>
# <div id="footer">
#
# <ul>
# <li class="first"><a href="http://www.naver.com/rules/service.html" class="nclicks(fot.agreement)">이용약관</a></li>
# <li><a href="/main/ombudsman/index.naver" class="nclicks(fot.guide)">서비스 안내</a></li>
# <li><a href="/main/ombudsman/edit.naver?mid=omb" class="nclicks(fot.editor)">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a href="http://www.naver.com/rules/privacy.html" class="nclicks(fot.privacy)">개인정보처리방침</a></strong></li>
# <li><a href="http://www.naver.com/rules/disclaimer.html" class="nclicks(fot.disclaimer)">책임의 한계와 법적고지</a></li>
# <li><a href="#" title="새창" onclick="news.external.OPS.helpNews(); return false;" class="nclicks(fot.help)">뉴스 고객센터</a></li>
# </ul>
# 	<p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
#
#
# 	<address class="address_nhn">
# 	<a href="https://www.navercorp.com/" target="_blank" class="logo nclicks(fot.naver)"><span class="blind">NAVER</span></a>
# 	<em>Copyright &copy;</em>
# 	<a href="https://www.navercorp.com/" target="_blank" class="nclicks(fot.navercorp)">NAVER Corp.</a>
# 	<span>All Rights Reserved.</span>
# </address>
# 	<!-- -->
#
#
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
# Q. response값에서 한글만 출력하세요.

import urllib
from bs4 import BeautifulSoup
import requests
import re

url = 'http://news.naver.com/main/main.nhn?mode=LSD%mid=shm&sid1=100'
req = urllib.request.urlopen(url)
byte_data = req.read()
text_data = byte_data.decode(encoding) #utf-8로 안쓰고 encoding 으로 쓰면 적용된 인코드가 자동 적용이 된다.
soup = BeautifulSoup(text_data, 'html.parser')
soup = str(soup)
text = re.findall('[가-힣]+',soup)
m = ' '.join(text)
m
# Out:
# '네이버 뉴스 정치 경제 사회 생활 문화 세계 과학 등 언론사별 분야별 뉴스 기사 제공 네이버 네이버 뉴스 네이버 뉴스 네이버 뉴스 정치 경제 사회 생활 문화 세계 과학 등 언론사별 분야별 뉴스 기사 제공 정치 홈 네이버 뉴스 광고적용 태그 추가 메인 메뉴로 바로가기 본문으로 바로가기 검색 뉴스 연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 월 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 언론사 구독하기 네이버 프리미엄콘텐츠 안내 헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출 됩니다 닫기
사회도 워싱턴 선언 에 커다란 우려 표시 북한이 지난달 일 현지시간 한미정상회담에서 도출된 워싱턴 선언 에 대해 국제사회가 부정적 결과를 우려하고 있다며 재차 반발했다 북한 노동당 기관 뉴스 개의 관련뉴스 더보기 국빈 방미 계기 더 선명해진 한미일 밀착 중 러 관계는 숙제 윤석열 대통령의 국빈 방미를 계기로 한미일 공조는 더욱 돈독해졌다는 평가다 하지만 대 중국 러시아와의 관계 개선은 앞으로 풀어야 할 과제로 남았 뉴스 한일 한미일 연쇄회담 월 외교안보 큰 장 윤석열 대통령이 박 일간의 국빈 방미 일정을 모두 마치며 워싱턴 선언 채택 등 한미 간 전략적 안보동맹을 더욱 강화했다는 평가 나오는 가운데 이 헤럴드경제 개의 관련뉴스 더보기 대통령실 워싱턴선언 제 한미상호방위조약 방미 최고성과 대통령실은 지난 일 이하 현지시간 한미 정상회담에서 채택한 워싱턴 선언 에 대해 제 의 한미상호방위조약이라고 거듭 강조했다 특히 이번 정상회담의 이데일리 확장억제 강화 워싱턴 선언 최대 성과 신냉전 구도 숙제 국빈방미 결산 윤석열 대통령의 박 일 미국 국빈방문 최대 성과로는 무엇보다 워싱턴 선언 이 꼽힌다 고도화하는 북한의 핵 미사일 위협에 맞서 대북 확장억제 핵우산 헤럴드경제 개의 관련뉴스 더보기 윤재옥 한미 핵협의그룹에 자체 핵무장 보다 더 큰 이익 윤재옥 국민의힘 원내대표는 일 한미가 합의 ...

# %%
#김나영
# 한글만 뽑기
text = response.content.decode(encoding)
result = ' '.join(re.findall('[가-힣]+',text))
print(result)
# Out:
# 네이버 뉴스 정치 경제 사회 생활 문화 세계 과학 등 언론사별 분야별 뉴스 기사 제공 네이버 네이버 뉴스 네이버 뉴스 네이버 뉴스 정치 경제 사회 생활 문화 세계 과학 등 언론사별 분야별 뉴스 기사 제공 정치 홈 네이버 뉴스 광고적용 태그 추가 메인 메뉴로 바로가기 본문으로 바로가기 검색 뉴스 연예 스포츠 날씨 프리미엄 언론사별 정치 선택됨 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 월 전체 언론사 전체 언론사 뉴스스탠드 뉴스스탠드 라이브러리 라이브러리 기사목록 정치 대통령실 국회 정당 북한 행정 국방 외교 정치일반 언론사 구독하기 네이버 프리미엄콘텐츠 안내 헤드라인 뉴스 헤드라인 뉴스와 각 기사묶음 타이틀은 기사 내용을 기반으로 자동 추출 됩니다 닫기 업그레이드된 한미동맹 청년 미래세대에 기회의 플랫폼 윤석열 대통령이 일 이번 미국 국빈방문을 업그레이드 되고 확장된 한미동맹 이라고 평가하며 청년 미래 세대에게 기회의 플랫폼이 돼야 한다 고 했다 조선 윤 대통령 업그레이드 한미동맹 청년 기회의 플랫폼 돼야 경향신문 윤 대통령 업그레이드된 한 미동맹 청년에게 기회의 플랫폼 되어야 서울신문 대통령 한미동맹 미래세대에 기회의 플랫폼 돼야 개의 관련뉴스 더보기 대통령실이 꼽은 국빈 방미 성과는 대통령실은 일 윤석열 대통령의 박 일 일정의 국빈 방미 성과를 밝혔다 윤석열 대통령이 일 현지시간 백악관에서 열린 국빈만찬 특별공연에서 조 이데일리 연합뉴스 대통령실 핵 포함 개념으로 한미상호방위조약 업그레이드 서울신문 워싱턴 선언 들고 온 한일 한미일 연쇄회담 예고 헤럴드경제 확장억제 강화 워싱턴 선언 최대 성과 신냉전 구도 숙제 국빈방미 결산 개의 관련뉴스 더보기 동영상기사 노동현장 불법 부조리 바로잡아야 앞장서 노력 국민의힘은 제 주년 세계 노동절을 맞아 노동현장의 불법 부조리를 바로잡고 사용자의 부당으로부터 선량한 근로자가 피해받지 않도록 주저하지 않겠다고 밝혔 이데일리 근로자의 날 특권노조 직격 노란�
치주의를 확립하고 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌 헤럴드경제 대통령 헌법 정신 위배되는 기득권 고용세습 뿌리 뽑을 것 윤석열 대통령이 번째 근로자의 날을 맞아 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것 이라고 일 밝혔다 윤 대통령은 이 중앙일보 개의 관련뉴스 더보기 감사원 사장 임명시 정당가입여부 조회 안해 드라마 제작 계열사 소홀 관리도 지적 직무유기와 배임 의혹 주장은 배척 감사원이 한국방송공사 이사회가 김의철 사장 후보자 임명제청 시 결격 사유 매일경제 감사원 경영진 중대한 위법 사실 발견 안 돼 감사원은 김의철 사장 등 경영진에 대한 감사 결과 중대한 위법 사실은 발견되지 않았다고 밝혔습니다 감사원은 지난해 월 보수 노조 등이 국민감사를 청구한 가지 의혹에 대해 실지감사를 벌인 개의 관련뉴스 더보기 북 전략핵잠 한반도 전개 적법 판단에 황당무계한 궤변 북한은 일 한미 워싱턴 선언 에 담긴 미국 전략 핵잠수함 의 한국 기항은 법적으로 아무런 문제가 없다는 당국의 판단에 대해 황당무계한 궤변 연합뉴스 북한 전략핵잠 한반도 전개 적법 판단에 황당한 궤변 북한이 미국의 핵추진 탄도미사일 잠수함 이 한반도에 전개되더라도 한반도 비핵화 공동선언 엔 위배되지 않는다는 우리 정 ...

# %%
import requests as rq
from bs4 import BeautifulSoup

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'

r = rq.get(url,headers=headers)
# print(r)
html = r.text
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh"/>
# <meta content="width=1106" name="viewport"/>
# <meta content="정치 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="정치 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공" name="twitter:description"/>
# <title>정치 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Mon May 01 16:32:10 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230420_103042/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h2"><a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a></h2>
# <ul class="nav">
# <li><a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a></li>
# <li><a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a></li>
# <li><a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a></li>
# <li><a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a></li>
# <li><a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a></li>
# <li><a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252971?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/277/2023/05/01/5252971.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252971?sid=100">舌禍논란 김재원 "자숙 마쳐 최고위 복귀…사퇴 없다"</a>
# <div class="cluster_text_lede">잇따른 '말실수'로 한 달 동안 공개 활동을 중단했던 김재원 국민의힘 최고위원이 1일 당 최고위원회에 복귀했다. 김 최고위원은 이날 오전 국회에서 진행된 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005252971',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0011834094',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">뉴시스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011834094?sid=100">민주당 "김재원, 자진사퇴보다 중징계가 제격"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news366,0000898074',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">조선비즈</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/366/0000898074?sid=100">‘설화 논란’ 김재원, 한 달 만에 최고위 복귀… “심려 끼쳐 대단히 죄송”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news214,0001269869',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBC</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001269869?sid=100">'설화' 김재원 "심려끼쳐 대단히 죄송"‥한 달만 최고위 복귀</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010930_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=277&amp;aid=0005252971"><span class="cluster_foot_more_icon_num">40</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185198?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/011/2023/05/01/4185198.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004185198?sid=100">유명 영어강사 오성식 "尹 영어 실력, 상상을 초월했다" 호평</a>
# <div class="cluster_text_lede">라디오 프로그램 ‘굿모닝팝스’를 진행해 유명 영어 강사로 알려진 오성식 씨가 국빈 방문 당시 윤석열 대통령의 미 의회 연설에 대해 극찬을 아끼지 않았다. …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news011,0004185198',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">서울경제</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news277,0005252847',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아시아경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005252847?sid=100">'1세대 영어강사' 오성식 "尹 영어 연설 만점"</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797998',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797998?sid=100">"소름 끼친 尹 영어실력" 극찬 속 "외교 성과는 `글쎄`" 시각도</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news015,0004839333',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">한국경제</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/015/0004839333?sid=100">"尹 영어 연설 상상 초월"…'1세대 강사' 오성식 극찬한 까닭</a>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304301840_00000102&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=011&amp;aid=0004185198"><span class="cluster_foot_more_icon_num">17</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000341325?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/437/2023/05/01/341325.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/437/0000
jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/088/0000811648?sid=100">국힘 윤리위 1일 첫 회의…김재원 5·18 전 징계할 듯</a>
# <div class="cluster_text_lede">국민의힘 윤리위원회(윤리위)가 1일부터 본격 활동에 돌입함에 따라 각종 설화(舌禍)로 구설에 오른 김재원·태영호 최고위원에 대한 단죄 여부에 관심이 모아 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news088,0000811648',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">매일신문</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202304281030_00001855&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=417&amp;aid=0000917329"><span class="cluster_foot_more_icon_num">93</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475909?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/056/2023/05/01/11475909.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011475909?sid=100">북, 미국 SSBN 한반도 전개 ‘적법’ 판단에 “황당무계한 궤변”</a>
# <div class="cluster_text_lede">북한이 한미 ‘워싱턴선언’에 담긴 미국 전략 핵잠수함(SSBN)의 한국 기항은 법적으로 아무런 문제가 없다는 우리 정부의 판단에 대해 “황당무계한 궤변” …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news056,0011475909',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">KBS</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276985?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3276985.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003276985?sid=100">北 "美전략핵잠 한반도 전개가 적법?…미사여구 분칠한 궤변"</a>
# <div class="cluster_text_lede">북한은 1일 한미 '워싱턴 선언'에 담긴 미국 전략 핵잠수함(SSBN)의 한국 기항은 법적으로 아무런 문제가 없다는 판단에 대해 "황당무계한 궤변"이라고 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003276985',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010810_00000018&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=056&amp;aid=0011475909"><span class="cluster_foot_more_icon_num">15</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/031/0000743947?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/031/2023/05/01/743947.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/031/0000743947?sid=100">"내가 복무한 부대는 언제 사라질까"…'이기자 부대' 이어 8군단도 하반기 해체</a>
# <div class="cluster_text_lede">강원도 양양에 주둔하던 육군 8군단이 올 하반기 해체된다. 1일 군 관계자는 8군단은 이날부로 임무해제를 하고 각종 경계 임무와 작전 기능을 3군단으로  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news031,0000743947',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">아이뉴스24</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137535?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/016/2023/05/01/2137535.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/016/0002137535?sid=100">이기자부대도 해체되고…‘인구절벽’에 8군단 오늘 임무해제</a>
# <div class="cluster_text_lede">육군 8군단이 1일 임무를 해제한다. 육군에 따르면 8군단은 내달 말 정식 해체된다. 그동안 양양 지역에 머무르며 부대 이름을 유지하고 예하 부대 3군단 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news016,0002137535',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">헤럴드경제</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305010510_00000259&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=031&amp;aid=0000743947"><span class="cluster_foot_more_icon_num">11</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277040?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/025/2023/05/01/3277040.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003277040?sid=100">감사원 "KBS사장, 정당 가입 이력 없어…중대한 위법 사실 없다"</a>
# <div class="cluster_text_lede">감사원은 한국방송공사(KBS) 이사회의 김의철 사장 후보자 검증 태만 의혹과 계열사 관리 실태 등을 감사한 결과 "중대한 위법사실은 발견되지 않았다"고  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news025,0003277040',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">중앙일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001879620?sid=100">감사원 "KBS 경영진, 중대한 위법 사실 발견 안 돼"</a>
# <div class="cluster_text_lede">감사원은 김의철 사장 등 KBS 경영진에 대한 감사 결과 중대한 위법 사실은 발견되지 않았다고 밝혔습니다. 감사원은 지난해 10월 KBS 보수 노조 등이 국민감사를 청구한 5가지 의혹에 대해 실지감사를 벌인 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news052,0001879620',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">YTN</div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster_foot">
# <div class="cluster_foot_inner">
# <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202305011410_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=025&amp;aid=0003277040"><span class="cluster_foot_more_icon_num">13</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </div>
# <div class="cluster_group _cluster_content" style="display: none">
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797771?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/04/30/2797771.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002797771?sid=100"> 5번 만남에 끈끈해진 한미 정상…`어깨동무` 만찬 백미[국빈 방미 결산]</a>
# <div class="cluster_text_lede">윤석열 대통령은 5박 7일 간의 미국 국빈 방문으로 조 바이든 미국 대통령과의 끈끈한 우애를 전 세계에 과시했다. 윤 대통령과 바이든 대통령은 25일(현 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news029,0002797771',params:{sid1:'100'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">디지털타임스</div>
# </div>
# </div>
# </li>
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/05/01/11833218.jpg?type=ofullfill132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/003/0011833218?sid=100">尹, 바이든 부부에게 트윗 글 "아내도 감사 전하고 싶어해"</a>
# <div class="cluster_text_lede">기사내용 요약 "인상적 만찬 준비해준 질 여사에 감사" "서울서 멋진 한식으로 보답하길 바라" [서울=뉴국빈 방미를 마치고 귀국한 윤석열 대통령은 1일  …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news003,0
a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=145"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/145/2020/12/09/logo_145_56_20201209180915.png" width="16"/></span>레이디경향</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <button class="refresh_button nclicks('rig.renws2new') _refreshButton" type="button">더보기</button>
# </div>
# <script type="text/javascript">
#     var OfficeTopRankingManager = jindo.$Class({
#         $static: {
#             RANKING_INFO_BUTTON_SELECTOR: '._rankingInfoButton',
#             RANKING_INFO_LAYER_SELECTOR : '._rankingInfoLayer',
#             RANKING_INFO_BUTTON_CLOSE_SELECTOR : '._rankingInfoCloseButton',
#             REFRESH_BUTTON_SELECTOR : '._refreshButton',
#             RANKING_LIST_SELECTOR : '._rankingList'
#         },
#
#         $init: function(base) {
#             this._welBase = jindo.$Element(base);
#             this._rankingInfoLayer = jindo.$Element(this._welBase.query(this.constructor.RANKING_INFO_LAYER_SELECTOR));
#             this._rankingListArray = jindo.$ElementList(this._welBase.queryAll(this.constructor.RANKING_LIST_SELECTOR));
#
#             this._initEvent();
#         },
#
#         _initEvent: function() {
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_SELECTOR, jindo.$Fn(this._showRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.RANKING_INFO_BUTTON_CLOSE_SELECTOR, jindo.$Fn(this._closeRankingInfoLayer, this).bind());
#             this._welBase.delegate('click', this.constructor.REFRESH_BUTTON_SELECTOR, jindo.$Fn(this._refreshRankingList, this).bind());
#         },
#
#         _showRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.toggle();
#         },
#
#         _closeRankingInfoLayer: function(event) {
#             event.stopDefault();
#
#             this._rankingInfoLayer.hide();
#         },
#
#         _refreshRankingList: function(event) {
#             event.stopDefault();
#
#             for (var i=0 ; i<this._rankingListArray.length() ; i++) {
#                 var rankingList = this._rankingListArray.get(i);
#
#                 if (rankingList.visible() === true) {
#                     var nextIndex = i + 1;
#
#                     if (nextIndex === this._rankingListArray.length()) {
#                         nextIndex = 0;
#                     }
#
#                     var nextRankingList = this._rankingListArray.get(nextIndex);
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087473");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003277045?sid=100" title='여당, 실언 김재원·태영호 징계절차…"칼 뽑았다, 질질 안끈다"'>여당, 실언 김재원·태영호 징계절차…"칼 뽑았다, 질질 안끈다"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011834023?sid=100" title="박광온, 민주 4기 원내대표단 인선…송기헌 운영수석 등(종합2보)">박광온, 민주 4기 원내대표단 인선…송기헌 운영수석 등(종합2보)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/123/0002304052?sid=100" title='윤 대통령, 노동절에 "기득권 고용세습 뿌리 뽑을 것"'>윤 대통령, 노동절에 "기득권 고용세습 뿌리 뽑을 것"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/437/0000341336?sid=104" title='일본 지지통신 "기시다 총리, 7~8일 방한 뜻 굳혀"'>일본 지지통신 "기시다 총리, 7~8일 방한 뜻 굳혀"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003357837?sid=104" title="“양육비 비싼 나라 1위 한국”…中연구소가 내놓은 해결방안은">“양육비 비싼 나라 1위 한국”…中연구소가 내놓은 해결방안은</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004881901?sid=101" title="반도체 수출 40% 급감 '직격탄'...&quot;무역적자 폭은 줄고 있어&quot;">반도체 수출 40% 급감 '직격탄'..."무역적자 폭은 줄고 있어"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004881898?sid=101" title='무차입 공매도 76건 조사한 금감원... "주가 급등락 종목 중점 점검"'>무차입 공매도 76건 조사한 금감원... "주가 급등락 종목 중점 점검"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000898089?sid=101" title="1년간 중대재해로 4명 숨진 세아베스틸…사고 후에도 위험요인 방치">1년간 중대재해로 4명 숨진 세아베스틸…사고 후에도 위험요인 방치</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/018/0005476552?sid=105" title="5G요금 절약법…4.3만원 50GB 알뜰폰, 4.6만원 80GB 다이렉트">5G요금 절약법…4.3만원 50GB 알뜰폰, 4.6만원 80GB 다이렉트</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/020/0003494733?sid=105" title="KAIST “유전자 가위로 코로나 바이러스 싹둑…증식 99.9% 억제”">KAIST “유전자 가위로 코로나 바이러스 싹둑…증식 99.9% 억제”</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765240?sid=102" title="엠폭스 주말에도 5명 추가확진·누적 47명…전원 국내 감염">엠폭스 주말에도 5명 추가확진·누적 47명…전원 국내 감염</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/015/0004839454?sid=102" title="부르지도 않았는데…'돈 봉투 의혹' 송영길 &quot;내일 검찰 출두&quot;">부르지도 않았는데…'돈 봉투 의혹' 송영길 "내일 검찰 출두"</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/079/0003765251?sid=102" title='"정당한 노조활동 했는데…" 건설노조 간부, 분신 전 검찰 겨냥 글 남겨'>"정당한 노조활동 했는데…" 건설노조 간부, 분신 전 검찰 겨냥 글 남겨</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/031/0000743921?sid=103" title='"난 안 볼건데 왜 돈 내"…말 많던 사찰 입장료, 61년만에 폐지'>"난 안 볼건데 왜 돈 내"…말 많던 사찰 입장료, 61년만에 폐지</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003277052?sid=103" title='"7년만에 수퍼 엘니뇨 우려"…한달 빠른 5월부터 덮친다'>"7년만에 수퍼 엘니뇨 우려"…한달 빠른 5월부터 덮친다</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"/> </a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>>

# %%
bs.find('div')

# %%
bs.find('div',id = True)

# %%
# bs.find('div')
## bs.find('div',id = True)
bs.find('div',id = 'header')
# Out:
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li class="on"><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>05</strong>.<strong>01</strong><span class="day">(월)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>

# %%
# 임수현
bs.select_one("[tabindex = '1']").text
# Out:
# '메인 메뉴로 바로가기'

# %%
#김동완
bs.div.find("a",href=True).get_text() #href 에서 있는것 중 처음것 추출
# Out:
# '메인 메뉴로 바로가기'

# %%
bs.find('div',id=True).find('a').text
# Out:
# '메인 메뉴로 바로가기'

# %%
lists = bs.find('div',id=True).find_all('a')
for i in lists:
    print(i.text) #전부 다 뽑을 때
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 北외교관 출신 태영호 "尹대통령 영어 잘하더라...토익 960점 정도?"
# 태영호 “尹대통령 영어, 토익 960점 수준…인토네이션 완전히 소화”
# 與윤리위 심의 위기 놓인 태영호 “제 생각 변함없다”
# 태영호 "역사적 소신 변함 없어"‥5.18 북 개입설엔 "근거 없다"
# 6개의 관련뉴스 더보기
#
#
#
# 윤 대통령, 바이든 부부에 트윗 “아내도 감사 전하고 싶어해”
# 尹, 바이든에 트윗 "아내가 감사 인사 전해…다음은 서울서 한식으로"
# 尹대통령, 美 바이든 대통령 부부에 감사 인사… “다음엔 서울서 한식으로”
# 尹대통령, 바이든 부부에 감사 글…"아내가 감사 전하고 싶어 해"
# 15개의 관련뉴스 더보기
#
#
#
# 김재원, 자숙 한달만에 최고위 복귀... 자진사퇴엔 “아직 생각 안해봐”
# 김재원, 한 달 만에 최고위 복귀…"자진사퇴? 생각한 적 없다"
# '설화' 김재원, 한 달 만에 최고위 복귀..."심려 끼쳐 죄송"
# '설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안해봐"(종합)
# 37개의 관련뉴스 더보기
#
#
#
# "어떤 정치세력도 공영방송 과점 못하게 방송법 개정 필요"
# 박대출 "방송법 국회 통과하면 대통령이 거부권 행사해야"
# 與 박대출 "방송법 통과하면, 대통령이 거부권 행사해야"
# 국민의힘, 방송법 통과 앞두고 KBS 때리기···박대출 “방송법 통과하면 대통령 거부권 행사해야”
# 11개의 관련뉴스 더보기
#
#
#
# 김민석 "윤 대통령, 간호법 거부권 행사? 그러면 굉장히 독특한 분으로 봐야"
#
#
#
# 김민석 "간호법, 尹공약…거부권 행사하면 굉장히 독특한 분"
# 10개의 관련뉴스 더보기
#
#
#
# 박광온 "초등 자녀 키우는 맞벌이 부부 위한 주4일제 적극 검토"
#
#
#
# 박광온 "주4.5일제·학부모 위한 주4일제도 적극 검토"
# 22개의 관련뉴스 더보기
#
#
#
# "워싱턴 선언은 제2 한·미 상호방위조약"
# 이종섭 국방장관 "워싱턴 선언, 제2한미상호방위조약"
# 9개의 관련뉴스 더보기
# 김기현 "尹 국빈 방미, 한미 새 이정표 수립 최대 성과"
#
#
#
# 김기현, ‘워싱턴 선언’ 두고 “한국형 확장억제 구체화…文때와 차원 달라”
# 17개의 관련뉴스 더보기
#
#
#
# 북, 美전략핵잠 한반도 전개 '적법' 판단에 "황당무계한 궤변"
#
#
#
# 북, 미국 SSBN 한반도 전개 ‘적법’ 판단에 “황당무계한 궤변”
# 14개의 관련뉴스 더보기
#
#
#
# 與 윤리위, 다음달 1일 첫 회의…김재원·태영호 운명은
#
#
#
# 국민의힘 윤리위, '설화' 김재원·태영호 징계절차 개시(상보)
# 58개의 관련뉴스 더보기
#
#
#
# 일본인 가네코 후미코·후세 다쓰지 ‘5월 독립운동가’
#
#
#
# 2명의 일본인이 ‘5월의 독립운동가’로 선정된 까닭은?
# 13개의 관련뉴스 더보기
#
#
#
# 방미 마친 尹지지율 4주만에 반등..전주 대비 소폭 오른 34.5%
#
#
#
# 민주당 1.0%p 내린  44.7%…국민의힘 35.2%[리얼미터]
# 39개의 관련뉴스 더보기
#
#
#
# 윤재옥, 한미 핵협의그룹에 "자체 핵무장 보다 더 큰 이익"
#
#
#
# 윤재옥 "워싱턴 선언, 우리 자체 핵무장보다 더 큰 이익될 것"
# 4개의 관련뉴스 더보기
#
#
#
# [속보]尹대통령 “한미동맹, 청년 세대에게도 기회의 플랫폼 돼야”
#
#
#
# 尹 "확장된 한미동맹, 미래세대 기회 플랫폼 돼야"
# 15개의 관련뉴스 더보기
#
#
#
# 갈등에서 화합의 장으로…제주 강정마을 ‘제1회 일강정의 날’ 개최
#
#
#
# “15년 갈등 ‘강정마을’서 민관군 화합축제 엽니다”
# 4개의 관련뉴스 더보기
#
#
#
# “국제사회는 강한 우려”…北, 중러 ‘워싱턴선언’ 비판 조명
#
#
#
# 북한, ‘내 뒤에 중·러있다’…‘워싱턴 선언’ 비판 움직임 집중 보도
# 8개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 홍성걸 칼럼
#
#
#
#
#  국빈 방문과 한미 정상회담의 이해
#  경고음 울린 대한민국호
#  한일관계 정상화 이유와 의미
#  문민정부 30주년에 돌아보는 한국 정치
#
#
#
#
# '오랑우탄이 가슴을'…동물학대 논란 휩싸인 '인어공주'
# 아시아경제
#
#
#
# “수천억에 사도 할 수 있는 것 없어”… 동원·KG 손사래 …
# 조선비즈
#
#
#
# '법카'로 구찌·샤넬…명품 수십억 산 경리에 징역 7년
# 연합뉴스
#
#
#
# 윤 대통령, 트위터로 바이든 부부에 "국빈만찬에 아내도 감 …
# JTBC
#
#
# 동영상기사
#
# 한 곳에서 로또 2등 103장…논란에 정부가 계획 내놨다
# SBS
#
#
#
# [단독]피해자 주장 임창정 회사, 사내이사는 '주가조작'  …
# 중앙일보
#
#
#
# 법원 "반찬에서 개구리 사체 나온 급식업체 영업정지 정당"
# YTN
#
#
#
# “자연스럽고 투명하게”…외국서 난리난 한국식 화장법, 비법 …
# 매일경제
#
#
#
# 34세 이하 청년, 매달 10만원씩 3년간 납입하면 2배  …
# ZDNet Korea
#
#
#
# 대만 ‘비상’ 한국 ‘비상’…18년 만에 1인당 GDP 추 …
# 서울신문
#
#
#
# [영상] 브로드웨이 한인 샌드위치 가게 폐업…배우들이 흘린 …
# 머니투데이
#
#
#
# “얼마나 아팠을지 가슴이 찢어진다”…부산 영도구 등굣길 참 …
# 부산일보
#
#
#
# “제주보다 싸다고, 일본 ‘우르르’ 가더니” 10만원 훌쩍 …
# 헤럴드경제
#
#
#
# 송영길이 밀고 최문순이 당겼나…남헌기 막은 '동해 사람들' …
# 시사저널
#
#
#
# 기자단 만찬서 기분 좋은 바이든… “1조원 날린 폭스, 공 …
# 조선일보
#
#
#
# 모텔서 쓰더니 이젠 '1인 가구 필수품'…삼성도 뛰어들었다 …
# 한국경제
#
#
# 동영상기사
#
# 복지장관 "간호조무사 학력 상한 꼭 개정해야"
# MBC
#
#
#
# 제주 해변서 주운 80년대 샴푸 껍데기…이뿐만이 아닙니다[ …
# 서울경제
#
#
# 동영상기사
#
# [핫클릭] 임창정 '1조 파티' 참석 논란에…"게스트로 참 …
# 연합뉴스TV
#
#
#
# "사명감? 그게 뭐죠?"... 의대 차석은 메스 대신 레이 …
# 한국일보
#
#
#
# DMZ근무 美장교 “北장교들 초코파이-도리토스 좋아해”[사 …
# 동아일보
#
#
#
# 고등학교 분리 배출함에 수북이 쌓인 물건, 걱정됩니다
# 오마이뉴스
#
#
#
# "곧 막내딸 생일, 선물도 사놨는데"…스쿨존 참변 초등생  …
# 뉴스1
#
#
#
# “얼마나 아팠을까” 부산 등굣길 참변 아이 아빠의 글
# 국민일보
#
#
#
# "이 맥주 많이 먹었는데"…식약처 전량 회수조치
# SBS Biz
#
#
#
# [뉴스비하인드] 대구경북신공항, 새로운 하늘길인가? 꽉 막 …
# 대구MBC
#
#
#
# '부자아빠' 기요사키 "바이든 역대 최악의 대통령...경기 …
# 한국경제TV
#
#
#
# 건설노조 간부, 법원 앞 분신…검찰 겨냥 마지막 글 남겨
# 한겨레
#
#
#
# '1세대 영어강사' 오성식 "윤 대통령 영어연설에 소름"
# MBN
#
#
#
# 임창정 압구정 수백억 건물주?…"물어보니 펄쩍, 저작권까지 …
# 디지털타임스
#
#
#
# 전세 거래 올 스톱…“잘 살던 세입자도 방 빼겠다고 해”
# 경향신문
#
#
#
# "검사 때 해외연수?" 尹 영어연설 띄우기 진심이었던 언론 …
# 미디어오늘
#
#
#
# "이게 맞나요?"…사장 기분 살피던 직원, 결국 '근로자의 …
# 아이뉴스24
#
#
#
# 다큐 '문재인입니다' 공개…"5년간 성취 무너져" 발언은  …
# TV조선
#
#
#
# '법카'로 구찌·샤넬 41억원 쇼핑한 경리…징역 7년
# 매일신문
#
#
# 동영상기사
#
# ‘브로드웨이 명물’ 한인 샌드위치 가게 문 닫자…단골들 ‘ …
# KBS
#
#
#
# '강남 투신' 10대 만났던 20대 남성 입건…자살방조죄  …
# 노컷뉴스
#
#
#
# [영상]광명에서 또? 국평 10억원 나왔다!(feat.광명 …
# 비즈워치
#
#
#
# ﻿운동 효과 떨어뜨리는 ‘잘못된 운동 습관’  …
# 코메디닷컴
#
#
#
# 대만 여행 간 30대 한국여성 숨진 채 발견…경찰, 타살  …
# 전자신문
#
#
#
# "부모님 모시고 외식 한 번 20만원"…지갑 열기 무서운  …
# 강원일보
#
#
#
# 회사 ‘52조’ 빚더미 앉았는데 임원 연봉 30% 오른 이 …
# 문화일보
#
#
#
# ‘남자한테 몸파는 놈이' 한마디가 부른 살해[그해 오늘]
# 이데일리
#
#
#
# 中우한 코로나19 실태 고발했다 실종된 시민 "3년만 석방 …
# 뉴시스
#
#
#
# "女연예인 주로 아이폰 쓰는데.. 박은빈은 갤럭시 마니아" …
# 파이낸셜뉴스
#
#
#
# 혈관청소부 OOO, 대장염 개선에도 ‘효과’ 입증
# 세계일보
#
#
#
# ‘전광훈 천하통일’ 김재원, 한 달 만에 복귀…“심려 끼쳐 …
# 채널A
#
#
#
# "더는 못 참겠다"… 박은빈 드라마 촬영장에 벽돌 투척한  …
# 대전일보
#
#
#
# 코로나 신규 확진 5774명...위중증 135명·사망자 8 …
# 동아사이언스
#
#
# 동영상기사
#
# 여수 새로운 관광단지 조성 첫 발..더 높은 비상 기대
# kbc광주방송
#
#
#
# 원빈♥이나영, 145억에 산 청담동 빌딩… 5년 만에 30 …
# 머니S
#
#
#
# [툰설툰설] 권선징악 ‘복수극’ 한 판…고백 VS 세명이서 …
# 디지털데일리
#
#
#
# 캐논 '이미지 포뮬러 R50'이면 5분만에 소설책 스캔 뚝 …
# 블로터
#
#
#
# 민주당, 문재인 때는 별나라에 가 있었나 [이진곤의 그건  …
# 데일리안
#
#
#
# 폭탄이 머리 위를 지나 기시다 총리 발밑으로
# 시사IN
#
#
#
# 겨드랑이에 ‘이 증상’ 생겼다면… 무좀균 옮은 것?
# 헬스조선
#
#
#
# 성행위 촬영물이 '엔터'로? 신동엽 뒤로 감춰진 '성착취'
# 프레시안
#
#
#
# ‘역대급 실적’ 2차전지, 급등락 요동치는 주가
# 주간동아
#
#
#
# "내가 번 돈 쟤한테 다 줘"…임창정, 또 투자자 행사 참 …
# 이코노미스트
#
#
#
# '똘똘한 100석이 낫다'... 개딸이 기존 팬덤과 다른  …
# 주간조선
#
#
#
# “요새 사이 좋네” 삼성전자와 네이버, 손잡는 이유는
# 한경비즈니스
#
#
#
# President Yoon Suk Yeol back fro …
# 코리아중앙데일리
#
#
#
# 문화재관람료 4일 폐지, 전국 산 무료 입장
# 월간 산
#
#
#
# 10만원 넣으면 '1140만원'…청년내일저축계좌 시작
# 더팩트
#
#
#
# 광화문·여의도 등 서울 도심서 노동절 집회
# 조세일보
#
#
#
# 저는 SKY, 사수는 그냥 ‘인서울’...학벌 알고 나니  …
# 매경이코노미
#
#
#
# 문 대통령이 오월 광주의 그 이름 하나하나 부르기까지
# 한겨레21
#
#
#
# 안성 양성면 물류창고서 화재…60대 직원 1명 연기흡입·  …
# 경기일보
#
#
#
# 김종인 “총선 마스코트 한동훈? 무모한 일” [+영상]
# 신동아
#
#
#
# 'Ilmu' puts contemporary spin on …
# 코리아헤럴드
#
#
#
# 야외활동 후 ‘사마귀’가 생겼다면? ‘이것’ 주의
# 농민신문
#
#
#
# 여자화장실 침입한 20대 여장 남성 검거... 시민이 붙잡 …
# CJB청주방송
#
#
#
# 해인사·불국사·월정사 등 65개 사찰 4일부터 무료입장
# 강원도민일보
#
#
#
# 73년 된 상속세, 어떻게 바뀌어야 하나
# 주간경향
#
#
#
# "부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …
# 전주MBC
#
#
#
# "부모 대부분 자녀들 마약 범죄 몰라".. 용돈으로 사고, …
# 전주MBC
#
#
#
# '부채 52조 원' 가스공사, 자사 임원에겐 '연봉 30% …
# 국제신문
#
#
#
# 유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근 …
# JIBS
#
#
#
# 리버버스 김포~여의도 20분? 실제론 1시간 28분 [視리 …
# 더스쿠프
#
#
#
# 적금 탔더니 그 돈으로 병원을 가네···5월 별자리 운세
# 레이디경향
# [속보] 與윤리위, '설화' 김재원·태영호 징계절차 개시
# '설화' 김재원 최고위 복귀…'자진사퇴'엔 "아직 생각 안 해봐"
# 尹지지율 34.5%, 4주 만에 반등…“방미 활동 평가” [리얼미터]
# 대만 “유일한 남미 친구 지켰다”…파라과이 대선 결과에 ‘일단’ 안도
# "한국, 양육비 가장 비싼 나라"…1인당 GDP의 7.7배
# '41% 급감' 반도체에 수출 7개월째 감소…무역적자 14개월 연속(종합2보)
# 금감원 “올해 공매도 규모 급증… 무차입 공매도 33건 제재 조치 완료”
# 정부 "전세사기 피해자 기존 전세대출 20년 분할상환"
# ‘중간요금제’ 속속 출격…LTE→5G 전환 이끌어낼까
# '노태북 열풍 이어갈까'…삼성, 인텔 13세대 기반 PC 3종 출시
# 송영길 측 "내일 검찰 자진 출석"...與 "상습 탈선"
# '강남 투신' 10대 만났던 20대 남성 입건…자살방조죄 적용
# ‘급식 개구리 사체’ 위탁업체 vs 영양사 책임공방… 법원 판단은?
# 4일부터 국립공원 사찰 등 문화재 관람료 무료
# 현대차, '대한민국 동행축제' 연계 최대 5% 할인 프로모션
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기

# %% [markdown]
# ## 과제 1_0501
#
# 'https://news.naver,com/'에서 title내용을 세가지 방법으로 출력하세요

# %%
from bs4 import BeautifulSoup
import requests as rq
url = 'https://news.naver.com/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')
print(bs)

# %%
import urllib.request as rq

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html = rq.urlopen(url)
bs  = BeautifulSoup(html, 'lxml')
texts = bs.find_all('p')
print(texts)
# Out:
# [<p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>, <p class="section_sub_txt">오전 11시~오후 12시까지 집계한 결과입니다.</p>, <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
for t in texts:
    t = t.get_text()
    print(t,'\n')
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
#
# 오전 11시~오후 12시까지 집계한 결과입니다.
#
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
import urllib.request as rq

url = 'https://news.naver.com'
html = rq.urlopen(url)
bs  = BeautifulSoup(html, 'lxml')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport"/>
#   <link href="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#   <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script>
#    (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/statistics_jquery.js" type="text/javascript">
#   </script>
#   <script>
#    document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#   </script>
#   <script>
#    document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#   </script>
#   <meta content="네이버 뉴스" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#   <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#   <meta content="네이버" property="og:article:author"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="네이버 뉴스" name="twitter:title"/>
#   <meta content="네이버 뉴스" name="twitter:site"/>
#   <meta content="네이버 뉴스" name="twitter:creator"/>
#   <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#   <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#   <script>
#    (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#   </script>
#  </head>
#  <body class="as_mp_layout">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             연예
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/factcheck/main.naver" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="Nlnb_right">
#         <div class="lnb_extra" id="">
#          <div class="lnb_extra_menu">
#           <ul class="lnb_extra_menu_list">
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://news.naver.com/main/officeList.naver" onclick="nclk(event,'slb.allmedia','','');">
#              전체 언론사
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://newsstand.naver.com/" onclick="nclk(event,'slb.newsstand','','');" target="_blank">
#              뉴스스탠드
#             </a>
#            </li>
#            <li class="lnb_extra_menu_item">
#             <a class="lnb_extra_menu_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event,'slb.library','','');" target="_blank">
#              라이브러리
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         5
#        </strong>
#        .
#        <strong>
#         1
#        </strong>
#        <span>
#         (월)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#           <div class="cjs_news_flash_wrap cjs_nf_close _newsflash_wrapper">
#            <div class="cjs_nf_title">
#             <span class="ico_newsflash">
#              속보
#             </span>
#            </div>
#            <div class="cjs_nf_list _item_list">
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/021/0002569547" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                국민의힘 윤리위, ‘설화’ 김재원·태영호 징계절차 개시
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/021/2022/08/04/logo_021_56_20220804125306.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  문화일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <a class="cjs_nf_a _item _cds_link _newsflash_link" href="https://n.news.naver.com/article/082/0001210039" onclick="nclk(event, 'home.newsflash', '', '')">
#              <div class="cn_title_area">
#               <h4 class="cn_title">
#                국민의힘 윤리위, 김재원·태영호 징계 절차 개시
#               </h4>
#               <div class="cn_snippet">
#                <div class="cn_journal_wrap">
#                 <div class="cn_thumb">
#                  <img alt="" height="10" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/082/2019/08/22/logo_082_56_20190822111222.png?type=nf20_20" width="10"/>
#                 </div>
#                 <div class="cn_name">
#                  부산일보
#                 </div>
#                </div>
#               </div>
#              </div>
#             </a>
#             <button class="cjs_nf_btn_open is_close _toggle_btn" type="button">
#              <span class="blind">
#               속보 닫기
#              </span>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_news_preview_wrapper" data-max-page="16">
#          <div class="comp_journal_subscribe _preview_card_page" style="">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/009" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2018/07/20/logo_009_56_20180720194820.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                매일경제
#                <span class="datetime">
#                 05월 01일 12:08
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="009" data-office_name="매일경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005124025" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/009/2023/05/01/5124025.jpg?type=nf264_176&amp;ut=20230501095501" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                ‘박은빈 드라마’ 촬영장에 시끄럽다며 벽돌 투척 40대男 입건
#               </div>
#               <p class="cjs_d">
#                배우 박은빈의 차기작인 드라마 ‘무인도의 디바’ 촬영장에서 40대 남성이 던진 벽돌에 스태프가 다치는 사건이 발생했다. 서울 혜화경찰서는 한밤중 드라마 촬영 현장에 벽돌을 던진 혐의로 40대 남성 A씨를 불구속 입건
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/660" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/660/2022/01/19/logo_660_56_20220119141745.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                kbc광주방송
#                <span class="datetime">
#                 05월 01일 11:55
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="660" data-office_name="kbc광주방송" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000033684" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/660/2023/04/30/33684.jpg?type=nf264_176&amp;ut=20230430213311" width="100%"/>
#               <span class="comp_ico_movie">
#                동영상
#               </span>
#               <span class="comp_playtime">
#                <span class="time">
#                 <span class="blind">
#                  재생시간
#                 </span>
#                 01:44
#                </span>
#               </span>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                여수 새로운 관광단지 조성 첫 발..더 높은 비상 기대
#               </div>
#               <p class="cjs_d">
#                해마다 천만 명이 넘는 관광객이 찾는 여수에 새로운 관광단지가 조성 중입니다. 가장 먼저 루지 테마파크가 문을 연 것을 시작으로 2026년까지 세계적인 브랜드 호텔과 대관람차도 추가로 들어설 예정입니다. 여수와 고흥
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/015" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/015/2020/08/11/logo_015_56_20200811194037.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한국경제
#                <span class="datetime">
#                 05월 01일 12:15
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="015" data-office_name="한국경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/015/0004839355" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/015/2023/05/01/4839355.jpg?type=nf264_176&amp;ut=20230501085701" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                '권리금 1억' 핫플이 어쩌다가…일산 '라페스타'의 몰락 [현장+]
#               </div>
#               <p class="cjs_d">
#                "2000년대 중반에 라페스타가 어땠냐고요? 지금의 스타필드와 비슷했다고 보면 될 거예요. 음식점, 옷 가게, 놀거리 등 없는 게 없었으니까요. 지금은 잘 안 오게 돼요. 인스타그램에서 관심이 많은 음식점이나 카페가
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/346" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2023/02/24/logo_346_56_20230224143254.jpg?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                헬스조선
#                <span class="datetime">
#                 05월 01일 12:11
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="346" data-office_name="헬스조선" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000060562" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/346/2023/05/01/60562.jpg?type=nf264_176&amp;ut=20230501120101" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                콜센터 막말 실형, 폭언도 ‘이 정도’면 정신질환
#               </div>
#               <p class="cjs_d">
#                콜센터 상담사에게 상습적으로 폭언을 일삼던 민원인이 실형을 선고받았다. 폭언을 자주 한다면 타인에게 상처를 주는 것뿐만이 아니라 스스로 정신질환이 있는지 점검해 볼 필요가 있다. 서울특별시 120다산콜재단은 폭행·협
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/417" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/417/2021/01/25/logo_417_56_20210125161624.png?type=nf76_76_q90" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                머니S
#                <span class="datetime">
#                 05월 01일 11:15
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="417" data-office_name="머니S" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/417/0000917195" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/417/2023/05/01/917195.jpg?type=nf264_176&amp;ut=20230501052701" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                月10만원 저축하면 3배 지급… "청년내일저축계좌 가입하세요"
#               </div>
#               <p class="cjs_d">
#                월 10만원씩 저축한 청년에게 3년 만기 시 최대 원금의 세 배를 추가로 지급하는 '청년내일저축계좌' 신청이 시작된다. 1일 보건복지부에 따르면 이날부터 오는 26일까지 청년내일저축계좌 신규 가입자를 모집한다. 대상
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/008" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/008/2018/09/13/logo_008_56_20180913140213.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                머니투데이
#                <span class="datetime">
#                 05월 01일 11:24
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="008" data-office_name="머니투데이" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/008/0004881749" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/008/2023/05/01/4881749.jpg?type=nf264_176&amp;ut=20230501093901" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                [영상] 브로드웨이 한인 샌드위치 가게 폐업…배우들이 흘린 눈물
#               </div>
#               <p class="cjs_d">
#                39년간 미국 뉴욕 극장가에서 자리를 지켜온 한인 샌드위치 가게가 문을 닫았다. 이 소식에 브로드웨이 배우와 스태프 등 단골이 모여 송별하는 자리를 마련한 데 이어 외신도 이를 슬픈 소식으로 보도했다. 지난달 30일
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/056" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/056/2021/10/28/logo_056_56_20211028103053.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                KBS
#                <span class="datetime">
#                 05월 01일 12:40
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="056" data-office_name="KBS" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/056/0011476128" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/056/2023/05/01/11476128.jpg?type=nf264_176&amp;ut=20230501123601" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#               <span class="comp_ico_movie">
#                동영상
#               </span>
#               <span class="comp_playtime">
#                <span class="time">
#                 <span class="blind">
#                  재생시간
#                 </span>
#                 02:04
#                </span>
#               </span>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                수단 군벌, 또 72시간 휴전 합의…“북한 무기 사용”
#               </div>
#               <p class="cjs_d">
#                지난달 15일부터 군벌 간 무력 충돌로 극도의 혼란에 빠진 수단에서 또다시 72시간 동안 휴전이 연장됐습니다. 한편 군벌의 다툼에 대북 제재로 금지된 북한의 무기가 사용됐을 수 있다고 미국 북한 전문 매체가 보도했습
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/087" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                강원일보
#                <span class="datetime">
#                 05월 01일 12:20
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="087" data-office_name="강원일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/087/0000967683" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/087/2023/05/01/967683.jpg?type=nf264_176&amp;ut=20230501000204" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "부모님 모시고 외식 한 번 20만원"…지갑 열기 무서운 가정의 달
#               </div>
#               <p class="cjs_d">
#                고공행진하는 먹거리 물가에 가정의 달을 맞이하는 서민들의 표정이 어둡다. 4인 가족 기준 10만원을 넘나드는 외식비에 소비자들 사이에선 "가족 모임이 무섭다"는 말까지 나온다. 원주에 거주하는 40대 직장인 홍모씨는
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/050" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/050/2021/07/15/logo_050_56_20210715110055.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한경비즈니스
#                <span class="datetime">
#                 05월 01일 09:29
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="050" data-office_name="한경비즈니스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000065225" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/050/2023/05/01/65225.jpg?type=nf264_176&amp;ut=20230501060210" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                “요새 사이 좋네” 삼성전자와 네이버, 손잡는 이유는
#               </div>
#               <p class="cjs_d">
#                삼성전자와 네이버가 손잡는 사례가 늘어나고 있다. 지난해 연말 ‘초거대 인공지능(AI)’에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술(IT) 등에서 협력 범위를 넓혀 나가고 있다. 최근
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/030" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/030/2018/07/20/logo_030_56_20180720194820.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                전자신문
#                <span class="datetime">
#                 05월 01일 11:38
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="030" data-office_name="전자신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003095374" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/030/2023/04/30/3095374.jpg?type=nf264_176&amp;ut=20230430155801" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                中, 반도체 원산지 전수조사…韓 압박
#               </div>
#               <p class="cjs_d">
#                중국이 우리나라 반도체 산업에 대한 압박에 나섰다. 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장, 미-중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_info">
#             <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">
#              새로보기
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#           <div class="cjs_channel_card">
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/449" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/449/2020/06/26/logo_449_56_20200626104826.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                채널A
#                <span class="datetime">
#                 05월 01일 12:47
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="449" data-office_name="채널A" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000248701" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/449/2023/05/01/248701.jpg?type=nf264_176&amp;ut=20230501083201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                ‘근로자의 날’…서울 도심 곳곳 대규모 집회
#               </div>
#               <p class="cjs_d">
#                근로자의 날인 오늘(1일) 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다. 민주노총은 오늘 오후 2시 서울 종로구 동화면세점 앞에서 '세계노동절대회'를 열고 7월 총파업 투쟁을 선포할 계획
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/082" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/082/2019/08/22/logo_082_56_20190822111222.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                부산일보
#                <span class="datetime">
#                 05월 01일 12:31
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="082" data-office_name="부산일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001210029" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/082/2023/05/01/1210029.jpg?type=nf264_176&amp;ut=20230501114701" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                “얼마나 아팠을지 가슴이 찢어진다”…부산 영도구 등굣길 참변 초등생 아빠의 글
#               </div>
#               <p class="cjs_d">
#                지난달 28일 부산 영도구 어린이보호구역에서 1.7t 규모 원형 어망실에 치여 10세 여아가 목숨을 잃은 사고와 관련해(부산일보 5월 1일 자 1면 보도 등) 아이의 아버지가 “아이에 대해 기억하고 싶어 글을 남긴다
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/014" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/014/2020/12/23/logo_014_56_20201223183322.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                파이낸셜뉴스
#                <span class="datetime">
#                 05월 01일 12:46
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="014" data-office_name="파이낸셜뉴스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005005141" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/014/2023/05/01/5005141.jpg?type=nf264_176&amp;ut=20230501095603" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "우한 코로나 끔찍" 고발했다 실종된 中시민, 3년 만에 석방된다
#               </div>
#               <p class="cjs_d">
#                2020년 코로나19 바이러스가 처음 확산한 중국 후베이성 우한시의 방역 실태를 고발했다가 실종된 중국 시민이 3년만에 석방될 예정이라는 보도가 나왔다. 30일(현지시간) AP통신은 해당 시민의 친척과 익명을 요구한
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/469" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2023/02/07/logo_469_56_20230207160012.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                한국일보
#                <span class="datetime">
#                 05월 01일 12:09
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="469" data-office_name="한국일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
#            <div class="cjs_journal_wrap _item_contents">
#             <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000736994" onclick="nclk(event, 'home.editnfimg', '', '')">
#              <div class="cjs_news_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/469/2023/05/01/736994.jpg?type=nf264_176&amp;ut=20230501104001" loading="lazy" onerror="showNoImage(this)" width="100%"/>
#              </div>
#              <div class="cjs_news_tw">
#               <div class="cjs_t">
#                "사명감? 그게 뭐죠?"... 의대 차석은 메스 대신 레이저를 잡았다
#               </div>
#               <p class="cjs_d">
#                편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미
#               </p>
#              </div>
#             </a>
#            </div>
#            <div class="cjs_ctitle _item_title">
#             <a class="cjs_ctitle_a" href="https://media.naver.com/press/123" onclick="nclk(event, 'home.editnfmedia', '', '')">
#              <div class="cjs_cmw small">
#               <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/123/2018/10/02/logo_123_56_20181002190002.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
#              </div>
#              <div class="cjs_ctw">
#               <h4 class="channel">
#                조세일보
#                <span class="datetime">
#                 05월 01일 11:49
#                </span>
#               </h4>
#              </div>
#             </a>
#             <div class="cjs_ctitle_right">
#              <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="123" data-office_name="조세일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#               구독
#              </button>
#             </div>
#            </div>
# ...
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/008/2018/09/13/logo_008_56_20180913140213.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               머니투데이
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="011" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               서울경제
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="014" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/014/2020/12/23/logo_014_56_20201223183322.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               파이낸셜뉴스
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="123" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/123/2018/10/02/logo_123_56_20181002190002.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               조세일보
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="018" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/018/2018/07/18/logo_018_56_20180718152418.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               이데일리
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="648" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/648/2023/02/13/logo_648_56_20230213170647.png" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               비즈워치
#              </div>
#             </a>
#            </li>
#            <li class="cjs_channel_item">
#             <a aria-checked="false" class="cjs_channel_a _item" data-office_id="016" href="javascript:;" role="checkbox">
#              <div class="cjs_channel_mw">
#               <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/016/2020/11/03/logo_016_56_20201103113832.jpg" loading="lazy" onerror="showNoImage(this)"/>
#              </div>
#              <div class="cjs_channel_name">
#               헤럴드경제
#              </div>
#             </a>
#            </li>
#           </ul>
#           <div class="cjs_info">
#            <button class="cjs_btn_refresh _refresh_btn" onclick="nclk(event, 'home.edittnew', '', '')" type="button">
#             새로보기
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_subinfo">
#     <div class="f_subinfoinner">
#      <div class="f_notice">
#       <h5 class="f_notice_badge">
#        공지
#       </h5>
#       <a class="f_notice_link" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=715","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=715"}' href="https://m.news.naver.com/ombudsman/noticeread?notiId=715" onclick="nclk(event, 'fot.noticetext', '', '');">
#        <p class="f_notice_text">
#         기자·연재 카드 개선 안내
#        </p>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:;" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_ftlkw _footer_login" id="u_ftlkw">
#        <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#         전체서비스
#        </a>
#       </p>
#       <p class="u_cr">
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">
#           이용약관
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');">
#           <strong>
#            개인정보처리방침
#           </strong>
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          청소년 보호 책임자 : 이희만
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#        </span>
#        <span class="u_cri">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230420_005654/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023050112";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
# lcs_do();
#
#
#     try{
#         initMa();
#     }catch(e){}
# });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
# Q. p태그 데이터를 모두 불어와서 텍스트만 출력
texts = bs.find_all('p')
for t in texts:
    t = t.get_text()
    print(t)
# Out:
# 배우 박은빈의 차기작인 드라마 ‘무인도의 디바’ 촬영장에서 40대 남성이 던진 벽돌에 스태프가 다치는 사건이 발생했다. 서울 혜화경찰서는 한밤중 드라마 촬영 현장에 벽돌을 던진 혐의로 40대 남성 A씨를 불구속 입건
# 해마다 천만 명이 넘는 관광객이 찾는 여수에 새로운 관광단지가 조성 중입니다. 가장 먼저 루지 테마파크가 문을 연 것을 시작으로 2026년까지 세계적인 브랜드 호텔과 대관람차도 추가로 들어설 예정입니다. 여수와 고흥
# "2000년대 중반에 라페스타가 어땠냐고요? 지금의 스타필드와 비슷했다고 보면 될 거예요. 음식점, 옷 가게, 놀거리 등 없는 게 없었으니까요. 지금은 잘 안 오게 돼요. 인스타그램에서 관심이 많은 음식점이나 카페가
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 ‘문재인입니다’(10일 개봉)는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 ‘입’을 빌린 대통령 문재인의 면모를 병치시킨다. 문 전 대통령의 정
# “김익래 회장이 주가 조작을 알았을 가능성은 0.0001%도 없다. 공교롭게 그때 매각을 했던 것이고 사실 그 전부터 팔려고 했다. 김 회장은 주가 조작 혐의를 받는 H투자자문 라덕연 대표와도 전혀 친분이 없다. 직
# # 김포의 황금빛 들녘을 상징한다는 이름, 김포골드라인. 하지만 개통 이후 줄곧 극심한 혼잡으로 각종 논란을 겪고 있는 비운의 노선이기도 합니다. 이 문제를 해결하기 위해 서울시에서 대체교통수단인 '리버버스(Rive
# 기사내용 요약 AP 보도…"분란 혐의 등으로 3년형 선고" 코로나19가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 3년 만에 석방될 것이라고 AP통신이 30일(현지시간) 보도했다. 통신은 이 시민의 친척
# 검찰이 청소년 마약범죄에 대해서는 최고 사형까지 구형하겠다며 엄정 대응을 예고했습니다. 검찰은 당장 '학원가 마약 음료' 사건에 가중처벌 조항을 적용하는 방안을 검토하고 있습니다. 취재기자 연결해 자세한 내용 알아봅
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “
# 우리나라에서 세단의 대명사는 쏘나타였다. 특히 강남 지역에서 자주 보이는 수입차에 ‘강남 쏘나타’라는 별명을 붙이기도 했다. 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
# 볼트엣마켓(Vault@Market)은 가치있는 거래 정보를 제공하고 투자자를 보호(Vault)하는, <블로터>의 새로운 자본시장 정보제공 서비스입니다. AI(인공지능) 영상감시솔루션 전문기업 트루엔의 수요예측이 4월
# 요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은
# ※기사 내 링크는 서울경제신문 홈페이지에서 이용할 수 있습니다. 일회용 '럭키 나너 콘디쇼닝 샴푸'. 얼마 전 변수빈 디프다제주 대표와 일행들이 한림 해변에서 주운 쓰레기입니다. 찾아보니 무려 1980년 출시된 제품
# 5·1 노동절을 맞아 여야가 노동 가치를 강조했다. 그러면서도 국민의힘은 '노조의 특권'을 비판했다. 더불어민주당은 윤석열 정부가 추진했던 '주 69시간 근무제'를 비판했다. 유상범 국민의힘 수석대변인은 1일 "윤석
# 독일 나치 부역자의 보석 700점, 2000억원어치가 경매에 나온다. 카르티에, 불가리 등 명품 브랜드의 희귀 보석들이다. 미국 뉴욕 크리스티 경매는 이달부터 오스트리아 억만장자인 하이디 호르텐의 소장품 중 보석 7
# 한귀섭 윤왕근 신관호 기자 = 1일 오전 9시 35분쯤 강원 강릉에 위치한 춘천지법 강릉지원 앞에서 양모씨(50)가 분신을 시도했다. 경찰과 소방당국에 따르면 양씨는 심정지 상태로 출동한 소방당국에 의해 인근 병원으
# 정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설
# “양심. 그래요, 양심. 세상에서 제일 무서운 게 그겁니다. 군인들이 쏘아 죽인 사람들의 시신을 리어카에 실어 앞세우고 수십만의 사람들과 함께 총구 앞에 섰던 날, 느닷없이 발견한 내 안의 깨끗한 무엇에 나는 놀랐습
# 최근 한 초등학생이 등굣길이 1.5t짜리 원통형 화물에 치여 숨진 사고와 관련, 유족 측이 먹먹한 심경을 전했다. 1일 한 온라인 커뮤니티에는 '부산 영도구 청학동 A 양 아빠입니다'라는 제목의 글이 올라왔다. 부산
# LG에너지솔루션·삼성SDI 1분기 호실적… 금융당국 “2차전지 신용거래 급증” 우려 “떨어질 땐 다 같이, 오를 땐 혼자.” 4월 26일 한 LG에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다. 이날 LG에
# # 국내 한 정유사에 다니는 A씨는 입사 이후 사수에게 혼나가며 일을 배웠다. 사수는 엄격했지만, 일처리가 빨랐고 업무 방식도 잘 알려줬다. 나름 사수에게 만족하며 다니던 A씨는 최근 ‘인사기록카드’를 보고 멈칫했다
# 유통업계의 디지털 전환(DX)은 거스를 수 없는 변화다. DX에 성공한 기업이 살아남고, 실패하면 도태될 것이란 긴장감이 감돌고 있다. 생존에 위협을 받은 유통업계는 DX에 대규모 투자를 쏟아붓고 있지만, 출혈경쟁
# 수백억원대 이스타항공 배임·횡령 혐의로 재판에 넘겨진 이상직 전 국회의원이 징역 6년을 확정받았다. 구속 당시 자신을 '불사조'라고 비유하며 부활을 호언한 것으로 알려진 그는 수의를 입고 후속 재판을 받게 됐다. 특
# 천연기념물 지정된 순천 승주 평지마을 이팝나무
경찰의 커뮤니티 폐쇄 요청과 이를 수용하지 않은 방심위의 결정을 두고 여러 이야기가 나옵니다.
# 최근 들어 10대들이 연루된 마약 범죄 사건이 '무시할 수 없는 수준'에 이르렀습니다. 청소년이 피해자인 경우가 많지만, 직접 마약을 판매하는 가해자인 사례도 적지 않습니다. 대검찰청은 오늘(1일) "대부분 부모는
# 2016년 5월1일. 경기 안산시 단원구 바닷가에서 신원미상 남성의 시신이 발견됐다. 마대에 담긴 시신은 신체 일부만 있었다. 일대에 대대적인 경찰 수색이 펼쳐졌다. 이틀 후 약 20km 떨어진 바닷가에서 시신의 나
# "다음 달이 우리 막내 생일이어서 미리 생일 선물을 준비했는데, 이제 전해줄 수가 없습니다." 가족의 사랑을 듬뿍 받았던 초등학생 막내딸, 등굣길에 1.5t이 넘는 화물에 깔려 하루아침에 세상을 떠났습니다. 사고가
# A 3.1 magnitude natural earthquake hit Okcheon, North Chungcheong Province, Sunday, the state weather agency said. The q
# “북한 장교들은 한국의 초코파이와 도리토스(나초칩)를 좋아했어요.” 2013년부터 2021년까지 유엔군 사령부 소속으로 비무장지대(DMZ)에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 28일 미
# “연산군이 황음무도한 짓을 벌인 탕춘대가 유네스코 세계유산감이라고?” 최근 문화재청이 한양도성과 북한산성, 탕춘대성을 포함한 ‘한양의 수도성곽’을 유네스코 세계유산 등재신청 후보로 선정했습니다. 이에따라 올해 9월에
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면, 자신의 운동 습관을 체크해 봐야 한다. 특히 체중, 허리 사이즈, 근육의 양 등 중요 수치에 변화가 없다면, 운동 효과에 대한 회의감마저 갖게 된
# ● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선
# 동원그룹, 맥도날드 인수 포기… “메뉴 하나도 글로벌 본사 허락 필요” 2016년 맥도날드 매각 불발 때도 ‘자율권’ 걸림돌 지적 업계 “스타벅스와 달리 작은 것 하나도 본사 허락받아야” KG그룹, KFC 운영 당시
#
#
#
#
#                                 방송 모아보기 클릭 시해당 방송사 뉴스를 볼 수 있으며LIVE 표시가 된 경우 생중계로시청 가능합니다.
#
#
#
# AI 시대 우리는 무엇을 하고 살게 될까? 나의 미래 계급은? [SDF다이어리]
# [씨네멘터리] 디자이너들이 꼽은 최고의 영화 포스터는?
# [월드리포트] 확장억제 성과 논란…'말의 성찬'이 부른 후과
# [월드리포트] 일본 남성 아이돌 대부 '성착취' 의혹…주류 언론 나서나
# 우크라, 크름반도 유류시설 공격 인정…“대반격 위한 준비”
# ‘제로백 3.8초’부터 ‘럭셔리’까지… 전기차 미래 뽐냈다[자동차]
# ‘깡통 전세’ 전세보증보험 가입 안돼…이제 전세가율 90%까지만 가입 가능
# 이번 방미 긍정 평가?...尹 지지율 4주만에 반등, 34.5%[리얼미터]
# '내 돈'에 손댄 은행사람들… 사라진 양심과 제식구 감싸기 [SCOOP 관점]
# 근로시간 69시간… 구로의 불편한 등대 [視리즈]
# 냉면, 비빔밥… 1만원으로 먹을 게 없는 야속한 시절
# 문 닫는 도봉고등학교 가보니… 사라질 공간에 남은 흔적들
# 여성을 가둔 감옥을 부수자, 마녀들과 춤추자
# 정통 워맨스, 그런데 킬힐 못 벗은 언니들의 '퀸메이커'
# 피해자 보호 관점 실종된 '나는 신이다' 열풍
# 60대에 '별의 순간' 양자경...트랜스젠더 연기로 8세에 은곰상
# 기업 ‘셀프 규제’…중대재해 예방 ‘미지수’ [경기도 근로자 재해실태 보고서_16]
# 5박7일 안보·경제 행보… 與 ‘찬사’ 野 ‘혹평’ [윤 대통령 방미 성과와 평가]
# 행안부 “경기북부특별자치도, 분도 검토가 먼저”
# 경기도, 내년 ‘인구인지예산’ 편성…저출생·고령화 대응 나선다
# 尹, 이달 한일·한미일 연쇄회담…한미일 협력 심화 본격화
# 기시다 지지율, 외교 성과 힘입어 8개월 만에 50%대 회복
# 기시다, 내달 초순 방한 '가닥'…식민지배 사죄·반성 언급할까
# 도대체 바닥은 어디일까...제주 아파트값 3억씩 ‘뚝뚝’ [김경민의 부동산NOW]
# “이러다 20억 다시 찍으려나”...마포 집값 슬금슬금 오른다 [김경민의 부동산NOW]
# 용인 반도체 클러스터 수혜지 어디?...이천·동탄 등 경기 남부 ‘반세권’ 뜬다[김경민의 부동산NOW]
# 아파트 이름만 무려 25글자?...“길고 어려운 아파트명 쉽게 바꾸자”
# 오리고기 먹었더니, 몸속 혈관에 변화가?
# 혈압 관리에 주의...나트륨 많이 든 뜻밖 식품 5
# 체중 줄이고 혈당 천천히 낮게 올리는 음식은?
# "민간 방송 공정성을 누가 심판할 수 있나"
# '핵무장론' 미련 못버리는 조선일보, 과거에는 어땠나
# '부실 감사' 논란에 한겨레 노조위원장 사퇴 파문
# 추경 가능성 생존 몸부림 TBS 앞에 강경한 서울시 의회
# 한·미 ‘新밀월’… 尹, 핵우산 들고 귀국
# “워싱턴 선언, 나토 약정보다 실효적… 한·미 방위 업그레이드”
# 尹 ‘아메리칸 파이’, 방미 하이라이트
# [THINK ENGLISH] 이르면 올해 거리에서 배달 로봇 보게 될 듯
# [THINK ENGLISH] 윤 대통령, 전세사기 매물 경매 중단 지시
# [THINK ENGLISH] 조선 회화사의 공백 채울 걸작들의 귀환
# “매달 월급처럼 배당금이 또박또박” 요즘 인기 모으는 월배당 ETF
# ‘노랜딩’ 가능성 날린 SVB 파산, 다음 악재는 국제유가?
# “KB? 미래에셋? 어느 게 좋나요” 목돈 마련 돕는 다양한 청년 펀드들
# 월 소득 4000만 원으로 주담대 먼저 갚으세요
# NYT "미국서 환대받은 윤 대통령, 한국 분위기는 달라"
# 윤 대통령 "마음 먹으면 1년 이내 핵무장 가능하지만..."
# 윤 대통령 "전체주의가 민주주의 위협, 민주세력으로 위장"
# '사실상 핵공유'는 성과 부풀리기? 대통령실 "용어 집착할 필요 없어"
# [세계를 가다]물가 뛴다고…이집트 정부, 닭발 먹기 캠페인
# [아는기자]순방 외교서 ‘한일·한미일’ 이야기 많이 나온 이유는?
# [아는기자]‘주가조작 의혹’ 8개는 어떤 종목인가?
# [아는기자]“나의 친구”…윤석열-바이든, 36시간 동안 4개 일정
# '돈봉투 파문' 민주당은 여유 왜? '이정도 스캔들 별 문제 없어' 안일한 인식 탓" [촌철살인]
# 尹 대통령 방미 성과 "100% 만족하기 어려워도 너무 폄하할 필요는 없어" [촌철살인]
# '구하라·박수홍' 변호인 "권경애, 변호사의 수치..법, 정의 실현하는지 의문"[여의도초대석]
# 장예찬 "송영길은 꼬리, 몸통은 이재명..연결고리 '키맨'은 바로 '이사람'"[여의도초대석]
# 외신 "美, 韓 핵무장론 달래기 시도…핵잠 기항 동북아 불안정 키울 것"
# 워싱턴선언 '동상이몽'? 대통령실 "사실상 핵공유" 美당국자 "핵공유 아냐"
# 尹대통령 '워싱턴선언' 후속행보, 한미 '핵공유' 온도차
# '자체 핵무장' 주장 태영호 "尹대통령에 영업왕 칭호까지 줘야겠다"
# [중국은, 왜] '21세기 베를린', 대만…투키디데스는 틀렸나
# [우알생] 그들은 왜 '거지방'에 열광하나…조언대로 하루 살아보니
# [퍼센트] '근로자의 날' 누가 쉬고 못 쉬나…법이 갈라놓은 노동자들
# [오늘과학] 동료의 퇴사, 남은 직원들에게 미치는 영향은
# [오늘과학] 남성 육아휴직, 가족 구성원 성평등 의식 높인다
# [오늘과학] 북미서 발견된 5000만년 전 고추 화석
# [오늘과학] 하얗게 세어버린 머리카락 되돌리는 법
# 확장억제 강화 ‘워싱턴 선언’ 최대 성과…신냉전 구도 ‘숙제’ [국빈방미 결산]
# 첨단기술 동맹 맺고 8조 투자유치…IRA·반도체법 우려는 ‘여전’ [국빈방미 결산]
# “핵 보장 첫걸음” “경제성과 아쉬워”…한미정상회담 엇갈린 평가[국빈방미 결산]
# 尹대통령 “바이든 부부, 국빈 만찬 감사…다음엔 서울에서”
# 김재원 "심려 끼쳐 죄송", 태영호 "소신 변함  없어"..징계  향방은
# 해독작용 뛰어난 '미나리'.."대장염 개선에도 효과"
# 유급휴일 '근로자의 날'.."직장인 10명 중 3명  출근"
# 어디 '학폭' 뿐이랴.. '직장내 괴롭힘'에 신고조차 못해 "출근길이 지옥"
# "내가 번 돈 쟤한테 다 줘"…임창정, 또 투자자 행사 참석 논란
# ‘주가 조작 논란’ 임창정, ‘압구정 빌딩설’ 해명…“파주 건물 1채 뿐”
# 임창정 측 “주가조작단 ‘1조 파티’, 초대손님일 뿐 내용 몰랐다”
# ‘가을이 사건’ 가스라이팅 있었나… 친모 입에 쏠린 눈
# [단독] 사상자 10명 ‘에쓰오일 폭발 사고’ 외국인 CEO, 처벌 대상서 빠졌다
# 성공작 평가 진주시 캐릭터 ‘하모’, 소극적 활용에 관심 ‘시들’
# 궂은 날씨에도 청춘의 춤은 뜨거웠다… 데스팟크루, 부산 댄스 페스티벌 우승
# [약손+] 아이들도 힘들다, '새 학기 증후군' ⑨ADHD라는 오해
# [영상+] "내 꼬리는 빨개" 가창 부채꼬리바위딱새
# [뉴스+] 죽음의 과속 방지턱···사고 잇따르는 이유는?
# [들어보니] 우리는 보통 사람입니다 | 빅벙커
# Yoon fetes new nuclear accord as allies take harder line on NK
# Samsung eyeing 25% cut in chip production: analysts
# [Herald Interview] Winds of change in Korea's labor movement
# 글로벌 리더 尹, 국격 드높였다…5박 7일간 국빈 방미 일정 마치고 귀국
# 尹, 안보·경제 동맹 후속조치 주력…중·러 간극도 좁혀야
# 尹 귀국에 여야 공방전…"대국민 사기 외교" vs "워싱턴선언, 승리 방정식"
# ‘워싱턴 선언’ 들고 온 尹… 한일·한미일 연쇄회담 예고
# ‘핵협의그룹’ 판 키우기 원하는 美… 긴밀 협력 속도 내는 한일
# 中 “韓에 악몽, 이익보다 손실 클 것”… 사드 후 최악 우려
# "북한 7차 핵실험 시 독자 핵무장으로 갈 수 밖에" 윤상현 국민의힘 의원 직격 인터뷰 [시사스페셜]
# 윤 대통령 오늘 귀국…여야, 방미 성과 '극과 극' 평가  [시사스페셜]
# 귀국 5일 만에 압수수색, 송영길 소환 빨라지나  [시사스페셜]
# 내일 윤리위 첫 회의, 김재원 '5·18 이전 징계' 무게  [시사스페셜]
# [기획] 中, 한미 밀착에 `경제보복` 예고
# [경고음 커지는 對中 수출] 반도체·배터리·스마트폰도 고전… 對中 무역적자 굳어질수도
# [경고음 커지는 對中 수출] 尹 방미로 냉랭해진 中… 당분간 갈등 기류 불가피
# ‘윤석열 특수활동비’ 6월 23일 공개된다
# [주간 뉴스타파] 1,243일만의 승소... '검사' 윤석열, 검증의 시간
# 확정판결 검찰예산 신속히 공개 안 하면, '간접강제' 신청한다
# 검찰의 방패를 뚫고, 정보공개 최종 판결을 받아내기까지
# SG발 주가폭락 사태, 8종목은 왜 타깃이 됐나?
# 전문가 79% “챗GPT 답변이 의사보다 낫다”
# 한국판 ‘버핏과 점심’ 1호 행사...정의선·박재욱과 방송인 노홍철
# 1분기 아파트 매입, 30대 비율 사상 최고
# [경제혹한 대응法]⑥ “회생기업 M&A는 ‘진술과 보증’이 없다…옥석 가리는 게 최대 관건”
# [경제혹한 대응法]⑤ “쌍용차·STX중공업도 시련 겪었다…회생, 기업이 살아있단 걸 확인시켜주는 과정”
# [경제혹한 대응法]④ “지금은 불황 초입…기업 회생 절차, 타이밍 빨라야 희생 줄일 수 있어”
# [경제혹한 대응法]③ “한번에 무너지거나, 한번에 살아나거나…IT기업 구조조정은 속도가 생명”
# 방미 이후 후속 조치 주력...尹, 간호법 대응 '고심'
# 與 "제2의 한미방위조약" vs 野 "대국민 사기"
# '준비 부족' 지적한 박지원에 대통령실 "반국가적 작태"
# '핵 선제공격 위협' 北, 도발 카드 '만지작'
# "꼭 재배해보고 작물 선택"…초보 귀농인의 '스마트 팜' 도전기 [귀농귀촌애(愛)]
# 美, 마약 엄벌에도 복용률 늘어… 치료 통해 ‘중독의 고리’ 끊어야 [세계는 지금]
# 천연고무 최대생산국 태국, 수출 세계 1위 제품들은? [박종현의 아세안 코너]
# ‘K방산 수출 첨병’ FA-50 생산현장을 가다 [S 스토리]
# 스포츠 꽃피운 금융, 비인기 스포츠도 키운다
# "홀인원 축하금 준다고?" 필드 가기 전엔 이 카드
# "올해는 우리가 이긴다" 은행권, 프로야구 예·적금 출시 봇물
# 사상 최대 규모 ‘영월~양구 강원 내륙고속도’ 정부 첫 검토 착수
# 춘천 상중도(孤山) 발굴현장 공개…팽팽한 신경전
# 상업지 '춘천 명동입구' 주거지 '강원대 후문 먹자골목' 도내 최고 땅값 기록
# 강원 의료계 4일 부분파업…의료대란 오나?
# [퇴직연금을 깨워라]① "자산배분형 디딤돌펀드에 주목하라"
# [퇴직연금을 깨워라]②하반기 디폴트옵션 의무화…운용 성적표 공개
# 고용부·금감원 "퇴직연금 수익률 높이자…시장 경쟁 유도"
# "주가급등 후 하따까지"…이 '작전' 어디서 봤더라?[손엄지의 주식살롱]
# [단독]골퍼 A씨측 "라덕연 1년전 알게돼…라대표, 회사 사줄테니 관리해라"
# [작전이 판친다]임창정도 30억?…연예인·골퍼·의사 엮인 주가조작판
# [작전이 판친다] 세력 손털기 도와주는 '하따'…유튜버도 부채질
# 엉터리 아파트 추첨, "어? 5백 명이 빠졌네?"
# "형도 친부도 계모도 살해하고".. 자신도 극단 선택
# 지역특화비자 취업박람회.."외국인 300명 운집"
# 농촌 살리는 '활력 사업'..지속 추진은 과제
# [법정B컷]"전세사기요? 전 심부름만"…'빌라왕' 재판 판사의 분노
# SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]
# [그래?픽!]"저도 선생님 XX까요" 교권 추락…학생인권 때문이라고?
# [딥뉴스]리버버스는 '골병라인'을 구할 수 있을까
# [뉴스야?!] 전세 사기에 침묵하는 친文?
# [따져보니] '지역사회'가 뭐길래…'간호법' 대립 이유는?
# [단독] "빛·소음 때문에 짜증"…드라마 촬영장에 벽돌 투척한 주민 입건
# [포커스] '가짜뉴스' 몸살 앓는 지구…곳곳서 '전쟁'
# K-콘텐츠 점령한 ‘센 언니’들…유리 천장 뚫는 여성 서사의 진화[K-콘텐츠 뒤흔드는 걸크러쉬]
# 콘텐츠가 앞서간 알파걸의 시대 [K-콘텐츠 뒤흔드는 걸크러쉬]
# 조선의 걸 크러시와 K-컬처의 여전사들 [EDITOR's LETTER]
# 지지율로 본 尹정부 1년…최고 53%·최저 24%
# 한미, 포괄적 전략동맹 격상…확장억제 명문화[尹정부 개혁 1년]
# 주점·편의점 매출 150%↑…용산 상권 '특수'[용산시대 1년]
# "용산공원 개방 계기로 국민소통 강화되길"[용산시대 1년]
# [스페셜리포트]방송법, 5월 정국 뇌관으로…여야 '평행선' 속 거부권 행사 초미 관심
# [스페셜리포트]해외 공영방송 지배구조 사례 보니…"공영방송 정의 먼저"
# [사설] 방송법 개정, 여야 타협점 모색해야
# [ET뷰]방송법 부의 의결…윤 정부, 방송개혁 정국으로
# 인파로 가득한 '서울페스타 2023 명동 페스티벌' [TF사진관]
# 윤석열, '5박 7일간 국빈 방미' 마치고 귀국 [TF사진관]
# 서울 밤하늘에 펼쳐진 '화려한 드론 쇼' [TF사진관]
# '방배본동' 모자 쓴 전성수 서초구청장 [TF사진관]
# 가족모임 많은 5월, "외식비 부담돼요"…치킨·삼겹살 등 줄인상
# [남궁창성의 용산리포트] 16. 김건희 여사의 국빈방미 내조 외교
# 1분기 전국 아파트 거래 4명중 1명은 30대…2019년 이후 최대
# [최동열의 산썰(山說)] 6.산에서 어명을 받은 소나무들
# 비대면 진료 초진 허용, 서로 물러설 수 없는 이유 [보건의료 리포트]
# 바이오헬스 인재 양성 나선 정부, 빠른 변화와 소통 필요하다 [보건의료 리포트]
# 바이오헬스 성장 위한 정부 '선물보따리'…'오답노트' 반복하나 [보건의료 리포트]
# [보건의료 리포트] 길 잃은 ‘혁신형 제약기업’, 변신의 갈림길 서다
# 406개 판결문으로 본 ‘법원으로 간 학폭’
# 학교폭력 그 이후, ‘생기부 빨간 줄’보다 중요한 것들이 있다
# 드라마보다 더 잔인한 현실, ‘학폭’ 판결문 406개 분석 [금요시사회]
# [사설] 윤 대통령 방미 폄훼·옹호 넘어 여야가 머리 맞대야
# [박정호의 시시각각] 대중시인 김지하, 대중가수 조용필
# [윤석만의 시선] 교대 커트라인 하락, 교사 인기 하락 탓?
# [리셋 코리아] 한·미 사이버동맹 걸맞은 사이버 역량 갖춰야
# '97% 폭락' 美은행주에 뭉칫돈 … "포모 조급증 벗어나야"
# 겁없는 서학불개미…美 3배ETF에 1조
# 서학 불개미 어쩌나 …'밈주식' 베드배스, 결국 파산신청
# "SVB 감독 부실했다" 연준, 파산 책임 인정
# '안보·공급망·기술' 한·미 동맹 강화…기업 우려는 해소 못했다
# "워싱턴 선언은 제2 한·미 상호방위조약"
# 윤석열 대통령 "과학기술 협력은 한·미 동맹 새로운 영역"
# 윤석열 대통령 "핵무장, 1년내 가능하지만 NPT 존중 의무"
# [뉴스 즉설]시치미 뚝 송영길, 동문서답 이재명, '돈봉투 민주당' 뭐가 중한디?
# [픽&톡]"마스크 벗었다고 코로나 끝난 게 아니다"
# [뉴스 즉설]영길이 형 아웃, 7인회 해체, 이재명 퇴진… 돈봉투 후폭풍 어디까지
# [줌인] 충청 인구감소 가속화
# 전두환 손자 폭로는 인정 욕구와 가족 사랑의 발로 [+영상]
# “석열아, 먼저 손 내밀고 더 많이 들어라” [+영상]
# “尹, 술 마실 땐 ‘통 큰 사람’… 정치는 통 크게 못했다” [+영상]
# ‘길복순’ 전도연 “집에선 아이에게 쩔쩔매는 엄마예요”
# 핵협의체 신설·전략자산 전개 확대…실효성 제고는 과제
# [뉴스초점] 박진 외교부 장관 '워싱턴 선언' 채택 등 방미 성과 설명
# 12년 만의 국빈 방문…글로벌 포괄적 전략동맹 확대
# 적과 아군뿐인 ‘치명적’ 윤석열 외교…북·중·러 반발 거세진
무튼, 자수] 꽃보다 그녀 ‘세월을 수놓다’
# ‘우주 최초 수달 공무원’ 충주씨의 귀한 실물 사진 보러오세요
# [명품 컷] 비 오는 날의 수채화처럼 청아한 각원사의 봄풍경
# 미국은 ‘국익’, 한국은 ‘미익’ [정상회담특집①]
# “냉전 때와 닮아…과거로 가는 동맹” [정상회담특집②]
# 과거사 사죄 요구가 ‘무릎 꿇리는’ 일인가
# 윤 대통령, 대만을 “세계적 문제”로 언급해 중국의 반발 부르다
# "점심은 전통시장, 저녁은 맛길에서"... 부산 최대 번화가의 상생 프로젝트
# 천년고도 경주 성동시장... '라이브 커머스'로 2막 엽니다
# '삼겹살도 골라 먹는 재미' 고기먹방의 성지 아시나요
# "진료비 많이 주면 비대면도 오케이" 의사의 태세전환 이유
# 국회에 법안 4개 발의됐지만…여야 막론 약사·의사 의원들 반대
# 초진 허용두고 전세계도 갈렸다… 플랫폼 vs 의료계 피터지는 이유
# 24년 묵히다 다시 '시계 제로'…결국 中에도 밀린 韓 비대면 진료
# 尹 “韓 핵무장 마음 먹으면 1년 이내에도 가능” 하버드大 연설
# 7, 8일 방한 가닥 기시다, ‘과거사 사죄-반성’ 밝힐지 주목
# 김여정 “결정적 행동” 핵 선제타격 위협… 정부 “초조함 반영”
# 中 “尹 압도적 친미정책, 北中러 보복 직면하게 될것”
# 등골 휘는 5월 ‘가정의 달’…“어버이날·어린이날 부담”
# “나 빼고 다 해외 가네”…5월 연휴 내내 SNS엔 여행 사진이
# 매년 1억~4억명의 생명을 위협하는 ‘OOO’ 감염
# 야외활동 후 ‘사마귀’가 생겼다면? ‘이것’ 주의
# 민간 주도 혁신성장 궤도 올랐지만… 감세發 세수펑크 우려 '딜레마'[尹정부 1년 성과와 전망]
# 시장·기업 중심 정책 대전환… 수출·물가 등 지표 개선 '숙제'[尹정부 1년 성과와 전망]
# 민간 소비 살아났지만 저성장 탈출은 역부족[尹정부 1년 성과와 전망]
# 수차례 경고했는데…통학로서 아이를 또 잃었다
# 40년째 비탈길서 안전불감 작업…영도구도 단속 손놨다
# 어린이보호구역 등굣길 사망사고多...부산 교통사고만 매년 40여건
# 통학로 공사위험 꼼꼼하게 대비한 북구 행정 눈길
# [직설] 순방 마친 윤 대통령 앞에 현안 '산적'…간호법 '거부권' 여부 관심
# [굿모닝 마켓] "실적만 따라간다"…뉴욕 증시 일제히 상승 마감
# [김대호 박사의 오늘 기업·사람] 한화·대우조선·HD현대·인텔·아마존·삼성·SK·FRB·JP모건·PNC
# [어제장 오늘장] '형만 한 아우 없다'…코스피는 회복했지만 코스닥은 또 하락
# 구독하신 기자가 최근 48시간 이내 작성한 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# 기자별 기사를 자동 추천해 드립니다. 기자를 구독하시면 해당 기자의 최신 기사를 언론사별에서 확인할 수 있습니다.
# 구독한 연재 중 최근 48시간 이내 작성된 기사가 제공됩니다. 전체 구독 리스트는 구독 설정에서 확인하세요.
# 다양한 연재 기사를 자동 추천해 드립니다. 연재를 구독하시면 해당 연재의 최신 기사를 언론사별에서 확인할 수 있습니다.
# 기자·연재 카드 개선 안내
#
# 전체서비스
#
#
#
# 이용약관
# 개인정보처리방침
# 청소년 보호 책임자 : 이희만
# 서비스안내
#
# 각 언론사가 직접 콘텐츠를 편집합니다.

# %%
# 김나영
# p태그 데이터 모두 불러와 한글만 출력
for i in bs.find_all('p'):
    t = ' '.join(re.findall('[가-힣]+',i.text))
    print(t)
# Out:
# 배우 박은빈의 차기작인 드라마 무인도의 디바 촬영장에서 대 남성이 던진 벽돌에 스태프가 다치는 사건이 발생했다 서울 혜화경찰서는 한밤중 드라마 촬영 현장에 벽돌을 던진 혐의로 대 남성 씨를 불구속 입건
# 해마다 천만 명이 넘는 관광객이 찾는 여수에 새로운 관광단지가 조성 중입니다 가장 먼저 루지 테마파크가 문을 연 것을 시작으로 년까지 세계적인 브랜드 호텔과 대관람차도 추가로 들어설 예정입니다 여수와 고흥
방송 모아보기 클릭 시해당 방송사 뉴스를 볼 수 있으며 표시가 된 경우 생중계로시청 가능합니다
# 시대 우리는 무엇을 하고 살게 될까 나의 미래 계급은 다이어리
# 씨네멘터리 디자이너들이 꼽은 최고의 영화 포스터는
# 월드리포트 확장억제 성과 논란 말의 성찬 이 부른 후과
# 월드리포트 일본 남성 아이돌 대부 성착취 의혹 주류 언론 나서나
# 우크라 크름반도 유류시설 공격 인정 대반격 위한 준비
# 제로백 초 부터 럭셔리 까지 전기차 미래 뽐냈다 자동차
# 깡통 전세 전세보증보험 가입 안돼 이제 전세가율 까지만 가입 가능
# 이번 방미 긍정 평가 지지율 주만에 반등 리얼미터
# 내 돈 에 손댄 은행사람들 사라진 양심과 제식구 감싸기 관점
# 근로시간 시간 구로의 불편한 등대 리즈
# 냉면 비빔밥 만원으로 먹을 게 없는 야속한 시절
# 문 닫는 도봉고등학교 가보니 사라질 공간에 남은 흔적들
# 여성을 가둔 감옥을 부수자 마녀들과 춤추자
# 정통 워맨스 그런데 킬힐 못 벗은 언니들의 퀸메이커
# 피해자 보호 관점 실종된 나는 신이다 열풍
# 대에 별의 순간 양자경 트랜스젠더 연기로 세에 은곰상
# 기업 셀프 규제 중대재해 예방 미지수 경기도 근로자 재해실태 보고서
# 박 일 안보 경제 행보 찬사 혹평 윤 대통령 방미 성과와 평가
# 행안부 경기북부특별자치도 분도 검토가 먼저
# 경기도 내년 인구인지예산 편성 저출생 고령화 대응 나선다
# 이달 한일 한미일 연쇄회담 한미일 협력 심화 본격화
# 기시다 지지율 외교 성과 힘입어 개월 만에 대 회복
# 기시다 내달 초순 방한 가닥 식민지배 사죄 반성 언급할까
# 도대체 바닥은 어디일까 제주 아파트값 억씩 뚝뚝 김경민의 부동산
# 이러다 억 다시 찍으려나 마포 집값 슬금슬금 오른다 김경민의 부동산
# 용인 반도체 클러스터 수혜지 어디 이천 동탄 등 경기 남부 반세권 뜬다 김경민의 부동산
# 아파트 이름만 무려 글자 길고 어려운 아파트명 쉽게 바꾸자
# 오리고기 먹었더니 몸속 혈관에 변화가
# 혈압 관리에 주의 나트륨 많이 든 뜻밖 식품
# 체중 줄이고 혈당 천천히 낮게 올리는 음식은
# 민간 방송 공정성을 누가 심판할 수 있나
# 핵무장론 미련 못버리는 조선일보 과거에는 어땠나
# 부실 감사 논란에 한겨레 노조위원장 사퇴 파문
# 추경 가능성 생존 몸부림 앞에 강경한 서울시 의회
# 한 미 밀월 핵우산 들고 귀국
# 워싱턴 선언 나토 약정보다 실효적 한 미 방위 업그레이드
# 아메리칸 파이 방미 하이라이트
# 이르면 올해 거리에서 배달 로봇 보게 될 듯
# 윤 대통령 전세사기 매물 경매 중단 지시
# 조선 회화사의 공백 채울 걸작들의 귀환
# 매달 월급처럼 배당금이 또박또박 요즘 인기 모으는 월배당
# 노랜딩 가능성 날린 파산 다음 악재는 국제유가
# 미래에셋 어느 게 좋나요 목돈 마련 돕는 다양한 청년 펀드들
# 월 소득 만 원으로 주담대 먼저 갚으세요
# 미국서 환대받은 윤 대통령 한국 분위기는 달라
# 윤 대통령 마음 먹으면 년 이내 핵무장 가능하지만
# 윤 대통령 전체주의가 민주주의 위협 민주세력으로 위장
# 사실상 핵공유 는 성과 부풀리기 대통령실 용어 집착할 필요 없어
# 귀국에 여야 공방전 대국민 사기 외교 워싱턴선언 승리 방정식
# 워싱턴 선언 들고 온 한일 한미일 연쇄회담 예고
# 핵협의그룹 판 키우기 원하는 긴밀 협력 속도 내는 한일
# 에 악몽 이익보다 손실 클 것 사드 후 최악 우려
# 북한 차 핵실험 시 독자 핵무장으로 갈 수 밖에 윤상현 국민의힘 의원 직격 인터뷰 시사스페셜
# 윤 대통령 오늘 귀국 여야 방미 성과 극과 극 평가 시사스페셜
# 귀국 일 만에 압수수색 송영길 소환 빨라지나 시사스페셜
# 내일 윤리위 첫 회의 김재원 이전 징계 무게 시사스페셜
# 기획 한미 밀착에 경제보복 예고
# 경고음 커지는 수출 반도체 배터리 스마트폰도 고전 무역적자 굳어질수도
# 경고음 커지는 수출 방미로 냉랭해진 당분간 갈등 기류 불가피
# 윤석열 특수활동비 월 일 공개된다
# 주간 뉴스타파 일만의 승소 검사 윤석열 검증의 시간
# 확정판결 검찰예산 신속히 공개 안 하면 간접강제 신청한다
# 검찰의 방패를 뚫고 정보공개 최종 판결을 받아내기까지
# 발 주가폭락 사태 종목은 왜 타깃이 됐나
# 전문가 챗 답변이 의사보다 낫다
# 한국판 버핏과 점심 호 행사 정의선 박재욱과 방송인 노홍철
# 분기 아파트 매입 대 비율 사상 최고
# 경제혹한 대응 회생기업 는 진술과 보증 이 없다 옥석 가리는 게 최대 관건
# 경제혹한 대응 쌍용차 중공업도 시련 겪었다 회생 기업이 살아있단 걸 확인시켜주는 과정
# 경제혹한 대응 지금은 불황 초입 기업 회생 절차 타이밍 빨라야 희생 줄일 수 있어
# 경제혹한 대응 한번에 무너지거나 한번에 살아나거나 기업 구조조정은 속도가 생명
# 방미 이후 후속 조치 주력 간호법 대응 고심
# 제 의 한미방위조약 대국민 사기
# 준비 부족 지적한 박지원에 대통령실 반국가적 작태
# 핵 선제공격 위협 도발 카드 만지작
# 꼭 재배해보고 작물 선택 초보 귀농인의 스마트 팜 도전기 귀농귀촌애
# 마약 엄벌에도 복용률 늘어 치료 통해 중독의 고리 끊어야 세계는 지금
# 천연고무 최대생산국 태국 수출 세계 위 제품들은 박종현의 아세안 코너
# 방산 수출 첨병 생산현장을 가다 스토리
# 스포츠 꽃피운 금융 비인기 스포츠도 키운다
# 홀인원 축하금 준다고 필드 가기 전엔 이 카드
# 올해는 우리가 이긴다 은행권 프로야구 예 적금 출시 봇물
# 사상 최대 규모 영월 양구 강원 내륙고속도 정부 첫 검토 착수
# 춘천 상중도 발굴현장 공개 팽팽한 신경전
# 상업지 춘천 명동입구 주거지 강원대 후문 먹자골목 도내 최고 땅값 기록
# 강원 의료계 일 부분파업 의료대란 오나
# 퇴직연금을 깨워라 자산배분형 디딤돌펀드에 주목하라
# 퇴직연금을 깨워라 하반기 디폴트옵션 의무화 운용 성적표 공개
# 고용부 금감원 퇴직연금 수익률 높이자 시장 경쟁 유도
# 주가급등 후 하따까지 이 작전 어디서 봤더라 손엄지의 주식살롱
# 단독 골퍼 씨측 라덕연 년전 알게돼 라대표 회사 사줄테니 관리해라
# 작전이 판친다 임창정도 억 연예인 골퍼 의사 엮인 주가조작판
# 작전이 판친다 세력 손털기 도와주는 하따 유튜버도 부채질
# 엉터리 아파트 추첨 어 백 명이 빠졌네
# 형도 친부도 계모도 살해하고 자신도 극단 선택
# 지역특화비자 취업박람회 외국인 명 운집
# 농촌 살리는 활력 사업 지속 추진은 과제
# 법정 컷 전세사기요 전 심부름만 빌라왕 재판 판사의 분노
# 부산에 기항 비핵화 선언 과 모순 아니라고 안보열전
# 그래 픽 저도 선생님 까요 교권 추락 학생인권 때문이라고
# 딥뉴스 리버버스는 골병라인 을 구할 수 있을까
# 뉴스야 전세 사기에 침묵하는 친
# 따져보니 지역사회 가 뭐길래 간호법 대립 이유는
# 단독 빛 소음 때문에 짜증 드라마 촬영장에 벽돌 투척한 주민 입건
# 포커스 가짜뉴스 몸살 앓는 지구 곳곳서 전쟁
# 콘텐츠 점령한 센 언니 들 유리 천장 뚫는 여성 서사의 진화 콘텐츠 뒤흔드는 걸크러쉬
# 콘텐츠가 앞서간 알파걸의 시대 콘텐츠 뒤흔드는 걸크러쉬
# 조선의 걸 크러시와 컬처의 여전사들
# 지지율로 본 정부 년 최고 최저
# 한미 포괄적 전략동맹 격상 확장억제 명문화 정부 개혁 년
# 주점 편의점 매출 용산 상권 특수 용산시대 년
# 용산공원 개방 계기로 국민소통 강화되길 용산시대 년
# 스페셜리포트 방송법 월 정국 뇌관으로 여야 평행선 속 거부권 행사 초미 관심
# 스페셜리포트 해외 공영방송 지배구조 사례 보니 공영방송 정의 먼저
# 사설 방송법 개정 여야 타협점 모색해야
# 뷰 방송법 부의 의결 윤 정부 방송개혁 정국으로
# 인파로 가득한 서울페스타 명동 페스티벌 사진관
# 윤석열 박 일간 국빈 방미 마치고 귀국 사진관
# 서울 밤하늘에 펼쳐진 화려한 드론 쇼 사진관
# 방배본동 모자 쓴 전성수 서초구청장 사진관
# 가족모임 많은 월 외식비 부담돼요 치킨 삼겹살 등 줄인상
# 남궁창성의 용산리포트 김건희 여사의 국빈방미 내조 외교
# 분기 전국 아파트 거래 명중 명은 대 년 이후 최대
# 최동열의 산썰 산에서 어명을 받은 소나무들
# 비대면 진료 초진 허용 서로 물러설 수 없는 이유 보건의료 리포트
# 바이오헬스 인재 양성 나선 정부 빠른 변화와 소통 필요하다 보건의료 리포트
# 바이오헬스 성장 위한 정부 선물보따리 오답노트 반복하나 보건의료 리포트
# 보건의료 리포트 길 잃은 혁신형 제약기업 변신의 갈림길 서다
# 개 판결문으로 본 법원으로 간 학폭
# 학교폭력 그 이후 생기부 빨간 줄 보다 중요한 것들이 있다
# 드라마보다 더 잔인한 현실 학폭 판결문 개 분석 금요시사회
# 사설 윤 대통령 방미 폄훼 옹호 넘어 여야가 머리 맞대야
# 박정호의 시시각각 대중시인 김지하 대중가수 조용필
# 윤석만의 시선 교대 커트라인 하락 교사 인기 하락 탓
# 리셋 코리아 한 미 사이버동맹 걸맞은 사이버 역량 갖춰야
# 폭락 은행주에 뭉칫돈 포모 조급증 벗어나야
# 겁없는 서학불개미 배 에 조
# 서학 불개미 어쩌나 밈주식 베드배스 결국 파산신청
# 감독 부실했다 연준 파산 책임 인정
# 안보 공급망 기술 한 미 동맹 강화 기업 우려는 해소 못했다
# 워싱턴 선언은 제 한 미 상호방위조약
# 윤석열 대통령 과학기술 협력은 한 미 동맹 새로운 영역
# 윤석열 대통령 핵무장 년내 가능하지만 존중 의무
# 뉴스 즉설 시치미 뚝 송영길 동문서답 이재명 돈봉투 민주당 뭐가 중한디
# 픽 톡 마스크 벗었다고 코로나 끝난 게 아니다
# 뉴스 즉설 영길이 형 아웃 인회 해체 이재명 퇴진 돈봉투 후폭풍 어디까지
# 줌인 충청 인구감소 가속화
# 전두환 손자 폭로는 인정 욕구와 가족 사랑의 발로 영상
# 석열아 먼저 손 내밀고 더 많이 들어라 영상
# 술 마실 땐 통 큰 사람 정치는 통 크게 못했다 영상
# 길복순 전도연 집에선 아이에게 쩔쩔매는 엄마예요
# 핵협의체 신설 전략자산 전개 확대 실효성 제고는 과제
# 뉴스초점 박진 외교부 장관 워싱턴 선언 채택 등 방미 성과 설명
# 년 만의 국빈 방문 글로벌 포괄적 전략동맹 확대
# 적과 아군뿐인 치명적 윤석열 외교 북 중 러 반발 거세진다
# 년 뒤 불확실 미국 올인 없다 기밀문서 속 각국 생존외교술
# 김건희 여사 방미 단독 일정 개 갤러리 관람만 취재 허용
# 기업 이익도 한반도 미래도 못 챙긴 윤 대통령의 가치외교
# 강제추행 혐의 전 멤버 징역 개월 확정
# 대법 군 병원에서 수술받다 숨진 군인 보훈 대상자 인정 안돼
# 조명 소음 방해돼 드라마 촬영 현장에 벽돌 던진 대 입건
# 경기 오산 예식장 건물서 불 백명 대피
# 박광온 돈 봉투 의혹 회피 말아야 대의원제 폐지는 시기상조
# 도 폭염에 말 죽고 바다 온도 관측 이래 최고
# 베트남 명 중 명이 해요 혐오 발언 시의원 해명은 주말엔
# 안보 강화 경제 아쉬움 미국 의원들이 본 방미 성과 특파원 리포트
# 수단 무력충돌 격화에 정부 경찰까지 동원했다
# 극단적 선택 성범죄자 앱스타인 수장 세계 석학도 자택 초대 이력
# 연일 한미정상회담 깎아내리기 친미 악몽될 것
# 정부 워싱턴 선언 폄훼 중국 비판 불순한 의도
# 대통령실이 꼽은 국빈 방미 성과는
# 워싱턴 선언 가지 포인트 눈여겨봐야 매우 잘된 선언
# 대통령실 워싱턴선언 제 한미상호방위조약 방미 최고성과
# 국빈방미에 안보성과까지 높아진 대한민국 위상 실감
# 년 만의 국빈 방문 쏟아진 최초 기록들 한미 밀월
# 확장억제 강화 워싱턴 선언의 성과와 과제는 한미 밀월
# 첨단기술동맹 새 지평 억 달러 투자 유치 성과
# 한미 신 밀월 시대 열어젖힌 윤대통령 귀국 장도 올랐다
# 따뜻한 날씨에 늘어난 호흡기감염병 예방 관리수칙은
# 무심코 먹은 감자튀김이 정신건강을 위협한다
# 스마트폰 이 뇌종양 에 미치는 안타까운 영향
# 취침 시간 분 늦추면 고혈압 위험
# 전세사기 피해자 가 되기 위한 조건
# 국가 개입은 전세사기 로 제한 깡통전세는 어쩌나
# 통학로 공사위험 꼼꼼하게 대비한 북구 행정 눈길
# 직설 순방 마친 윤 대통령 앞에 현안 산적 간호법 거부권 여부 관심
# 굿모닝 마켓 실적만 따라간다 뉴욕 증시 일제히 상승 마감
# 김대호 박사의 오늘 기업 사람 한화 대우조선 현대 인텔 아마존 삼성 모건
# 어제장 오늘장 형만 한 아우 없다 코스피는 회복했지만 코스닥은 또 하락
# 구독하신 기자가 최근 시간 이내 작성한 기사가 제공됩니다 전체 구독 리스트는 구독 설정에서 확인하세요
# 기자별 기사를 자동 추천해 드립니다 기자를 구독하시면 해당 기자의 최신 기사를 언론사별에서 확인할 수 있습니다
# 구독한 연재 중 최근 시간 이내 작성된 기사가 제공됩니다 전체 구독 리스트는 구독 설정에서 확인하세요
# 다양한 연재 기사를 자동 추천해 드립니다 연재를 구독하시면 해당 연재의 최신 기사를 언론사별에서 확인할 수 있습니다
# 기자 연재 카드 개선 안내
# 전체서비스
# 이용약관 개인정보처리방침 청소년 보호 책임자 이희만 서비스안내 각 언론사가 직접 콘텐츠를 편집합니다

# %%
# requests
from bs4 import BeautifulSoup
import requests
import re
url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=105"
res = requests.get(url).text
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').text
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# '(하늘상태) 이번 예보기간은 대체로 흐린 날이 많겠으나, 8일(월)~11일(목)은 대체로 맑겠습니다.(기온) 이번 예보기간 아침 기온은 4~17도로 평년(최저기온 6~12도)과 비슷하거나 조금 높겠고, 낮 기온은 13~26도로 평년(최고기온 17~25도)과 비슷하거나 조금 낮겠습니다.(해상) 동해중부해상의 물결은 5일(금)~6일(토)은 1.0~3.0m로 높게 일겠습니다.(주말전망) 6일(토)~7일(일)은 대체로 흐리겠습니다. 아침 기온은 6~17도, 낮 기온은 13~22도가 되겠습니다. 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수시점과 구역이 변경될 가능성이 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.'

# %%
# urllib
import re
from bs4 import BeautifulSoup
import urllib.request
import urllib.parse

API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"
# 매개변수를 URL 인코딩합니다.
values = {
    'stnId': '109' # 서울 109, 강원도 105
}
params = urllib.parse.urlencode(values)
# 요청 전용 URL을 생성합니다.
url = API + "?" + params
print("url=", url)

res = urllib.request.urlopen(url)
soup = BeautifulSoup(res,'html.parser')
wf = soup.find('wf').string
text = ''.join(re.findall('[^A-Z0-9]?[0-9가-힣]+[^A-Z0-9]?',wf))
text
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=109
# '(강수) 4일(목)~7일(일)은 대체로 흐리겠고, 8일(월)~11일(목)은 맑겠습니다.(기온) 아침 기온은 4일(목)~7일(일)은 10~17도로 평년(최저기온 9~12도)보다 높겠고, 그 밖의 날은 8~13도로 평년과 비슷하겠습니다. 이번 예보기간 낮 기온은 18~25도로 평년(최고기온 20~24도)과 비슷하겠습니다.(해상) 서해중부해상의 물결은 4일(목)~5일(금)은 1.0~3.0m로 높게 일겠고, 그 밖의 날은 1.0~2.0m로 일겠습니다.(주말전망) 6일(토)과 7일(일)은 대체로 흐리겠습니다. 아침 기온은 10~16도, 낮 기온은 19~21도가 되겠습니다. 4일(목)부터 7일(일) 사이 기압골의 발달 정도와 이동 속도에 따라 강수 예보가 변경될 수 있으니, 앞으로 발표되는 최신 예보를 반드시 참고하기 바랍니다.'

# %% [markdown]
# ## 과제 2_0501
#
# "http://www.naver.com" 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %%
import urllib.request as rq
from bs4 import BeautifulSoup
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.prettify())

# %% [markdown]
# ## 과제 3_0501
# "http://www.naver.com" 사이트에서 span 태그에 연결된 문자 + 숫자를 불필요한 공백을 제거한 후 출력하세요.

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
texts = bs.find_all('span')

lt = ''
for t in texts:
    t = t.get_text()
    lt += t 
# print(lt)

lt = str(lt)
lt = re.findall('[^\W]+',lt) # 문자 + 숫자와 매치
lt = ' '.join(lt)
lt

# %% [markdown]
# Q. "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 아래와 같이 출력하세요.
# - 해당되는 조건에 맞게 모두 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한줄에 출력

# %%
# A.
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
texts
# Out:
# [<a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1b" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn"><span style="background-color: #0436c7">다운로드</span></a>,
#  <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">네이버를 시작페이지로</a>,
#  <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button"><span class="blind">한글 입력기</span><span class="ico_keyboard"></span></a>,
#  <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2"><span class="blind">자동완성 레이어</span><span class="ico_arr"></span></a>,
#  <a class="btn_set" data-clk="tca.like" href="#" id="NM_THEME_EDIT_SET" role="button">관심주제 설정</a>,
#  <a class="content_top" href="#wrap" id="NM_scroll_top_btn"><span class="blind">TOP</span></a>]

# %% [markdown]
# ## 과제 4_0501
#
# "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자 + 숫자를 아래와 같이 출력하세요.
#
# - 해당되는 조건에 맞게 모두 출력
# - 한글만 열방향으로 출력
# - 불필요한 공백을 제거한 후 한글만 한줄에 출력

# %%
# 답
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
print(texts)

# %%
# 답 
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
bs.text
texts = bs.find_all('a',id=True)
for t in texts:
    print(t,'\n')

# %%
#답
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
result = re.findall('[가-힣]+', str(texts))

for i in result:
    print(i)

# %%
#답
mport urllib.request as rq
import re
from bs4 import BeautifulSoup

url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
bs.text
texts = bs.find_all('a',id=True)
print(type(texts))
texts = [text.get_text() for text in texts]  # ResultSet에서 각 요소의 텍스트 부분을 추출하여 리스트로 변환

for text in texts:
    if re.search('[가-힣]+', text):
        print(text)

# %%
#답
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'html.parser')
texts = bs.find_all('a',id=True)
lt = ''
for t in texts:
    t = t.get_text()
    lt += t
# lt = str(lt)    
lt = re.findall('[가-힣]+', lt)
lt = ' '.join(lt)
print(lt)

# %%
#답
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
text = bs.find('div').get_text()

# %%
#답
from bs4 import BeautifulSoup
import urllib.request as rq
url = 'https://news.naver.com/'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.find_all('p'))

# %%
import urllib.request as rq
import re
url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
text = bs.find('div').get_text()
text
# Out:
# ' 뉴스스탠드 바로가기 주제별캐스트 바로가기 타임스퀘어 바로가기 쇼핑캐스트 바로가기 로그인 바로가기 '

# %%
from bs4 import BeautifulSoup
import urllib.request as rq
url = 'https://news.naver.com/'
html = rq.urlopen(url)
bs = BeautifulSoup(html, 'lxml')
print(bs.find_all('p'))
# Out:
# [<p class="cjs_d">국민 10명 중 8명은 사업주가 가짜 신분증에 속아 청소년에게 주류 등을 판매했다면 행정제재나 형사처벌 수위를 낮춰줘야 한다고 생각하는 것으로 나타났다. 국민권익위원회와 법제처는 오는 6월 ‘만 나이’ 제도 도입을 </p>, <p class="cjs_d">삼성전자와 LG전자가 글로벌 스마트홈 표준 '매터'(Matter)의 국내 적용·확산 사업에 나란히 참여한다. 정부 주도의 첫 매터 사업으로 8개 컨소시엄 간 치열한 수주전이 펼쳐진 가운데 삼성, LG는 각각 디바이스</p>, <p class="cjs_d">133번째 노동절을 맞아 민주노동조합총연맹(민주노총)과 한국노동조합총연맹(한국노총)이 서울 도심 곳곳에서 집회를 열었다. 시민들은 집회로 인한 소음 공해, 길거리 흡연, 극심한 교통정체 등으로 불편을 겪었다. 1일 </p>, <p class="cjs_d">“내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크</p>, <p class="cjs_d">1일 리움미술관에 따르면 지난달 27일 오후 1시께 미술관에서 전시 중인 마우리치오 카텔란의 작품 '코미디언'을 한 관람객이 훼손했습니다. '코미디언'은 바나나를 덕트 테이프로 벽에 붙여 놓은 작품입니다. 2019년</p>, <p class="cjs_d">일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상</p>, <p class="cjs_d">러시아가 우크라이나에 대규모 미사일 공습을 퍼부은 이튿날, 우크라이나는 러시아군 유류저장고를 파괴하며 반격에 나섰습니다. 우크라이나가 공언해 온 '봄철 대반격'이 임박했다는 관측이 나옵니다. #우크라이나 #러시아 #</p>, <p class="cjs_d"># 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택</p>, <p class="cjs_d">태영호 국민의힘 최고위원이 최근 윤석열 대통령이 미국 국빈 방문에서 보여준 의회 연설을 두고 연일 호평을 쏟아냈다. 북한 외교관 출신인 태 최고위원은 1일 MBC 라디오 '김종배의 시선집중'에 나와 '(방미 외교에서</p>, <p class="cjs_d">윤석열 대통령의 국정수행 지지도가 4주만에 반등에 성공하면서 34.5%를 기록했습니다. 여론조사기관 리얼미터가 지난 4월 24~28일 전국 18세 이상 유권자 2천5백7명을 대상으로 윤 대통령의 국정수행에 대해 물은</p>, <p class="cjs_d">내년에 적용될 최저임금 수준을 결정하기 위한 최저임금위원회 첫 전원회의가 2일 다시 열린다. 1일 고용노동부와 연합뉴스에 따르면 최저임금위는 2일 오후 3시 정부세종청사에서 제1차 전원회의를 개최한다. 당초 첫 회의</p>, <p class="cjs_d">올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다. 기상청은 현재 중립상태를 유지하고 있는 엘니뇨·라니냐 감시구역(열대태평양 남위5도~북위5도, 서경170도~서경120도 지역) 해수면 온도가 </p>, <p class="cjs_d">지난해 4월 '검수완박' 입법 당시 더불어민주당을 탈당하면서 '꼼수탈당'이란 비판을 받았던 민형배 의원이 1일 최근 민주당에 복당하면서 "이지메를 세게 당한 느낌이었다"고 말했다. 자신의 틸당이 민주당과 논의 끝에 </p>, <p class="cjs_d">정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설</p>, <p class="cjs_d">수많은 화제를 낳으며 끝난 윤석열 대통령의 5박7일간의 국빈 방미 일정 중 가장 반응이 뜨거웠던 건 '윤 대통령의 영어실력' 이었다. 윤 대통령의 귀국 이후에도 그에 대한 뜨거운 반응이 여전히 식지않은 채 회자되고 </p>, <p class="cjs_d">비트코인 가격이 4개월째 상승세를 이어가자 잠잠했던 '코인 대망론'이 또 다시 등장했다. 내년 말까지 비트코인이 10만 달러(1억3천410만원)에 육박할 것이란 것이다. 1일 블룸버그통신에 따르면 비트코인 가격은 3</p>, <p class="cjs_d">더불어민주당의 '2021년 전당대회 돈봉투 의혹'을 수사하는 검찰이 송영길 전 대표에 이어 당시 경선캠프 관계자들에 대한 강제수사에 나섰다. 돈봉투 살포 의혹뿐만 아니라 송 전 대표 개인 차원의 자금 살포 의혹으로 </p>, <p class="cjs_d">우리나라에서 세단의 대명사는 쏘나타였다. 특히 강남 지역에서 자주 보이는 수입차에 ‘강남 쏘나타’라는 별명을 붙이기도 했다. 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑</p>, <p class="cjs_d">생성형 인공지능(AI) '챗GPT'와 이를 접목한 서비스들이 성행하고 있다. 이에 데이터 보안 이슈와 더불어 거대 기업들의 독점 현상에 우려하는 목소리가 나오고 있다. 데이터브릭스가 명령어 추종 대형언어모델(LLM)</p>, <p class="cjs_d">향후 5년간 인공지능 영향으로 노동시장에 심각한 혼란이 야기될 것이라는 전망이 나왔다. 1일(현지시각) 미국 경제지 포천에 따르면, 세계경제포럼(WEF)은 보고서를 통해 인공지능과 같은 기술이 사무직 감소를 빠르게 </p>, <p class="cjs_d">올해 전주국제영화제에서 공개된 다큐멘터리 영화 ‘문재인입니다’(10일 개봉)는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 ‘입’을 빌린 대통령 문재인의 면모를 병치시킨다. 문 전 대통령의 정</p>, <p class="cjs_d">“여사님이 저희 매장을 방문해 저도 놀랐어요. 어리둥절했어요.” 서울 성동구 성수동에서 소규모로 수제화 매장('앤서니 수제화')을 운영 중인 A씨는 1일 중앙일보와의 통화에서 김건희 여사가 최근 자신의 가게에서 신발</p>, <p class="cjs_d">송 전 대표 측 “2일 오전 10시 서울중앙지방검찰청에 자진해 출두” 검찰, 현시점서 조사할 수 없다는 입장 '전당대회 돈봉투' 의혹 송영길 전 더불어민주당 대표가 지난달 24일 인천국제공항으로 귀국하고 있다. 영종</p>, <p class="cjs_d">겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식, 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다. 이우석 먹고놀기연구소 소장은 "횟집에서 회 뜨고 남은 생선으로 끓</p>, <p class="cjs_d">“비상연락망을 확인하고, 고위험군인 주변인에게 연락할 것.” 성폭력 피해자 연대 활동을 하면서 매해 3~4월과 10~11월에 강조하는 일이다. 봄과 가을에는 계절성 우울증 등 여러 요인이 겹쳐 자살 고위험군인 피해자</p>, <p class="cjs_d">기사내용 요약 AP 보도…"분란 혐의 등으로 3년형 선고" 코로나19가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 3년 만에 석방될 것이라고 AP통신이 30일(현지시간) 보도했다. 통신은 이 시민의 친척</p>, <p class="cjs_d">남성 위주 고프코어룩, 여성 관심 쑥 W컨셉서 살로몬 등 트레킹화 인기 여성 사이즈 일찌감치 품절되기도 에이블리 “고프코어 검색 늘어” 바람막이·카고바지 관심도 높아져 그동안 10·30대 남성들이 주로 관심을 가졌던</p>, <p class="cjs_d">미국 우주개발 스타트업이 물을 동력으로 쓰는 우주선을 개발해 우주 운송사업에 뛰어들겠다고 선언했다. 지구 저궤도 운송은 내년 말 첫 시험을 거쳐 2025년 상용 서비스를 시작한다는 야심찬 계획이다. 일론 머스크가 설< ...
#
#
#
#                                 방송 모아보기 클릭 시<br/>해당 방송사 뉴스를 볼 수 있으며<br/><span class="comp_ico_live">LIVE</span> 표시가 된 경우 생중계로<br/>시청 가능합니다.
#
#
#                     </p>, <p class="cjs_dept_desc">전두환 손자 폭로는 인정 욕구와 가족 사랑의 발로 [+영상]</p>, <p class="cjs_dept_desc">“석열아, 먼저 손 내밀고 더 많이 들어라” [+영상]</p>, <p class="cjs_dept_desc">“尹, 술 마실 땐 ‘통 큰 사람’… 정치는 통 크게 못했다” [+영상]</p>, <p class="cjs_dept_desc">‘길복순’ 전도연 “집에선 아이에게 쩔쩔매는 엄마예요”</p>, <p class="cjs_dept_desc">[법정B컷]"전세사기요? 전 심부름만"…'빌라왕' 재판 판사의 분노</p>, <p class="cjs_dept_desc">SSBN 부산에 기항…'비핵화 선언'과 모순 아니라고?[안보열전]</p>, <p class="cjs_dept_desc">[그래?픽!]"저도 선생님 XX까요" 교권 추락…학생인권 때문이라고?</p>, <p class="cjs_dept_desc">[딥뉴스]리버버스는 '골병라인'을 구할 수 있을까</p>, <p class="cjs_dept_desc">[뉴스야?!] 전세 사기에 침묵하는 친文?</p>, <p class="cjs_dept_desc">[따져보니] '지역사회'가 뭐길래…'간호법' 대립 이유는?</p>, <p class="cjs_dept_desc">[단독] "빛·소음 때문에 짜증"…드라마 촬영장에 벽돌 투척한 주민 입건</p>, <p class="cjs_dept_desc">[포커스] '가짜뉴스' 몸살 앓는 지구…곳곳서 '전쟁'</p>, <p class="cjs_dept_desc">"꼭 재배해보고 작물 선택"…초보 귀농인의 '스마트 팜' 도전기 [귀농귀촌애(愛)]</p>, <p class="cjs_dept_desc">美, 마약 엄벌에도 복용률 늘어… 치료 통해 ‘중독의 고리’ 끊어야 [세계는 지금]</p>, <p class="cjs_dept_desc">천연고무 최대생산국 태국, 수출 세계 1위 제품들은? [박종현의 아세안 코너]</p>, <p class="cjs_dept_desc">‘K방산 수출 첨병’ FA-50 생산현장을 가다 [S 스토리]</p>, <p class="cjs_dept_desc">외신 "美, 韓 핵무장론 달래기 시도…핵잠 기항 동북아 불안정 키울 것"</p>, <p class="cjs_dept_desc">워싱턴선언 '동상이몽'? 대통령실 "사실상 핵공유" 美당국자 "핵공유 아냐"</p>, <p class="cjs_dept_desc">尹대통령 '워싱턴선언' 후속행보, 한미 '핵공유' 온도차</p>, <p class="cjs_dept_desc">'자체 핵무장' 주장 태영호 "尹대통령에 영업왕 칭호까지 줘야겠다"</p>, <p class="cjs_dept_desc">[효자 車보험]㊤아픈 손가락은 옛말</p>, <p class="cjs_dept_desc">[효자 車보험]㊥돈 냄새 맡은 중소 손보사들</p>, <p class="cjs_dept_desc">[효자 車보험]㊦치솟는 한방 진료비 논란</p>, <p class="cjs_dept_desc">‘가을이 사건’ 가스라이팅 있었나… 친모 입에 쏠린 눈</p>, <p class="cjs_dept_desc">[단독] 사상자 10명 ‘에쓰오일 폭발 사고’ 외국인 CEO, 처벌 대상서 빠졌다</p>, <p class="cjs_dept_desc">성공작 평가 진주시 캐릭터 ‘하모’, 소극적 활용에 관심 ‘시들’</p>, <p class="cjs_dept_desc">궂은 날씨에도 청춘의 춤은 뜨거웠다… 데스팟크루, 부산 댄스 페스티벌 우승</p>, <p class="cjs_dept_desc">방미 이후 후속 조치 주력...尹, 간호법 대응 '고심'</p>, <p class="cjs_dept_desc">與 "제2의 한미방위조약" vs 野 "대국민 사기"</p>, <p class="cjs_dept_desc">'준비 부족' 지적한 박지원에 대통령실 "반국가적 작태"</p>, <p class="cjs_dept_desc">'핵 선제공격 위협' 北, 도발 카드 '만지작'</p>, <p class="cjs_dept_desc">Yoon fetes new nuclear accord as allies take harder line on NK</p>, <p class="cjs_dept_desc">Samsung eyeing 25% cut in chip production: analysts</p>, <p class="cjs_dept_desc">[Herald Interview] Winds of change in Korea's labor movement</p>, <p class="cjs_dept_desc">사상 최대 규모 ‘영월~양구 강원 내륙고속도’ 정부 첫 검토 착수</p>, <p class="cjs_dept_desc">춘천 상중도(孤山) 발굴현장 공개…팽팽한 신경전</p>, <p class="cjs_dept_desc">상업지 '춘천 명동입구' 주거지 '강원대 후문 먹자골목' 도내 최고 땅값 기록</p>, <p class="cjs_dept_desc">강원 의료계 4일 부분파업…의료대란 오나?</p>, <p class="cjs_dept_desc">尹, 이달 한일·한미일 연쇄회담…한미일 협력 심화 본격화</p>, <p class="cjs_dept_desc">기시다 지지율, 외교 성과 힘입어 8개월 만에 50%대 회복</p>, <p class="cjs_dept_desc">기시다, 내달 초순 방한 '가닥'…식민지배 사죄·반성 언급할까</p>, <p class="cjs_dept_desc">[벤처하는 의사들] “아동 발달장애 조기 진단과 치료, 집에서 하세요.”</p>, <p class="cjs_dept_desc">[벤처하는 의사들] “암 수술 길잡이 역할 하는 AI, 외과 미래 바꿀 것”</p>, <p class="cjs_dept_desc">[벤처하는 의사들] “귀한 자식 시집⋅장가 보내듯 신약기술 중개로 K-바이오 몸값 올릴 것”</p>, <p class="cjs_dept_desc">[벤처하는 의사들] “운동하세요”…척추·관절 환자에 내준 숙제, 스마트폰으로 검사</p>, <p class="cjs_dept_desc">갭투자 방치 vs 거주비 부담 완화... 전세제도 ‘양비론’ [스토리가 있는 뉴스]</p>, <p class="cjs_dept_desc">경기도내 노후교량 지적사항 ‘수백건’ 쏟아져</p>, <p class="cjs_dept_desc">“복리후생 꿈도 못꿔”…기업간 복지 양극화 심각 [5·1 근로자의 날]</p>, <p class="cjs_dept_desc">5박7일 안보·경제 행보… 與 ‘찬사’ 野 ‘혹평’ [윤 대통령 방미 성과와 평가]</p>, <p class="cjs_dept_desc">‘윤석열 특수활동비’ 6월 23일 공개된다</p>, <p class="cjs_dept_desc">[주간 뉴스타파] 1,243일만의 승소... '검사' 윤석열, 검증의 시간</p>, <p class="cjs_dept_desc">확정판결 검찰예산 신속히 공개 안 하면, '간접강제' 신청한다</p>, <p class="cjs_dept_desc">검찰의 방패를 뚫고, 정보공개 최종 판결을 받아내기까지</p>, <p class="cjs_dept_desc">“매달 월급처럼 배당금이 또박또박” 요즘 인기 모으는 월배당 ETF</p>, <p class="cjs_dept_desc">‘노랜딩’ 가능성 날린 SVB 파산, 다음 악재는 국제유가?</p>, <p class="cjs_dept_desc">“KB? 미래에셋? 어느 게 좋나요” 목돈 마련 돕는 다양한 청년 펀드들</p>, <p class="cjs_dept_desc">월 소득 4000만 원으로 주담대 먼저 갚으세요</p>, <p class="cjs_dept_desc">[르포]베일에 싸인 '라덕연 오른팔'… 집에도, BAR에도 없었다</p>, <p class="cjs_dept_desc">[단독]SG발 역풍 맞은 증권가... CFD '종목별 유통주식수' 따진다</p>, <p class="cjs_dept_desc"> ...
# <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
# </p>, <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
# <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
# </span>
# <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
# </p>]

# %%
import urllib.request as rq
import re

url = "http://www.naver.com"
html = rq.urlopen(url)
bs = BeautifulSoup(html,'lxml')
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html data-dark="false" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <meta content="NAVER" name="apple-mobile-web-app-title"/>
#   <meta content="index,nofollow" name="robots"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description"/>
#   <meta content="네이버" property="og:title"/>
#   <meta content="https://www.naver.com/" property="og:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="" name="twitter:title"/>
#   <meta content="https://www.naver.com/" name="twitter:url"/>
#   <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#   <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description"/>
#   <link href="https://pm.pstatic.net/dist/css/nmain.20230302.css" rel="stylesheet"/>
#   <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet"/>
#   <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#   <script>
#    window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})
#   </script>
#   <script>
#    var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#   </script>
#   <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#   </script>
#   <script>
#    window.nmain.gv = {  isLogin: false,
# useId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"LIVINGHOME_1","unit":"SU10571","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000186","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_2","tb":"LIVINGHOME_1","unit":"SU10572","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]}},
# svt: 20230501141932,
# };
#   </script>
#   <script>
#    window.nmain.newsstand = {
# rcode: '09560104',
# newsCastSubsInfo: '',
# newsStandSubsInfo: ''
# };
# window.etc = {  };
# window.svr = "<!--aweb11-->";
#   </script>
#   <script defer="defer" src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/external.2961eaa5.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/preload.5fe99fda.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/polyfill.f3c68d2d.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~notice~search~sidebar_notice.40da85e0.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/search.c0c3b1c5.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/vendors~more~nmain~sidebar_notice.7aad5e27.js?o=www" type="text/javascript">
#   </script>
#   <script crossorigin="anonymous" defer="defer" src="https://pm.pstatic.net/dist/js/nmain.e31af4db.js?o=www" type="text/javascript">
#   </script>
#   <style>
#    :root{color-scheme:light}#_nx_kbd .setkorhelp a{display:none}
#   </style>
#  </head>
#  <body>
#   <div id="u_skip">
#    <a href="#newsstand">
#     <span>
#      뉴스스탠드 바로가기
#     </span>
#    </a>
#    <a href="#themecast">
#     <span>
#      주제별캐스트 바로가기
#     </span>
#    </a>
#    <a href="#timesquare">
#     <span>
#      타임스퀘어 바로가기
#     </span>
#    </a>
#    <a href="#shopcast">
#     <span>
#      쇼핑캐스트 바로가기
#     </span>
#    </a>
#    <a href="#account">
#     <span>
#      로그인 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="wrap">
#    <style>
#     ._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;width:18px;height:18px;margin:16px 8px 0 0;background-position:-98px 0}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1syGnXOL._3dsvmZg2:before{background-position:-47px -85px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-position:-21px -89px}._1syGnXOL._2mcQEKCd:before{width:22px;height:22px;margin:14px 7px 0 0;background-position:-47px -63px}._1syGnXOL._36slsKuJ:before{width:21px;height:49px;margin:0 14px 0 0;background-position:0 -63px}._1syGnXOL._3qlJVWzR:before{width:24px;height:49px;margin:0 10px 0 0;background-position:-117px 0}._1syGnXOL._3VkgqBXB:before{width:26px;height:49px;margin:0 10px 0 0;background-position:-116px -54px}._1syGnXOL._3di88A4c{padding-right:12px;font-size:17px}._1syGnXOL._3di88A4c:before{content:none}._1syGnXOL ._19K4X1CD{text-decoration:underline}._2aeXMlrb{display:inline-block;position:relative;font-size:12px;height:49px;width:78px;text-decoration:none;color:#fff;font-weight:700;letter-spacing:-.5px;vertical-align:top}._2aeXMlrb span{text-align:center;margin:9px 0;height:31px;display:block;line-height:31px;border-radius:15px}._2aeXMlrb span:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._2aeXMlrb span:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._2aeXMlrb.BMgpjddw{font-size:11px;width:94px}._2aeXMlrb.BMgpjddw span:before{margin:9px 3px 0 0;width:17px;height:13px;background-position:-89px -63px}._3h-N8T9V{position:absolute;top:0;left:0;right:0;bottom:0;background:rgba(0,0,0,0)}._1KncATpM{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px;margin-top:14px;float:left;width:98px;height:21px;background-position:0 -21px}[data-useragent*="MSIE 8"] ._1KncATpM{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._1KncATpM._2v3uxv2x{background-position:0 0}._1KncATpM._1yl_Ow6o{background-position:0 -42px}._20PYt6lT{font-size:11px;height:49px;cursor:pointer;position:absolute;top:0;right:0;color:#666;opacity:.7}._20PYt6lT:after{width:15px;height:15px;margin-left:4px;background-position:-98px -33px;display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20220527@2x.png);background-repeat:no-repeat;background-size:141px 112px}[data-useragent*="MSIE 8"] ._20PYt6lT:after{background-image:url(https://static-whale.pstatic.net/main/sprite-20220527.png)}._20PYt6lT._39oMCV2N:after{background-position:-98px -18px}._20PYt6lT._3MOWOORv{color:#c3c2c2}._20PYt6lT._3MOWOORv:after{background-position:-80px -85px}._20PYt6lT._3wm5EzmJ{color:#fff}._20PYt6lT._3wm5EzmJ:after{background-position:-65px -85px}._1hiMWemA{height:49px}._1hiMWemA .tY_u8r23{position:relative;width:1130px;margin:0 auto}._1hiMWemA .tY_u8r23 a{text-decoration:none}._1hiMWemA._23U_6TM_{position:relative}._1hiMWemA._23U_6TM_:after{position:absolute;z-index:1;content:"";display:block;width:100%;height:1px;bottom:0;background-color:rgba(0,0,0,.050980392156862744)}
#    </style>
#    <div class="_1hiMWemA" data-clk-prefix="top" id="NM_TOP_BANNER" style="background-color: #fff7e1">
#     <div class="tY_u8r23">
#      <a class="_3h-N8T9V" data-clk="dropbanner1a" href="https://whale.naver.com/ko/details/security/&amp;wpid=RydDy7">
#      </a>
#      <span class="_1syGnXOL _3VkgqBXB" data-clk="dropbanner1a" style="padding-right: 20px; font-size: 17px; color: black">
#       <span>
#        매일 쓰는 브라우저 보안이 걱정된다면,
#       </span>
#       <strong>
#        안전하고 빠른 최신 브라우저 웨일로 업데이트 하세요.
#       </strong>
#      </span>
#      <a class="_2aeXMlrb BMgpjddw" data-clk="dropdownload1a" href="https://installer-whale.pstatic.net/downloads/banner/RydDy7/WhaleSetup.exe" id="NM_whale_download_btn">
#       <span style="background-color: #0436c7">
#        다운로드
#       </span>
#      </a>
#      <button class="_20PYt6lT _39oMCV2N" data-clk="dropclose1a" data-ui-cookie-exp-days="3" data-ui-cookie-key="NM_TOP_PROMOTION" data-ui-cookie-value="1" data-ui-hide-target="#NM_TOP_BANNER" type="button">
#       3일 동안 보지 않기
#      </button>
#     </div>
#    </div>
#    <div id="header" role="banner">
#     <div class="special_bg">
#      <div class="group_flex">
#       <div class="logo_area">
#        <h1 class="logo_default">
#         <a class="logo_naver" data-clk="top.logo" href="/">
#          <span class="blind">
#           네이버
#          </span>
#         </a>
#        </h1>
#       </div>
#       <div class="service_area">
#        <a class="link_set" data-clk="top.mkhome" href="https://help.naver.com/support/welcomePage/guide.help" id="NM_set_home_btn">
#         네이버를 시작페이지로
#        </a>
#        <i class="sa_bar">
#        </i>
#        <a class="link_jrnaver" data-clk="top.jrnaver" href="https://jr.naver.com">
#         <i class="ico_jrnaver">
#         </i>
#         <span class="blind">
#          쥬니어네이버
#         </span>
#        </a>
#        <a class="link_happybin" data-clk="top.happybean" href="https://happybean.naver.com">
#         <i class="ico_happybin">
#         </i>
#         <span class="blind">
#          해피빈
#         </span>
#        </a>
#       </div>
#       <div class="search_area" data-clk-prefix="sch" id="search">
#        <form action="https://search.naver.com/search.naver" id="sform" method="get" name="sform" role="search">
#         <fieldset>
#          <legend class="blind">
#           검색
#          </legend>
#          <input name="where" type="hidden" value="nexearch"/>
#          <input id="sm" name="sm" type="hidden" value="top_hty"/>
#          <input id="fbm" name="fbm" type="hidden" value="0"/>
#          <input disabled="disabled" id="acr" name="acr" type="hidden" value=""/>
#          <input disabled="disabled" id="acq" name="acq" type="hidden" value=""/>
#          <input disabled="disabled" id="qdt" name="qdt" type="hidden" value=""/>
#          <input id="ie" name="ie" type="hidden" value="utf8"/>
#          <input disabled="disabled" id="acir" name="acir" type="hidden" value=""/>
#          <input disabled="disabled" id="os" name="os" type="hidden" value=""/>
#          <input disabled="disabled" id="bid" name="bid" type="hidden" value=""/>
#          <input disabled="disabled" id="pkid" name="pkid" type="hidden" value=""/>
#          <input disabled="disabled" id="eid" name="eid" type="hidden" value=""/>
#          <input disabled="disabled" id="mra" name="mra" type="hidden" value=""/>
#          <div class="green_window" style="">
#           <!-- [AU] data-atcmp-element 에 해당하는 attribute를 추가해주세요. -->
#           <input accesskey="s" autocomplete="off" class="input_text" data-atcmp-element="" id="query" maxlength="255" name="query" onclick="document.getElementById('fbm').value=1;" placeholder="검색어를 입력해 주세요." style="ime-mode:active;" tabindex="1" title="검색어 입력" type="search" value=""/>
#          </div>
#          <button class="btn_submit" id="search_btn" onclick="window.nclick(this,'sch.action','','',event);" style="" tabindex="3" title="검색" type="submit">
#           <span class="blind">
#            검색
#           </span>
#           <span class="ico_search_submit">
#           </span>
#          </button>
#         </fieldset>
#        </form>
#        <!-- 한글입력기 -->
#        <a class="btn_keyboard" href="#" id="ke_kbd_btn" onclick="return false;" role="button">
#         <span class="blind">
#          한글 입력기
#         </span>
#         <span class="ico_keyboard">
#         </span>
#        </a>
#        <div id="_nx_kbd" style="display:none;">
#        </div>
#        <div class="autocomplete">
#         <!-- 자동완성 열린 경우 fold 클래스 추가, 딤드인 경우 dim 추가 -->
#         <a aria-pressed="false" class="btn_arw _btn_arw fold" data-atcmp-element="" href="#" id="nautocomplete" role="button" tabindex="2">
#          <span class="blind">
#           자동완성 레이어
#          </span>
#          <span class="ico_arr">
#          </span>
#         </a>
#        </div>
#        <!-- 자동완성레이어 -->
#        <div class="reatcmp" id="autoFrame" style="display: none;">
#         <!-- [AU] data-atcmp-element attribute를 추가해주세요. -->
#         <div class="ly_atcmp" data-atcmp-element="">
#          <div class="api_atcmp_wrap">
#           <!-- 최근검색어 -->
#           <!-- [AU] _recent_layer 클래스를 추가해주세요. -->
#           <div class="atcmp_fixer _recent_layer" style="display:none;">
#            <!-- [AU] _recent_header 클래스를 추가해주세요. -->
#            <div class="atcmp_header _recent_header">
#             <strong class="tit">
#              최근검색어
#             </strong>
#             <div class="option">
#              <!-- [AU] _delAll 클래스를 추가해주세요. -->
#              <a aria-pressed="false" class="item _delAll" href="#" role="button">
#               전체삭제
#              </a>
#             </div>
#            </div>
#            <div class="atcmp_container">
#             <!-- [AU] _recent 클래스를 추가해주세요. -->
#             <ul class="kwd_lst _recent">
#              <!-- 최근검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 <span>
#                  @txt@
#                 </span>
#                </span>
#               </a>
#               <span class="etc">
#                <em class="date">
#                 @date@.
#                </em>
#                <!-- [AU] _del 클래스를 추가해주세요. -->
#                <a aria-pressed="false" class="bt_item _del" href="#" role="button">
#                 <i class="imsc ico_del">
#                  삭제
#                 </i>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <!-- [D] 검색어 저장 꺼진 경우 atcmp_fixer에 type_off 추가 -->
#             <!-- [AU] _offMsg 클래스를 추가해주세요. -->
#             <div class="kwd_info kwd_off _offMsg" style="display: none;">
#              검색어 저장 기능이 꺼져 있습니다.
#              <br/>
#              <span class="kwd_dsc">
#               설정이 초기화 된다면
#               <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">
#                도움말
#               </a>
#               을 확인해주세요.
#              </span>
#             </div>
#             <!-- [D] 검색어 내역 없는 경우 atcmp_fixer에 type_off 추가 -->
#             <!-- [AU] _recentNone 클래스를 추가해주세요. -->
#             <div class="kwd_info kwd_none _recentNone" style="display: none;">
#              최근 검색어 내역이 없습니다.
#              <br/>
#              <span class="kwd_dsc">
#               설정이 초기화 된다면
#               <a class="kwd_help" data-clk="sly.help" href="https://help.naver.com/support/alias/search/word/word_29.naver" target="_blank">
#                도움말
#               </a>
#               을 확인해주세요.
#              </span>
#             </div>
#            </div>
#            <div class="atcmp_footer">
#             <span class="side_opt_area">
#              <span class="opt_item">
#               <a data-clk="sly.help" href="https://help.naver.com/support/service/main.help?serviceNo=605&amp;categoryNo=1991" target="_blank">
#                도움말
#               </a>
#              </span>
#             </span>
#             <span class="rside_opt_area">
#              <span class="opt_item">
#               <!-- [AU] _keywordOnOff 클래스를 추가해주세요. -->
#               <a class="close _keywordOnOff" href="#">
#                자동저장 끄기
#               </a>
#              </span>
#             </span>
#            </div>
#           </div>
#           <!-- 자동완성 -->
#           <!-- [AU] _atcmp_layer 클래스를 추가해주세요. -->
#           <div class="atcmp_fixer _atcmp_layer" style="display:none;">
#            <!-- [AU] _words 클래스를 추가해주세요. -->
#            <div class="atcmp_container _words">
#             <!-- 정답형 템플릿 : 로또당첨번호 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_3" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_lotto _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_3">
#              <a class="link_item" href="#">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_search">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @5@회 로또당첨번호
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  동행복권 제공
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc lotto">
#                 <em class="n@6@">
#                  @6@
#                 </em>
#                 <em class="n@7@">
#                  @7@
#                 </em>
#                 <em class="n@8@">
#                  @8@
#                 </em>
#                 <em class="n@9@">
#                  @9@
#                 </em>
#                 <em class="n@10@">
#                  @10@
#                 </em>
#                 <em class="n@11@">
#                  @11@
#                 </em>
#                 <em class="imsc_bf bonus n@12@">
#                  @12@
#                 </em>
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 환율 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_9" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_exchange _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_9">
#              <!-- [D] 상승 up, 하락 down 추가 -->
#              <a class="link_item @11@" href="#">
#               <!-- [D] 국가별 class 가나다순
# ZAR 남아프리카 공화국
# NPR 네팔
# NOK 노르웨이
# NZD 뉴질랜드
# TWD 대만
# DKK 덴마크
# RUB 러시아
# MOP 마카오
# MYR 말레이시아
# MXN 멕시코
# MNT 몽골
# USD 미국
# BHD 바레인
# BDT 방글라데시
# VND 베트남
# BRL 브라질
# SAR 사우디아라비아
# SEK 스웨덴
# CHF 스위스
# SGD 싱가포르
# AED 아랍에미리트
# GBP 영국
# EUR 유럽연합
# ILS 이스라엘
# EGP 이집트
# INR 인도
# IDR 인도네시아
# JPY 일본
# CNY 중국
# CZK 체코
# CLP 칠레
# KZT 카자흐스탄
# QAR 카타르
# CAD 캐나다
# KWD 쿠웨이트
# THB 태국
# TRY 터키
# PKR 파키스탄
# PLN 폴란드
# PHP 필리핀
# HUF 헝가리
# AUD 호주
# HKD 홍콩
# -->
#               <span class="common_ico_kwd">
#                <i class="imsc ico @12@">
#                 @14@
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                 <span class="sub">
#                  @currency@
#                 </span>
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  <i class="imsc ico_arr">
#                  </i>
#                  @8@(@9@%)
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 <em class="num">
#                  @6@
#                 </em>
#                 원
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 날씨(국내11, 해외12) -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_11" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_weather _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_11">
#              <!-- [D] 상승 up, 하락 down 추가 -->
#              <a class="link_item @12@" href="#">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_search">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  @7@, @message@
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 <!-- [D] 날씨별 class
# ico1 맑음(낮)
# ico2 맑음(밤)
# ico3 구름조금(낮)
# ico4 구름조금(밤)
# ico5 구름많음(낮)
# ico6 구름많음(밤)
# ico7 흐림
# ico8 약한비
# ico9 비
# ico10 강한비
# ico11 약한눈
# ico12 눈
# ico13 강한눈
# ico14 진눈깨비
# ico15 소나기
# ico16 안개
# ico17 소낙눈
# ico18 번개뇌우
# ico19 우박
# ico20 황사
# ico21 비또는눈
# ico22 가끔비
# ico23 가끔눈
# ico24 가끔비또는눈
# ico25 흐린후갬
# ico26 뇌우후갬
# ico27 비후갬
# ico28 눈후갬
# ico29 흐려져비
# ico30 흐려져눈
# -->
#                 <span class="ico_weather">
#                  <i class="imsc ico ico@iconNo@">
#                   @7@
#                  </i>
#                 </span>
#                 <em class="degree">
#                  @8@
#                  <sup class="celsius">
#                   °
#                  </sup>
#                 </em>
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- 정답형 템플릿 : 사이트 바로가기 -->
#             <!-- [AU] _answer 클래스를 추가해주세요. -->
#             <!-- [AU] data-template-type="answer_17" data-code="@code@" data-keyword="@1@" attribute를 추가해주세요. -->
#             <div class="atcmp_correct type_site _answer" data-code="@code@" data-keyword="@1@" data-template-type="answer_17">
#              <a class="link_item" href="@5@" target="_blank">
#               <span class="common_ico_kwd">
#                <i class="imsc ico_url">
#                </i>
#               </span>
#               <div class="dsc_area">
#                <span class="tit">
#                 @txt@
#                </span>
#                <span class="dsc">
#                 <span class="item">
#                  @5@
#                 </span>
#                </span>
#               </div>
#               <span class="etc_area">
#                <span class="etc">
#                 바로가기
#                </span>
#               </span>
#              </a>
#             </div>
#             <!-- [AU] _kwd_list 클래스를 추가해주세요. -->
#             <ul class="kwd_lst _kwd_list">
#              <!-- [AU] 자동완성 검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-rank="@rank@" data-template-type="suggestion" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="suggestion">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 @txt@
#                </span>
#               </a>
#               <span class="etc">
#                <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                 <i class="imsc ico_insert">
#                  추가
#                 </i>
#                </a>
#               </span>
#              </li>
#              <!-- [AU] 최근검색어 템플릿 -->
#              <!-- [AU] _item 클래스를 추가해주세요. -->
#              <!-- [AU] data-rank="@rank@" data-template-type="history" data-keyword="@in_txt@" attribute를 추가해주세요. -->
#              <li class="item has_correct _item" data-keyword="@in_txt@" data-rank="@rank@" data-template-type="history">
#               <a class="kwd" href="#">
#                <span class="fix">
#                 <span class="common_ico_kwd">
#                  <i class="imsc ico_search">
#                  </i>
#                 </span>
#                 @txt@
#                </span>
#               </a>
#               <span class="etc">
#                <!-- 최근검색어 있으면 날짜 표시 -->
#                <em class="date">
#                 @date@.
#                </em>
#                <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                 <i class="imsc ico_insert">
#                  추가
#                 </i>
#                </a>
#               </span>
#              </li>
#             </ul>
#             <!-- [AU] 문맥검색 템플릿 -->
#             <!-- [AU] _item 클래스를 추가해주세요. -->
#             <!-- [AU] data-rank="@rank@" data-template-type="intend" data-keyword="@transQuery@" attribute를 추가해주세요. -->
#             <li class="item has_correct _item" data-intend-rank="@intendRank@" data-keyword="@transQuery@" data-rank="@rank@" data-template-type="intend">
#              <a class="kwd" href="#">
#               <span class="fix">
#                <span class="common_ico_kwd">
#                 <i class="imsc ico_search">
#                 </i>
#                </span>
#                @query@
#                <span class="context">
#                 @intend@
#                </span>
#               </span>
#              </a>
#              <span class="etc">
#               <a aria-pressed="false" class="bt_item _add" href="#" role="button">
#                <i class="imsc ico_insert">
#                 추가
#                </i>
#               </a>
#              </span>
#             </li>
#             <!-- [D] 선거안내문구 -->
#             <!-- [AU] _alert 클래스를 추가해주세요. -->
#             <div class="atcmp_alert _alert">
#              <div class="dsc_election">
#               <p class="dsc">
#                <i class="imsc ico_election">
#                </i>
#                <span class="_alert_passage">
#                </span>
#               </p>
#               <span class="dsc_inner">
#                <!-- [AU] _alert_passage2 클래스를 추가해주세요. -->
#                <span class="_alert_passage2">
#                </span>
#                <!-- [AU] _alert_link 클래스를 추가해주세요. -->
#                <a class="link _alert_link" href="#" target="_blank">
#                 자세히보기
#                </a>
#               </span>
#              </div>
#             </div>
#             <!-- [AU] _plus 클래스를 추가해주세요. -->
#             <div class="atcmp_plus _plus">
#              <div class="dsc_plus">
#               <a class="link_dsc" data-clk="sug.cxhelp" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                관심사를 반영한 컨텍스트 자동완성
#                <i class="imsc ico_help">
#                 도움말
#                </i>
#               </a>
#              </div>
#              <div class="switch">
#               <!-- [D] 선택시 aria-pressed="ture/false" -->
#               <!-- [AU] _plus_btn 클래스를 추가해주세요. -->
#               <a aria-pressed="false" class="bt_switch active _plus_btn" href="#" role="button">
#                <i class="imsc ico_option">
#                 컨텍스트 자동완성
#                </i>
#               </a>
#              </div>
#              <!-- [AU] _plus_layer 클래스를 추가해주세요. -->
#              <div class="layer_plus _plus_layer">
#               <strong class="tit">
#                컨텍스트 자동완성
#               </strong>
#               <!-- [AU] _plus_layer_isloggedin 클래스를 추가해주세요. -->
#               <!-- [AU] style="display:none" 추가해주세요. -->
#               <div class="_plus_layer_isloggedin" style="display:none">
#                <p class="dsc">
#                 ON/OFF 설정은
#                 <br/>
#                 해당기기(브라우저)에 저장됩니다.
#                </p>
#                <div class="btn_area">
#                 <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                  자세히
#                 </a>
#                </div>
#               </div>
#               <!-- [AU] _plus_layer_isnotloggedin 클래스를 추가해주세요. -->
#               <!-- [AU] style="display:none" 추가해주세요. -->
#               <div class="_plus_layer_isnotloggedin" style="display:none">
#                <p class="dsc">
#                 <em class="txt">
#                  동일한 시간대/연령/남녀별
#                 </em>
#                 사용자 그룹의
#                 <br/>
#                 관심사에 맞춰 자동완성을 제공합니다.
#                </p>
#                <div class="btn_area">
#                 <a class="btn btn_login" data-clk="sug.cxlogin" href="https://nid.naver.com/nidlogin.login">
#                  로그인
#                 </a>
#                 <a class="btn btn_view" data-clk="sug.cxlink" href="https://help.naver.com/support/alias/search/word/word_16.naver" target="_blank">
#                  자세히
#                 </a>
#                </div>
#               </div>
#               <!-- [AU] _plus_layer_close 클래스를 추가해주세요. -->
#               <a class="btn_close _plus_layer_close" href="#" role="button">
#                <i class="imsc ico_close">
#                 컨텍스트 자동완성 레이어 닫기
#                </i>
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="atcmp_footer">
#             <span class="side_opt_area">
#              <span class="opt_item">
#               <a data-clk="sug.help" href="https://help.naver.com/alias/search/word/word_17.naver" target="_blank">
#                도움말
#               </a>
#              </span>
#              <span class="opt_item">
#               <a class="report" data-clk="sug.report" href="https://help.naver.com/support/contents/contents.help?serviceNo=605&amp;categoryNo=18215" target="_blank">
#                신고
#               </a>
#              </span>
#             </span>
#             <span class="rside_opt_area">
#              <span class="opt_item">
#               <!-- [AU] _suggestOnOff 클래스를 추가해주세요. -->
#               <a class="close _suggestOnOff" href="#">
#                자동완성 끄기
#               </a>
#              </span>
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="promotion11">
#      <a data-clk="top.ann" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_ros&amp;fbm=0&amp;ie=utf8&amp;query=%EA%B7%BC%EB%A1%9C%EC%9E%90%EC%9D%98+%EB%82%A0">
#       <img alt="근로자의 날" height="56" src="https://s.pstatic.net/static/www/mobile/edit/20230427/mobile_173626958161.png" width="225"/>
#      </a>
#     </div>
#     <div id="gnb" role="navigation">
#      <div class="gnb_inner" id="NM_FAVORITE">
#       <div class="group_nav">
#        <ul class="list_nav type_fix">
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.mail" href="https://mail.naver.com/">
#           <i class="ico_mail">
#           </i>
#           메일
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">
#           카페
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">
#           블로그
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">
#           지식iN
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/">
#           <span class="blind">
#            쇼핑
#           </span>
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home">
#           <span class="blind">
#            쇼핑LIVE
#           </span>
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">
#           Pay
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/">
#           <i class="ico_tv">
#           </i>
#           TV
#          </a>
#         </li>
#        </ul>
#        <ul class="list_nav NM_FAVORITE_LIST">
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">
#           사전
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.news" href="https://news.naver.com/">
#           뉴스
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.stock" href="https://finance.naver.com/">
#           증권
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.land" href="https://land.naver.com/">
#           부동산
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.map" href="https://map.naver.com/">
#           지도
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.vibe" href="https://vibe.naver.com/?from=naver_main&amp;utm_source=naver_main&amp;utm_medium=naver_main_pcweb&amp;utm_campaign=naver_main_redirect">
#           VIBE
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.book" href="https://search.shopping.naver.com/book/home">
#           도서
#          </a>
#         </li>
#         <li class="nav_item">
#          <a class="nav" data-clk="svc.webtoon" href="https://comic.naver.com/">
#           웹툰
#          </a>
#         </li>
#        </ul>
#        <ul class="list_nav type_empty" style="display: none;">
#        </ul>
#        <a class="btn_more" data-clk="svc.more" href="#" role="button">
#         더보기
#        </a>
#        <div class="ly_btn_area">
#         <a class="btn NM_FAVORITE_ALL" data-clk="map.svcmore" href="more.html">
#          서비스 전체보기
#         </a>
#         <a class="btn btn_set" data-clk="map.edit" href="#" role="button">
#          메뉴설정
#         </a>
#         <a class="btn btn_reset" data-clk="edt.reset" href="#" role="button">
#          초기화
#         </a>
#         <a class="btn btn_save" data-clk="edt.save" href="#" role="button">
#          저장
#         </a>
#        </div>
#       </div>
#       <div class="group_weather" id="NM_WEATHER">
#        <div>
#         <a class="weather_area ico_w01" data-clk="squ.weat" href="https://weather.naver.com/today/09560104?cpName=KMA">
#          <div class="current_box">
#           <strong aria-label="현재기온" class="current">
#            19.2°
#           </strong>
#           <strong class="state">
#            맑음
#           </strong>
#          </div>
#          <div class="degree_box">
#           <span aria-label="최저기온" class="min">
#            9.0°
#           </span>
#           <span aria-label="최고기온" class="max">
#            21.0°
#           </span>
#          </div>
#          <span class="location">
#           영등포동3가
#          </span>
#         </a>
#        </div>
#        <div>
#         <a class="air_area" data-clk="squ.dust" href="https://weather.naver.com/today/09560104?cpName=KMA">
#          <ul class="list_air">
#           <li class="air_item">
#            미세
#            <strong class="state state_good">
#             좋음
#            </strong>
#           </li>
#           <li class="air_item">
#            초미세
#            <strong class="state state_good">
#             좋음
#            </strong>
#           </li>
#          </ul>
#          <span class="location">
#           영등포동3가
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="ly_service">
#       <div class="group_service NM_FAVORITE_ALL_LY">
#       </div>
#       <div class="group_service NM_FAVORITE_EDIT_LY" style="display: none;">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="container" role="main">
#     <div style="position:relative;width:1130px;margin:0 auto;z-index:11">
#      <div id="da_top">
#      </div>
#      <div id="da_expwide">
#      </div>
#     </div>
#     <div class="column_left" id="NM_INT_LEFT">
#      <div id="veta_top">
#       <div id="veta_top_inner" style="height:135px">
#       </div>
#       <span class="veta_bd_t">
#       </span>
#       <span class="veta_bd_b">
#       </span>
#       <span class="veta_bd_l">
#       </span>
#       <span class="veta_bd_r">
#       </span>
#      </div>
#      <div class="sc_newscast" id="newsstand">
#       <h2 class="blind">
#        뉴스스탠드
#       </h2>
#       <div class="group_issue" data-clk-prefix="ncy" id="NM_NEWSSTAND_HEADER">
#        <div class="issue_area">
#         <a class="link_media" data-clk="newsflash" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y">
#          연합뉴스
#         </a>
#         <div class="list_issue" data-nm-ui="rolling" id="NM_ONELINE_ROLLING">
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914317">
#            경찰 '전세사기=조직범죄' 확대 적용 검토
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914142">
#            尹, 이달 한일·한미일 연쇄회담…한미일 협력 심화 본격화
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914341">
#            송영길측 "내일 자진 출두"…검찰 "조사 불가"
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914259">
#            '돈봉투 녹음' 이정근 측 "검찰이 언론에 녹음파일 흘려"
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914139">
#            與윤리위, '설화' 김재원·태영호 징계 절차 개시
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914141">
#            무역적자 터널 끝 보이나…향후 '반도체·對中 수출' 관건
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914136">
#            종로학원 "2025학년도 SKY 문과→이과 교차지원 사실상 어려워"
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914138">
#            엠폭스 환자 연일 늘지만…국민 40% "정확히 아는 정보 없어"
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013914135">
#            영장실질심사 앞둔 건설노조 간부 법원 앞서 분신…의식 없어
#           </a>
#          </div>
#          <div>
#           <a class="issue" data-clk="quickarticle" href="https://news.naver.com/main/list.naver?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0013913828">
#            해인사 등 65개 사찰 4일부터 무료입장…문화재관람료 국비지원
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="direct_area">
#         <a class="link_news" data-clk="newshome" href="http://news.naver.com/">
#          뉴스홈
#         </a>
#         <a class="link_direct" data-clk="entertainment" href="http://entertain.naver.com/home">
#          연예
#         </a>
#         <a class="link_direct" data-clk="sports" href="http://sports.news.naver.com/">
#          스포츠
#         </a>
#         <a class="link_direct" data-clk="economy" href="http://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">
#          경제
#         </a>
#        </div>
#       </div>
#       <div class="group_title" data-clk-prefix="nsd" id="NM_NEWSSTAND_TITLE">
#        <a class="link_newsstand" data-clk="title" href="http://newsstand.naver.com/" target="_blank">
#         뉴스스탠드
#        </a>
#        <div class="sort_area" id="NM_NEWSSTAND_data_buttons" role="tablist">
#         <a aria-controls="NM_NEWSSTAND_MY_LIST" aria-selected="false" class="btn_sort" data-clk="my" data-type="my" href="#" role="tab">
#          구독한 언론사
#         </a>
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_sort" data-clk="all" data-type="all" href="#" role="tab">
#          전체언론사
#         </a>
#        </div>
#        <div class="set_area" id="NM_NEWSSTAND_view_buttons" role="tablist">
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_LIST" aria-selected="false" class="btn_set" data-clk="articleview" data-type="list" href="#" role="tab">
#          <i class="ico_list">
#           <span class="blind">
#            리스트형
#           </span>
#          </i>
#         </a>
#         <a aria-controls="NM_NEWSSTAND_DEFAULT_THUMB" aria-selected="true" class="btn_set" data-clk="pressview" data-type="thumb" href="#" role="tab">
#          <i class="ico_tile">
#           <span class="blind">
#            썸네일형
#           </span>
#          </i>
#         </a>
#         <a class="btn_set" data-clk="set" href="http://newsstand.naver.com/config.html" target="_blank">
#          <i class="ico_set">
#           <span class="blind">
#            설정
#           </span>
#          </i>
#         </a>
#        </div>
#       </div>
#       <div id="NM_NEWSSTAND_VIEW_CONTAINER" style="position:relative">
#        <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_LIST" role="tabpanel" style="display:none">
#         <a class="pm_btn_prev_l _NM_NEWSSTAND_LIST_prev_btn" data-clk-custom="prev" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            이전
#           </span>
#          </i>
#         </a>
#         <a class="pm_btn_next_l _NM_NEWSSTAND_LIST_next_btn" data-clk-custom="next" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            다음
#           </span>
#          </i>
#         </a>
#         <div class="list_view">
#          <div class="option_area">
#           <div class="list_option_wrap">
#            <ul class="list_option">
#             <li class="option_item" data-cateid="ct2">
#              <a class="option" data-clk="daei" href="#">
#               종합/경제
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct3">
#              <a class="option" data-clk="dtvcom" href="#">
#               방송/통신
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct4">
#              <a class="option" data-clk="dit" href="#">
#               IT
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct5">
#              <a class="option" data-clk="deng" href="#">
#               영자지
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct6">
#              <a class="option" data-clk="dsporent" href="#">
#               스포츠/연예
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct7">
#              <a class="option" data-clk="dmagtec" href="#">
#               매거진/전문지
#              </a>
#             </li>
#             <li class="option_item" data-cateid="ct8">
#              <a class="option" data-clk="dloc" href="#">
#               지역
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="_NM_NEWSSTAND_ARTICLE_CONTAINER" data-clk-sub="*a">
#          </div>
#         </div>
#         <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_invalid" data-clk-sub="*a" style="display:none">
#          <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">
#           <i class="ico_close">
#           </i>
#           <span class="blind">
#            닫기
#           </span>
#          </a>
#          <p class="popup_msg">
#           해당 언론사 사정으로 접근이 제한됩니다.
#          </p>
#          <div class="popup_btn">
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" href="#" role="button">
#            확인
#           </a>
#          </div>
#         </div>
#         <div class="ly_popup NM_NEWSSTAND_POPUP NM_NEWSSTAND_undescribe_confirm" data-clk-sub="*a" style="display:none">
#          <a class="btn_close NM_NEWSSTAND_POPUP_CLOSE" data-clk="usclose" href="#" role="button">
#           <i class="ico_close">
#           </i>
#           <span class="blind">
#            닫기
#           </span>
#          </a>
#          <p class="popup_msg">
#           <strong class="NM_NEWSSTAND_POPUP_PNAME">
#           </strong>
#           을(를)
#           <br/>
#           구독해지 하시겠습니까?
#          </p>
#          <div class="popup_btn">
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CONFIRM" data-clk="usdone" href="#" role="button">
#            확인
#           </a>
#           <a class="btn_confirm NM_NEWSSTAND_POPUP_CLOSE" data-clk="uscancel" href="#" role="button">
#            취소
#           </a>
#          </div>
#         </div>
#         <div class="ly_toast NM_NEWSSTAND_TOAST" style="display:none">
#          <p class="toast_msg">
#           구독한 언론사에 추가되었습니다.
#          </p>
#         </div>
#        </div>
#        <div class="group_news" data-clk-prefix="nsd_all" id="NM_NEWSSTAND_DEFAULT_THUMB" role="tabpanel" style="display:block">
#         <a class="pm_btn_prev_l _NM_UI_PAGE_PREV" data-clk-custom="prev" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            이전
#           </span>
#          </i>
#         </a>
#         <a class="pm_btn_next_l _NM_UI_PAGE_NEXT" data-clk-custom="next" href="#" role="button">
#          <i class="ico_btn">
#           <span class="blind">
#            다음
#           </span>
#          </i>
#         </a>
#         <div class="_NM_UI_PAGE_CONTAINER" data-clk-sub="*p" style="height:100%;overflow:hidden">
#          <div style="width: 750px; float: left;">
#           <div class="tile_view">
#            <div class="frame_area">
#             <i class="line to_right1">
#             </i>
#             <i class="line to_right2">
#             </i>
#             <i class="line to_right3">
#             </i>
#             <i class="line to_bottom1">
#             </i>
# ...
#                 VIEW H
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_c65f3f98-e4c3-11ed-9574-4329b1951270">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=35837240&amp;memberNo=38890623" target="_blank">
#              <img alt="람보르기니, 창립 60주년 기념 ‘우라칸 스페셜 에디션’ 출시" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230427_1095%2Fupload_1682576500238N7dpn.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont2" href="https://post.naver.com/viewer/postView.naver?volumeNo=35837240&amp;memberNo=38890623" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               람보르기니, 창립 60주년 기념 ‘우라칸 스페셜 에디션’ 출시
#              </strong>
#              <p class="desc">
#               람보르기니 우라칸의 스페셜 에디션 3종이 출시됐다. 창립 60주년 기념 모델로 차량 넘버가 새겨진 카본 파이버 플레이트와 기념 로고 등이 적용된다.최근 람보르기니는 창립 60주년을 맞아 밀라노 디자인 위크를 통해 우라칸의 스페셜 한정판 에디션 3종을 출시했다. 해당 모델은 우라칸 STO(Huracán STO), 우라칸 테크니카&amp;#
#              </p>
#              <div class="source_box">
#               <span class="date">
#                6일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 모터프레스
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_7cbd7ebb-e3e6-11ed-9177-0d7279211469">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont3" href="https://post.naver.com/viewer/postView.naver?volumeNo=35842233&amp;memberNo=11959051" target="_blank">
#              <img alt="BMW 슈퍼 SUV 'XM', 최고급 알칸타라로 럭셔리한 실내 분위기 완성" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230426_1095%2Fupload_1682481486429PcPAf.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont3" href="https://post.naver.com/viewer/postView.naver?volumeNo=35842233&amp;memberNo=11959051" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               BMW 슈퍼 SUV 'XM', 최고급 알칸타라로 럭셔리한 실내 분위기 완성
#              </strong>
#              <p class="desc">
#               [Motoroid / New Car] BMW XM BMW 슈퍼 SUV 'XM'의 인테리어 소재로 동명의 자사 소재 '알칸타라'가 채택됐다. BMW XM은 BMW M이 지난 1978년 출시한 전설적인 스포츠 쿠페 M1 이후에 처음으로 선보이는 M 전용 모델이자 M 하이 퍼포먼스 라인업 최초의 전기화 모델이다. 한층 강조된 BMW
#              </p>
#              <div class="source_box">
#               <span class="date">
#                5일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 모터로이드
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_7cbd7ebc-e3e6-11ed-9177-eb508e0b6d00">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont4" href="https://post.naver.com/viewer/postView.naver?volumeNo=35843818&amp;memberNo=39711695" target="_blank">
#              <img alt="롤스로이스 vs 벤틀리, 한정판 어떤 차로 살까?" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230426_1095%2Fupload_1682481515594sWue8.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont4" href="https://post.naver.com/viewer/postView.naver?volumeNo=35843818&amp;memberNo=39711695" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               롤스로이스 vs 벤틀리, 한정판 어떤 차로 살까?
#              </strong>
#              <p class="desc">
#               롤스로이스, 벤틀리 등의 럭셔리 브랜드는 자동차 시장에서도 아주 유니크한 존재로 손꼽힙니다. 브랜드의 명성은 모두가 알고 있지만, 비싼 가격에 엄두를 좀처럼 낼 수 없는 차니까요. 게다가 돈이 있어도 많은 시간을 기다려야 합니다. 숙련된 장인의 손끝에서 완성되는 수제작 부품이 많아서죠. 그래서 롤스로이스, 벤틀리 등의 브랜드는 주문형 제작의 끝판왕이나 다름
#              </p>
#              <div class="source_box">
#               <span class="date">
#                5일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 KB차차차
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#            <li class="theme_item" data-da-position="true" data-gdid="CAS_6e94fe9a-e1bd-11ed-9574-5d31fc877a2f">
#             <a class="theme_thumb" data-clk="tcc_aut.list12cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=35821117&amp;memberNo=40524516" target="_blank">
#              <img alt="황색신호의 시간이 애매하면? 이렇게 하세요" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F20230423_1095%2Fupload_16822439416919dxhP.jpg%22&amp;type=nf340_228" height="114" onerror="this.outerHTML='&lt;span class=\'pm_noimg\'&gt;&lt;span class=\'noimg_text\'&gt;이미지 준비중&lt;/span&gt;&lt;/span&gt;'" width="170"/>
#              <span class="thumb_bd">
#              </span>
#             </a>
#             <a class="theme_info" data-clk="tcc_aut.list12cont5" href="https://post.naver.com/viewer/postView.naver?volumeNo=35821117&amp;memberNo=40524516" target="_blank">
#              <em class="theme_category">
#               자동차
#              </em>
#              <strong class="title elss">
#               황색신호의 시간이 애매하면? 이렇게 하세요
#              </strong>
#              <p class="desc">
#               차량이 교차로에 진입할 때 신호가 황색으로 바뀌면 운전자는 빠르게 상황 판단을 해서 교차로를 통과할지, 멈출지 선택해야 한다. 그런데 이때 황색신호가 켜져 있는 시간에 따라 '딜레마 존'과 '옵션 존'이 발생한다. 이번 포스트는 '딜레마 존'과 '옵션 존'에 대해서 알아보려 한다. '딜레마 존
#              </p>
#              <div class="source_box">
#               <span class="date">
#                1주일 전
#               </span>
#               <span class="source">
#                <span class="source_inner">
#                 카피엔스
#                </span>
#               </span>
#              </div>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="btn_more_wrap">
#          <button class="btn_more" data-clk-custom="tcc_aut.more" data-next-page="2" type="button">
#           <i class="ico_more">
#           </i>
#           새로운 글 더보기
#          </button>
#         </div>
#         <div class="NM_THEME_META" data-panel-code="CARGAME" data-parent-code="" style="display: none">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="column_right" id="NM_INT_RIGHT">
#      <div class="column_fix_wrap">
#       <div id="da_brand">
#       </div>
#       <div class="sc_login" id="account">
#        <h2 class="blind">
#         Sign in
#        </h2>
#        <p class="login_msg">
#         Connect with people
#        </p>
#        <a class="link_login" data-clk="log_off.login" href="https://nid.naver.com/nidlogin.login?mode=form&amp;url=https%3A%2F%2Fwww.naver.com">
#         <i class="ico_naver">
#          <span class="blind">
#           NAVER
#          </span>
#         </i>
#         Sign in
#        </a>
#        <div class="sub_area">
#         <div class="look_box">
#          <a class="link_look" data-clk="log_off.searchid" href="https://nid.naver.com/user/help.nhn?todo=idinquiry">
#           Forgot Username
#          </a>
#          <a class="link_look" data-clk="log_off.searchpass" href="https://nid.naver.com/nidreminder.form">
#           Password
#          </a>
#         </div>
#         <a class="link_join" data-clk="log_off.registration" href="https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com">
#          Sign up
#         </a>
#        </div>
#       </div>
#       <div class="sc_timesquare" id="timesquare">
#        <h2 class="blind">
#         타임스퀘어
#        </h2>
#        <div class="card_wrap">
#         <div class="card_nav">
#          <a class="btn_nav btn_prev" data-clk="squ.pre" href="#" role="button">
#           <span class="blind">
#            이전
#           </span>
#          </a>
#          <a class="btn_nav btn_next" data-clk="squ.next" href="#" role="button">
#           <span class="blind">
#            다음
#           </span>
#          </a>
#         </div>
#         <div id="NM_TS_ROLLING_WRAP" style="height: 100%;">
#          <div>
#           <a class="card_news" data-clk="squ.line3" href="https://search.naver.com/search.naver?sm=top_hty&amp;fbm=0&amp;ie=utf8&amp;query=%EC%BD%94%EB%A1%9C%EB%82%9819">
#            <i class="news_badge">
#             이슈
#            </i>
#            <span class="news">
#             코로나바이러스감염증-19 현황
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#        <!-- EMPTY -->
#       </div>
#       <div id="veta_branding">
#        <span class="blind">
#         <script id="veta_service_check">
#         </script>
#        </span>
#        <div id="veta_branding_inner" style="width:350px;height:200px">
#        </div>
#        <span class="veta_bd_t">
#        </span>
#        <span class="veta_bd_b">
#        </span>
#        <span class="veta_bd_l">
#        </span>
#        <span class="veta_bd_r">
#        </span>
#       </div>
#       <div class="sc_shopcast" id="shopcast">
#        <iframe data-iframe-src="/shoppingbox/shoppingboxnew/main.nhn?mode=plusdeal&amp;domain=N" frameborder="0" height="1809" id="shopcast_iframe" marginheight="0" marginwidth="0" scrolling="no" title="쇼핑캐스트" width="350">
#        </iframe>
#       </div>
#      </div>
#     </div>
#     <a class="content_top" href="#wrap" id="NM_scroll_top_btn">
#      <span class="blind">
#       TOP
#      </span>
#     </a>
#     <button aria-pressed="false" class="btn_theme" id="NM_darkmode_btn" role="button" type="button">
#      <span class="blind">
#       라이트 모드로 보기
#      </span>
#     </button>
#    </div>
#    <div id="footer" role="contentinfo">
#     <div class="footer_inner">
#      <div class="banner_area" id="NM-FOOTER-AD">
#       <div class="da_box_wrap">
#        <div id="da_public_left">
#        </div>
#        <div id="da_public_right">
#        </div>
#        <div id="veta_time2">
#        </div>
#       </div>
#      </div>
#      <div class="notice_area" data-clk-prefix="ntc">
#       <div class="notice_box">
#        <h3 class="title">
#         <a href="https://www.naver.com/NOTICE">
#          공지사항
#         </a>
#        </h3>
#        <!-- EMPTY -->
#       </div>
#       <a class="link_all" data-clk="svcmap" href="more.html">
#        서비스 전체보기
#       </a>
#      </div>
#      <div class="aside_area">
#       <div class="partner_box_wrap">
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Creators
#         </h3>
#         <a class="link_partner" data-clk="creator" href="https://www.navercorp.com/service/creators">
#          크리에이터
#         </a>
#         <a class="link_partner" data-clk="smbusiness" href="https://www.navercorp.com/service/business">
#          스몰비즈니스
#         </a>
#        </div>
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Partners
#         </h3>
#         <a class="link_partner" data-clk="sme" href="https://campaign.naver.com/smefullcare/online/">
#          SME 풀케어 시스템
#         </a>
#         <a class="link_partner" data-clk="service" href="https://business.naver.com/service.html">
#          비즈니스 · 광고
#         </a>
#         <a class="link_partner" data-clk="store" href="https://sell.storefarm.naver.com/#/home/about">
#          스토어 개설
#         </a>
#         <a class="link_partner" data-clk="place" href="https://smartplace.naver.com">
#          지역업체 등록
#         </a>
#         <a class="link_partner" data-clk="expert" href="https://expert.naver.com/expert/introduction?tab=guide#join">
#          엑스퍼트 등록
#         </a>
#        </div>
#        <div class="partner_box" data-clk-prefix="crt">
#         <h3 class="title">
#          Developers
#         </h3>
#         <a class="link_partner" data-clk="center" href="https://developers.naver.com">
#          네이버 개발자 센터
#         </a>
#         <a class="link_partner" data-clk="openapi" href="https://developers.naver.com/docs/common/openapiguide/#/apilist.md">
#          오픈 API
#         </a>
#         <a class="link_partner" data-clk="opensource" href="https://naver.github.io">
#          오픈소스
#         </a>
#         <a class="link_partner" data-clk="d2" href="https://d2.naver.com">
#          네이버 D2
#         </a>
#         <a class="link_partner" data-clk="naverD2SF" href="http://d2startup.com">
#          네이버 D2SF
#         </a>
#         <a class="link_partner" data-clk="labs" href="https://www.naverlabs.com">
#          네이버 랩스
#         </a>
#        </div>
#       </div>
#       <div class="service_box_wrap">
#        <div class="service_box" data-clk-prefix="wbd">
#         <a class="service_logo" data-clk="bt" href="http://whale.naver.com/">
#          <img alt="웨일" height="48" src="data:image/png;base64,..." width="48"/>
#         </a>
#         <div class="service_info">
#          <strong class="title">
#           웨일 브라우저
#          </strong>
#          <a class="dsc" data-clk="bt" href="http://whale.naver.com/">
#           다운받기
#          </a>
#         </div>
#        </div>
#        <div class="service_box" data-clk-prefix="prj">
#         <a class="service_logo" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">
#          <img alt="꽃" height="50" src="data:image/png;base64,..." width="47"/>
#         </a>
#         <div class="service_info">
#          <strong class="title">
#           프로젝트 꽃
#          </strong>
#          <a class="dsc" data-clk="link" href="https://search.naver.com/search.naver?where=nexearch&amp;sm=top_hty&amp;fbm=1&amp;ie=utf8&amp;query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83">
#           바로가기
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="corp_area" data-clk-prefix="plc">
#       <h3 class="blind">
#        네이버 정책 및 약관
#       </h3>
#       <ul class="list_corp">
#        <li class="corp_item">
#         <a data-clk="intronhn" href="https://www.navercorp.com">
#          회사소개
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="recruit" href="https://recruit.navercorp.com/">
#          인재채용
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="contact" href="https://www.navercorp.com/naver/proposalGuide">
#          제휴제안
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="service" href="/policy/service.html">
#          이용약관
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="privacy" href="/policy/privacy.html">
#          <strong>
#           개인정보처리방침
#          </strong>
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="youth" href="/policy/youthpolicy.html">
#          청소년보호정책
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="policy" href="https://policy.naver.com/policy/service_group.html">
#          네이버 정책
#         </a>
#        </li>
#        <li class="corp_item">
#         <a data-clk="helpcenter" href="https://help.naver.com/">
#          고객센터
#         </a>
#        </li>
#       </ul>
#       <address class="addr">
#        <a data-clk="nhn" href="https://www.navercorp.com" target="_blank">
#         ⓒ NAVER Corp.
#        </a>
#       </address>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="adscript" style="display:none">
#   </div>
#  </body>
# </html>

# %%
# find() : 하나의 요소만 가져옴
print(bs.find('p'))
# Out:
# <p class="cjs_d">부산지역의 올해 1분기 건축 허가·착공·준공 실적이 지난해 같은 기간에 비해 크게 개선된 것으로 나타났다. 특히 경기 동향을 확인할 수 있는 후행 지표인 준공 면적 증가율은 전국 1위를 기록했다. 1일 국토교통부에 </p>

# %%
# limit : 태그의 양을 제한
print(bs.find_all('p', limit=1),'\n')
print(bs.find_all('p', limit=2),'\n')
print(bs.find_all('p', limit=10))
# Out:
# [<p class="cjs_d">국민 10명 중 8명은 사업주가 가짜 신분증에 속아 청소년에게 주류 등을 판매했다면 행정제재나 형사처벌 수위를 낮춰줘야 한다고 생각하는 것으로 나타났다. 국민권익위원회와 법제처는 오는 6월 ‘만 나이’ 제도 도입을 </p>]
#
# [<p class="cjs_d">국민 10명 중 8명은 사업주가 가짜 신분증에 속아 청소년에게 주류 등을 판매했다면 행정제재나 형사처벌 수위를 낮춰줘야 한다고 생각하는 것으로 나타났다. 국민권익위원회와 법제처는 오는 6월 ‘만 나이’ 제도 도입을 </p>, <p class="cjs_d">삼성전자와 LG전자가 글로벌 스마트홈 표준 '매터'(Matter)의 국내 적용·확산 사업에 나란히 참여한다. 정부 주도의 첫 매터 사업으로 8개 컨소시엄 간 치열한 수주전이 펼쳐진 가운데 삼성, LG는 각각 디바이스</p>]
#
# [<p class="cjs_d">국민 10명 중 8명은 사업주가 가짜 신분증에 속아 청소년에게 주류 등을 판매했다면 행정제재나 형사처벌 수위를 낮춰줘야 한다고 생각하는 것으로 나타났다. 국민권익위원회와 법제처는 오는 6월 ‘만 나이’ 제도 도입을 </p>, <p class="cjs_d">삼성전자와 LG전자가 글로벌 스마트홈 표준 '매터'(Matter)의 국내 적용·확산 사업에 나란히 참여한다. 정부 주도의 첫 매터 사업으로 8개 컨소시엄 간 치열한 수주전이 펼쳐진 가운데 삼성, LG는 각각 디바이스</p>, <p class="cjs_d">133번째 노동절을 맞아 민주노동조합총연맹(민주노총)과 한국노동조합총연맹(한국노총)이 서울 도심 곳곳에서 집회를 열었다. 시민들은 집회로 인한 소음 공해, 길거리 흡연, 극심한 교통정체 등으로 불편을 겪었다. 1일 </p>, <p class="cjs_d">“내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크</p>, <p class="cjs_d">1일 리움미술관에 따르면 지난달 27일 오후 1시께 미술관에서 전시 중인 마우리치오 카텔란의 작품 '코미디언'을 한 관람객이 훼손했습니다. '코미디언'은 바나나를 덕트 테이프로 벽에 붙여 놓은 작품입니다. 2019년</p>, <p class="cjs_d">일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상</p>, <p class="cjs_d">러시아가 우크라이나에 대규모 미사일 공습을 퍼부은 이튿날, 우크라이나는 러시아군 유류저장고를 파괴하며 반격에 나섰습니다. 우크라이나가 공언해 온 '봄철 대반격'이 임박했다는 관측이 나옵니다. #우크라이나 #러시아 #</p>, <p class="cjs_d"># 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택</p>, <p class="cjs_d">태영호 국민의힘 최고위원이 최근 윤석열 대통령이 미국 국빈 방문에서 보여준 의회 연설을 두고 연일 호평을 쏟아냈다. 북한 외교관 출신인 태 최고위원은 1일 MBC 라디오 '김종배의 시선집중'에 나와 '(방미 외교에서</p>, <p class="cjs_d">윤석열 대통령의 국정수행 지지도가 4주만에 반등에 성공하면서 34.5%를 기록했습니다. 여론조사기관 리얼미터가 지난 4월 24~28일 전국 18세 이상 유권자 2천5백7명을 대상으로 윤 대통령의 국정수행에 대해 물은</p>]

# %% [markdown]
# url = "http://news.naver.com/" 사이트 p태그에서 class 가 cjs_ht 인 데이터를 출력하세요

# %%
from bs4 import BeautifulSoup
import requests as rq

url = 'https://news.naver.com/'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

# print(bs.find('p', class_="cjs_ht"))
print(bs.find_all('p', {'class':"cjs_d"})) # 딕셔너리 타입으로 가능
# Out:
# [<p class="cjs_d">편집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미</p>, <p class="cjs_d">지난달 28일 부산 영도구 청학동 스쿨존에서 1.5t짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다. 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다. </p>, <p class="cjs_d">● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선</p>, <p class="cjs_d">경찰청 국가수사본부(국수본)가 인천 미추홀구 전세사기 사건의 주범인 이른바 '건축사기꾼' 남모씨가 동해 망상지구 사업자로 선정되는 과정에서 특혜가 있었다는 의혹에 대해 입건 전 조사(내사)에 착수했다. 1일 경찰 등</p>, <p class="cjs_d">국민 10명 중 8명은 사업주가 가짜 신분증에 속아 청소년에게 주류 등을 판매했다면 행정제재나 형사처벌 수위를 낮춰줘야 한다고 생각하는 것으로 나타났다. 국민권익위원회와 법제처는 오는 6월 ‘만 나이’ 제도 도입을 </p>, <p class="cjs_d">지난해 4월 '검수완박' 입법 당시 더불어민주당을 탈당하면서 '꼼수탈당'이란 비판을 받았던 민형배 의원이 1일 최근 민주당에 복당하면서 "이지메를 세게 당한 느낌이었다"고 말했다. 자신의 틸당이 민주당과 논의 끝에 </p>, <p class="cjs_d">올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다. 기상청은 현재 중립상태를 유지하고 있는 엘니뇨·라니냐 감시구역(열대태평양 남위5도~북위5도, 서경170도~서경120도 지역) 해수면 온도가 </p>, <p class="cjs_d">송영길 전 대표가 내일(2일) '2021년 전당대회 돈 봉투 의혹'과 관련해 기자회견을 열 예정입니다. 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로</p>, <p class="cjs_d">LG에너지솔루션·삼성SDI 1분기 호실적… 금융당국 “2차전지 신용거래 급증” 우려 “떨어질 땐 다 같이, 오를 땐 혼자.” 4월 26일 한 LG에너지솔루션 주주가 어닝 서프라이즈 소식에 보인 반응이다. 이날 LG에</p>, <p class="cjs_d">네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “</p>, <p class="cjs_d">더불어민주당의 '2021년 전당대회 돈봉투 의혹'을 수사하는 검찰이 송영길 전 대표에 이어 당시 경선캠프 관계자들에 대한 강제수사에 나섰다. 돈봉투 살포 의혹뿐만 아니라 송 전 대표 개인 차원의 자금 살포 의혹으로 </p>, <p class="cjs_d">소시에테제네랄(SG)증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 '1조 축하 파티'에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 1일 밝혀졌다. SBS에 따르면 임창정은 지난</p>, <p class="cjs_d">“여사님이 저희 매장을 방문해 저도 놀랐어요. 어리둥절했어요.” 서울 성동구 성수동에서 소규모로 수제화 매장('앤서니 수제화')을 운영 중인 A씨는 1일 중앙일보와의 통화에서 김건희 여사가 최근 자신의 가게에서 신발</p>, <p class="cjs_d">국민의힘 중앙당 윤리위원회는 잇따른 설화로 논란을 일으킨 김재원·태영호 최고위원에 대한 징계 절차를 시작했다. 황정근 윤리위원장은 1일 오전 서울 여의도 국민의힘 중앙당사에서 윤리위 첫 회의를 연 뒤 이같이 결정했다</p>, <p class="cjs_d">이정근 전 민주당 사무부총장 측이 민주당 전당대회 돈 봉투 사건 단서를 검찰은 이미 지난해 말 인지하고 있었다며, �
즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은< ...

# %%
 # Q. text=bs.find_all('p',{'class':'cjs_d'}) 에서 한글만 출력하세요.(p 태그별로 열방향)

# %%
texts = bs.find_all('p',{'class':'cjs_d'})
for i in texts:
    t = ' '.join(re.findall('[가-힣]+',i.text))
    print(t,'\n')
# Out:
# 이재명 더불어민주당 대표가 일 근로자의 날을 맞아 년 전 노동자들이 시간 노동 을 외치며 일어섰건만 년 대한민국에선 주 시간 노동 이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태
#
# 세계적인 베스트셀러 부자 아빠 가난한 아빠 의 저자 로버트 기요사키가 미국 연방준비제도 연준 를 저격하고 나섰다 일 현지시간 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
#
# 진중권 박근혜 정권보다 퇴행적 박성민 민주당 분열 가능성 영상 윤석열 년을 말하다 영상 국민의힘을 말하다 영상 민주당을 말하다 년 월 일 치러지는 대 총선
#
# 잉글랜드 프리미어리그 에서 뛰고 있는 손흥민 토트넘 홋스퍼 의 반칙 상황을 무술 에 비유한 유명 해설가가 인종차별 논란에 휩싸였다 손흥민은 일 한국시간 에 열린 시즌 라운드
#
# 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원
#
# 배우 원빈 이나영 부부가 년 매입한 서울 강남구 청담동 건물이 억원을 호가하는 것으로 알려졌다 일 부동산 업계에 따르면 원빈과 이나영은 년 월 지하철 분당선 압구정로데오역에서 거
#
# 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 비주류 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법
#
# 정부가 저소득층 청년 저축액의 최대 배까지 같은 금액을 추가 지원하는 청년내일저축계좌 신규 가입자 모집이 일 시작된다 중위소득 이하 가구의 만 세 세 일하는 청년이이라면 청년내일저축계좌를 개설
#
# 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓
#
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다 농성 현장을 찾은 조규홍 보건복지부 장관은 같은 간호 인력 간에도 협의가 이뤄지지 않
#
# 년 개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다 농성 인원이 적은 년 월 일 서울 중구청은 경찰까지 동원해 주변을 지키며 행정대집행 이란 이름으로 농성장
#
# 수원지검 평택지청 전경 평택의 한 아파트단지에서 초등학생을 흉기로 습격하고 달아난 고교생이 구속 기소됐다 수원지검 평
#
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다 네이버는 일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 기존 약관 대신 추가 수정한 개정 약관으로 재동의를 구하고자 한다 며
#
# 송영길 전 대표가 내일 일 년 전당대회 돈 봉투 의혹 과 관련해 기자회견을 열 예정입니다 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로
#
#
#
# 근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가 대부분 번이라고 답할 것이다 이 숫자는 도대체 어디서 온 걸까 사실 번 이하로 해도 된다 번 이상으로 해도 된다 운동 목적에 따라 달라질
#
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 장성 백양사 쌍계루 앞의 이팝나무 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다 꽃이 활짝 핀 지난해 월 풍경이다 이돈삼 이팝나무꽃이 피고 있다 연둣
#
# 동원그룹 맥도날드 인수 포기 메뉴 하나도 글로벌 본사 허락 필요 년 맥도날드 매각 불발 때도 자율권 걸림돌 지적 업계 스타벅스와 달리 작은 것 하나도 본사 허락받아야 그룹 운영 당시
#
# 한은금융망에 신규 가입한 보험회사가 약 년 사이에 두 배나 증가한 것으로 나타났다 한국은행은 이례적이라는 평가를 내놨다 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나 지난해 말 자금난에
#
# 인 가족이 주일 정도 해외에 함께 나가면 만원을 훌쩍 넘어가는 게 현실이다 여행객 주일이나 열흘간 해외에 갔다고 십몇만원 로밍요금 을 내야 하는 것은 과해 보인다 박윤규 과학기술정보통신부 차
#
# 제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까 세 번째로는 순댓국
#
# 지난 월 일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다 더불어민주당 정책위원회 수석부의장인 김병욱 송기헌 유동수 의원이 주최했다 토론회 명칭은 상속세 유산취득세 방식 긍정적 검토 토론회 다
#
# 모빌리티 구 쌍용자동차 가 전기버스 업체인 에디슨 모터스 인수에 열중입니다 에디슨 모터스는 한때 그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금
#
# 소시에테제네랄 증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 조 축하 파티 에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 일 밝혀졌다 에 따르면 임창정은 지난
#
# 윤석열 대통령이 미국 백악관 국빈 만찬에서 아메리칸 파이 를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다 윤 대통령은 미국 국빈 방문 중 지난 달 일 현지시간 열린 백악관
#
# 근로자의 날인 오늘 일 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다 민주노총은 오늘 오후 시 서울 종로구 동화면세점 앞에서 세계노동절대회 를 열고 월 총파업 투쟁을 선포할 계획
#
# 북한 장교들은 한국의 초코파이와 도리토스 나초칩 를 좋아했어요 년부터 년까지 유엔군 사령부 소속으로 비무장지대 에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 일 미
#
# 청소년을 겨냥한 마약 범죄가 기승을 부리자 검찰이 최대 사형까지 구형하겠다며 특단의 조치를 내놨습니다 검찰은 최근 발생한 학원가 마약 음료 사건부터 이번 가중처벌 조항을 적용하는 방안을 검토하고 있습니다 취재
#
# 삼성전자와 네이버가 손잡는 사례가 늘어나고 있다 지난해 연말 초거대 인공지능 에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술 등에서 협력 범위를 넓혀 나가고 있다 최근
#
# 삼성전자 스마트폰 광고 모델을 맡아온 방탄소년단 멤버 슈가가 제품에 대한 남다른 애정을 드러내 화제다 지난달 일 유튜브에는 갤럭시만 셀동 찍어 주겠다는 참 모델 이 영상을 삼성 회장님께 받칩니다
#
# 우리나라 월 수출이 지난해 월 이후 개월째 하락세를 보이면서 무역수지도 개월 연속 하락세를 면치 못했다 지난 일 관세청이 발표한 월 수출입 현황 잠정치 에 따르면 수출은 억 만 달러
#
# 유승민 국민의힘 전 의원이 한미정상회담 결과 와 관련 대한민국 대통령이면 대한민국 국민들께서 가장 위협을 느끼는 북핵문제에 대해서 이번에 길과 방향을 제대로 틀고 왔어야 된다 면서 그런데 오히려 미국한테 좀
#
# 월 일 노동절 근로자의 날 을 맞아 주요 신문들이 우리 사회 노동자들의 현실을 분석한 기획 보도들을 내놨다 정부가 노동 관련 현행 법 제도 사각지대를 보완하고 노동 탄압이 우려되는 정책을 재고해야 한다는 주문이
#
# 내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요 월 일 오전 시 분께 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
#
# 윤석열 대통령은 일 번째 근로자의 날 을 맞아 진정한 노동 약자를 보호하기 위해 노사 법치주의를 확립하고 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것 이라고 밝혔다 윤 대통령은
#
# 우리나라에서 세단의 대명사는 쏘나타였다 특히 강남 지역에서 자주 보이는 수입차에 강남 쏘나타 라는 별명을 붙이기도 했다 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
#
# 리얼미터선 주 만에 반등 한국갤럽은 하락세 대통령 방미 성과 홍보 매진하고 국정 드라이브 박 일간의 미국 국빈 방문 일정을 마치고 귀국한 윤석열 대통령이
경찰의 커뮤니티 폐쇄 요청과 이를 수용하지 않은 방심위의 결정을 두고 여러 이야기가 나옵니다
#
# 에코프로그룹주 더 오른다 국내 배터리업계 주목해야 비판적 읽기 피력 기관 증권사 등 이해관계 있다 돈 벌 기회가 주어져 있다 년 주기로 꼭 투자해야 하는 투자 대상들이 생기는데 그게 마침 배터리
#
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장 미 중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
#
# 마이크로바이옴 시장의 게임체인저가 등장했다 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 먹는 방법의 마이크로바이옴 치료제가 세상에 나온 것이다 이에 마이크로바이옴 치료제 시장 성장은
#
# 윤희근 경찰청장이 계급 특진 임용을 내걸고 건폭 과 마약 수사 를 독려하면서 내부에서는 윗선 입맛에 맞는 수사만 할 것 이라는 우려의 목소리가 나오고 있습니다 윤 청장은 지난달 일 전북경찰청을 찾아 건
#
# 약사 면허증을 위조해 년 동안 가짜 약사 행세를 해온 대가 경찰에 검거됐습니다 제주경찰청 의료 안전사고 전문수사팀은 대 씨를 공문서위조 및 행사 사기와 약사법 위반 혐의 등으로 검찰에 송치했다고 밝혔
#
# 문 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 문재인입니다 가 일 전주 국제영화제에서 공개됐다 다큐는 문 전 대통령이 평산마을에 도착한 지난해 봄부터 가을까지 시간적 순서에 따라 반려견과 함께 마을
#
# 중국 네티즌들이 한복 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다 일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에 올라온 한옥 애셋
#
# 국립공원 입장이 완전 무료화된다 그동안 국립공원 지역 내에 위치한 사찰에서 국가 지정 문화재관람 명목으로 등산객들로부터 입장료를 받아왔는데 대한불교조계종이 일 관람료를 면제한다고 밝혔다 면제 조치는 월
#
# 년간 폭력을 행사하고 교제를 강요한 여자친구에게 이별을 통보받자 승용차로 들이받고 흉기로 살해하려 한 대가 중형을 선고받았다 경남 창원지법 제 형사부 장유진 부장판사 는 살인미수와 특수상해 특수협박 등으로
#
# 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나 그들의 분노가 좀처럼 가라앉지
#
# 편집자주한국은 의료 가성비가 좋다고 하죠 아프면 예약 없이 원에 전문의를 보는 나라 흔치 않으니까요 그러나 건보 흑자 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다 미
#
#
#
# 한 서울대생이 억 만 원 상당의 미술 작품 속 바나나를 먹고 아침을 안 먹고 와서 배고파 먹었다 라고 한 사실이 알려졌습니다 서울대 미학과 재학생 노 모 씨는 지난달 일 리움미술관에서 진행한 마우리
#
# 서울특별시 동대문구 답십리 동 번지 호 통 반 년도 이상호씨 호적명 이대호 가족이 살았던 주소다 그리고 그해 실종 또는 유괴된 상호씨의 아들 이은권씨 당시 만 세 사진 가 년이 넘게
#
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면 자신의 운동 습관을 체크해 봐야 한다 특히 체중 허리 사이즈 근육의 양 등 중요 수치에 변화가 없다면 운동 효과에 대한 회의감마저 갖게 된
#
# 지난달 일 부산 영도구 청학동 스쿨존에서 짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다

# %%
#박주경
texts = bs.find_all('p', {'class':'cjs_d'})

for text in texts:
    print(text.text,'\n')
# Out:
# 이재명 더불어민주당 대표가 1일 근로자의 날을 맞아 "133년 전 노동자들이 '8시간 노동'을 외치며 일어섰건만, 2023년 대한민국에선 '주 69시간 노동'이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태
#
# 세계적인 베스트셀러 '부자 아빠 가난한 아빠'의 저자 로버트 기요사키가 미국 연방준비제도(Fed·연준)를 저격하고 나섰다. 27일(현지시간) 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
#
# ● 진중권 “尹, 박근혜 정권보다 퇴행적” ● 박성민 “민주당 분열 가능성 60%” [+영상] 윤석열 1년을 말하다 [+영상] 국민의힘을 말하다 [+영상] 민주당을 말하다 2024년 4월 10일 치러지는 22대 총선
#
# 잉글랜드 프리미어리그(EPL)에서 뛰고 있는 손흥민(31·토트넘 홋스퍼)의 반칙 상황을 ‘무술’에 비유한 유명 해설가가 인종차별 논란에 휩싸였다. 손흥민은 1일(한국시간)에 열린 2022-23시즌 EPL 34라운드
#
# 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다. 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원
#
# 배우 원빈·이나영 부부가 2018년 매입한 서울 강남구 청담동 건물이 300억원을 호가하는 것으로 알려졌다. 30일 부동산 업계에 따르면, 원빈과 이나영은 2018년 2월 지하철 분당선 압구정로데오역에서 300m 거
#
# 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 '비주류' 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법
#
# 정부가 저소득층 청년 저축액의 최대 3배까지 같은 금액을 추가 지원하는 '청년내일저축계좌' 신규 가입자 모집이 1일 시작된다. 중위소득 100% 이하 가구의 만19세~34세 일하는 청년이이라면 청년내일저축계좌를 개설
#
# # 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다. 수상택시입니다. 그 옆에는 늘 함께 붙어다니는 말이 있습니다. 서울시입니다. # 서울시는 2005년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식, 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다. 이우석 먹고놀기연구소 소장은 "횟집에서 회 뜨고 남은 생선으로 끓
#
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다. 농성 현장을 찾은 조규홍 보건복지부 장관은 "같은 간호 인력 간에도 협의가 이뤄지지 않
#
# 1년5개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다. 농성 인원이 적은 2023년 4월4일 서울 중구청은 경찰까지 동원해 주변을 지키며 ‘행정대집행’이란 이름으로 농성장
#
# 수원지검 평택지청 전경 평택의 한 아파트단지에서 초등학생을 흉기로 습격하고 달아난 고교생이 구속 기소됐다. 수원지검 평
#
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다. 네이버는 28일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 “(기존 약관 대신) 추가 수정한 개정 약관으로 재동의를 구하고자 한다”며 “
#
# 송영길 전 대표가 내일(2일) '2021년 전당대회 돈 봉투 의혹'과 관련해 기자회견을 열 예정입니다. 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로
#
# Korea's exports fell for the seventh consecutive month in April due primarily to weak demand for semiconductors amid an
#
# 근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가? 대부분 10~15번이라고 답할 것이다. 이 숫자는 도대체 어디서 온 걸까? 사실 5번 이하로 해도 된다. 30번 이상으로 해도 된다. 운동 목적에 따라 달라질
#
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 ▲ 장성 백양사 쌍계루 앞의 이팝나무. 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다. 꽃이 활짝 핀 지난해 5월 풍경이다. ⓒ 이돈삼 이팝나무꽃이 피고 있다. 연둣
#
# 동원그룹, 맥도날드 인수 포기… “메뉴 하나도 글로벌 본사 허락 필요” 2016년 맥도날드 매각 불발 때도 ‘자율권’ 걸림돌 지적 업계 “스타벅스와 달리 작은 것 하나도 본사 허락받아야” KG그룹, KFC 운영 당시
#
# 한은금융망에 신규 가입한 보험회사가 약 1년 사이에 두 배나 증가한 것으로 나타났다. 한국은행은 이례적이라는 평가를 내놨다. 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나, 지난해 말 자금난에
#
# “4인 가족이 1주일 정도 해외에 함께 나가면, 10만원을 훌쩍 넘어가는 게 현실이다” (여행객) “1주일이나 열흘간 해외에 갔다고 십몇만원(로밍요금)을 내야 하는 것은 과해 보인다” (박윤규 과학기술정보통신부 2차
#
# “제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요. 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠. 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까? 세 번째로는 순댓국
#
# 지난 4월 21일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다. 더불어민주당 정책위원회 수석부의장인 김병욱·송기헌·유동수 의원이 주최했다. 토론회 명칭은 ‘상속세 유산취득세 방식 긍정적 검토 토론회’다.
#
# KG모빌리티(구 쌍용자동차)가 전기버스 업체인 에디슨 모터스 인수에 열중입니다. 에디슨 모터스는 한때 KG그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다. 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금
#
# 소시에테제네랄(SG)증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 '1조 축하 파티'에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 1일 밝혀졌다. SBS에 따르면 임창정은 지난
#
# 윤석열 대통령이 미국 백악관 국빈 만찬에서 '아메리칸 파이'(American Pie)를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다. 윤 대통령은 미국 국빈 방문 중 지난 달 26일(현지시간) 열린 백악관
#
# 근로자의 날인 오늘(1일) 양대노총을 비롯한 노동 단체들이 서울 도심 곳곳에서 대규모 집회를 엽니다. 민주노총은 오늘 오후 2시 서울 종로구 동화면세점 앞에서 '세계노동절대회'를 열고 7월 총파업 투쟁을 선포할 계획
#
# “북한 장교들은 한국의 초코파이와 도리토스(나초칩)를 좋아했어요.” 2013년부터 2021년까지 유엔군 사령부 소속으로 비무장지대(DMZ)에서 근무한 미국 해군 퇴역 장교 대니얼 맥셰인 전 소령은 지난달 28일 미
#
# 청소년을 겨냥한 마약 범죄가 기승을 부리자 검찰이 최대 사형까지 구형하겠다며 특단의 조치를 내놨습니다. 검찰은 최근 발생한 '학원가 마약 음료' 사건부터 이번 가중처벌 조항을 적용하는 방안을 검토하고 있습니다. 취재
#
# 삼성전자와 네이버가 손잡는 사례가 늘어나고 있다. 지난해 연말 ‘초거대 인공지능(AI)’에 활용된 반도체 솔루션 개발을 위한 업무 협약을 시작으로 금융과 정보기술(IT) 등에서 협력 범위를 넓혀 나가고 있다. 최근
#
# 삼성전자 스마트폰 광고 모델을 맡아온 방탄소년단(BTS) 멤버 슈가가 제품에 대한 남다른 애정을 드러내 화제다. 지난달 30일 유튜브에는 '갤럭시만 셀동 찍어 주겠다는 참 모델', '이 영상을 삼성 회장님께 받칩니다
#
# 우리나라 4월 수출이 지난해 10월 이후 7개월째 하락세를 보이면서, 무역수지도 14개월 연속 하락세를 면치 못했다. 지난 1일 관세청이 발표한 '3월 수출입 현황(잠정치)'에 따르면, 수출은 496억2000만 달러
#
# 유승민 국민의힘 전 의원이 '한미정상회담 결과'와 관련, "대한민국 대통령이면 대한민국 국민들께서 가장 위협을 느끼는 북핵문제에 대해서 이번에 길과 방향을 제대로 틀고 왔어야 된다"면서 "그런데 오히려 미국한테 좀
#
# 5월1일 노동절(근로자의 날)을 맞아 주요 신문들이 우리 사회 노동자들의 현실을 분석한 기획 보도들을 내놨다. 정부가 노동 관련 현행 법·제도 사각지대를 보완하고 노동 탄압이 우려되는 정책을 재고해야 한다는 주문이
#
# “내 머리 위를 넘어 기시다 총리의 발밑에 떨어진 순간 폭탄인 줄 알았어요.” 4월15일 오전 11시30분께, 와카야마시 사이카자키 어시장에서 중의원 보궐선거 지원 연설을 하려던 기시다 후미오 총리를 향해 연막탄 크
#
# 윤석열 대통령은 1일 133번째 '근로자의 날'을 맞아 "진정한 노동 약자를 보호하기 위해 노사 법치주의를 확립하고, 우리 헌법 정신에 위배되는 기득권의 고용세습은 확실히 뿌리 뽑을 것"이라고 밝혔다. 윤 대통령은
#
# 우리나라에서 세단의 대명사는 쏘나타였다. 특히 강남 지역에서 자주 보이는 수입차에 ‘강남 쏘나타’라는 별명을 붙이기도 했다. 최근 세단 모델이 위기를 겪는 가운데 고급스러운 디자인과 효율 높은 친환경 디젤 엔진을 탑
#
# 리얼미터선 4주 만에 반등, 한국갤럽은 하락세 尹대통령, '방미 성과' 홍보 매진하고 국정 드라이브 5박7일간의 미국 국빈 방문 일정을 마치고 귀국한 윤석열 대통령이 '지지율 반등'이라는 성적표를 받게 됐다. 1일
#
# “금융규제 방식은 포크레인식으로 모두 다 이렇게 엎어 버리는 방식인데, 기술의 분야를 그런 식으로 규제를 하면 기술이 발전할 수 없겠지요.”(최화인 블록체인 에반젤리스트) “이 대목이 지금 되게 좀 중요한 것 같은데
#
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 ‘문재인입니다’(10일 개봉)는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 ‘입’을 빌린 대통령 문재인의 면모를 병치시킨다. 문 전 대통령의 정
#
# '정권교체 예상' 여론조사 크게 엇나가…대만, 한숨 돌릴 듯 이재림 특파원 = 금전 외교를 앞세운 중국의 영향력 확대 의지도, 중남미에 거세게 일렁이는 온건 좌파 물결('핑크 타이드')도 인구 750만명의 남미 내륙
#
# 검거 전 보험금 지급 청구 소송 구속 수감 후에도 소송 이어가 ‘가평 계곡 살인’으로 세상을 떠들썩하게 했던 이은해가 1심에 이어 항소심에서도 무기징역을 선고 받았습니다. 이은해의 내연남이자 공범인 조현수 역시 1심
#
# 2023년 4월 13일 국회 본회의에서 '대구경북신공항 건설을 위한 특별법'이 통과됐습니다. 대구경북신공항은 현재 대구 도심에 있는 군 공항인 K2와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
#
# 일본의 중노년 싱글여성 단체인 ‘와쿠와쿠 시니어 싱글즈’가 릿쿄대학 유자와 나오미(湯澤直美) 씨와 북경JAC 협력으로 중고령 싱글여성의 생활실태를 조사했다. ‘와쿠와쿠’(두근두근이라는 뜻)는 2016년에 50세 이상
#
# 정부가 문화유산을 활용한 게임·메타버스 창작을 지원하기 위해 무료로 개방한 문화재 3D 데이터에 중국 누리꾼들의 '댓글 테러'가 이어지고 있다. 1일 게임 업계 등에 따르면 에픽게임즈가 운영하는 '언리얼 엔진 마켓플
#
# 정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다. 오늘(1일) 게임업계에 따르면 에픽게임즈가 운영하는 '언리얼 엔진 마켓플레이스'에
#
# 기사내용 요약 AP 보도…"분란 혐의 등으로 3년형 선고" 코로나19가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 3년 만에 석방될 것이라고 AP통신이 30일(현지시간) 보도했다. 통신은 이 시민의 친척
#
# 요즘 4대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다. 이명박 전 대통령(이하 존칭 생략)은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 4대강도 방문할 예정이라고 한다. 4대강 추진본부장이었던 심명필은
#
# 서울시는 청년에게 월세 최대 20만원을 지원하는 '2023년도 청년월세' 대상자를 모집합니다. 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 19∼39세 청년 2만5천명에게 10개월간 월세 최대 20만원을
#
# 음상준 보건의료전문기자 = 간호법 제정안과 중범죄를 저지른 의료인 면허를 취소한다는 내용의 의료법 개정안(의료인면허 취소법)이 지난 27일 국회 본회의를 통과했지만, 그 후폭풍이 계속되고 있다. 간호법 제정을 반대한
#
# 경기 이천시(시장 김경희)가 20일 시 농산물 브랜드인 <임금님표이천> 상표 사용 30년을 맞아 기념식과 함께 ‘쌀밥데이’를 선포한다. 시는 1993년 가짜 이천쌀 문제에 대응하고자 <임금님표 이천쌀> 상표를 사용하
#
# 윤석열 대통령의 5박7일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 ‘영어’ 연설에 관한 반응이 뜨거웠다. 이와 관련 중요한 것은 ‘외교 성과’라는 지적과 함께 외신의 보도 내용도 눈길을 끈다. 태영호 국민의힘
#
# 올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다. 기상청은 현재 중립상태를 유지하고 있는 엘니뇨·라니냐 감시구역(열대태평양 남위5도~북위5도, 서경170도~서경120도 지역) 해수면 온도가
#
# 컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 10대가 재판에 넘겨졌다. 1일 수원지검 평택지청 형사1부는 살인미수 혐의로 A(17) 군을 구속기소 했다고 밝혔다. A 군은 지난 달 3일 경기도 평택시의 한 아
#
# 국민의힘 윤리위원회는 1일 실언으로 논란을 일으킨 김재원, 태영호 최고위원에 대한 징계를 개시하기로 결정했다. 황정근 윤리위원장은 이날 오전 여의도 중앙당사에서 열린 전체회의 후 브리핑에서
집자주한국은 의료 가성비가 좋다고 하죠. 아프면 예약 없이 3,000~4,000원에 전문의를 보는 나라, 흔치 않으니까요. 그러나 건보 흑자, 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다. 미
#
# A 3.1 magnitude natural earthquake hit Okcheon, North Chungcheong Province, Sunday, the state weather agency said. The q
#
# 한 서울대생이 1억 5,000만 원 상당의 미술 작품 속 바나나를 먹고 "아침을 안 먹고 와서 배고파 먹었다"라고 한 사실이 알려졌습니다. 서울대 미학과 재학생 노 모 씨는 지난달 27일 리움미술관에서 진행한 마우리
#
# '서울특별시 동대문구 답십리4동 51번지 12호 13통 2반' 1981년도 이상호씨(호적명 이대호) 가족이 살았던 주소다. 그리고 그해 실종 또는 유괴된 상호씨의 아들 이은권씨(당시 만 2세· 사진)가 40년이 넘게
#
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면, 자신의 운동 습관을 체크해 봐야 한다. 특히 체중, 허리 사이즈, 근육의 양 등 중요 수치에 변화가 없다면, 운동 효과에 대한 회의감마저 갖게 된
#
# 지난달 28일 부산 영도구 청학동 스쿨존에서 1.5t짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다. 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다.

# %%
texts = bs.find_all('p',{'class':'cjs_d'})
for t in texts:
    t = str(t)
    t = re.findall('[가-힣]+',t)
    t = ' '.join(t)
    print(t,'\n')
# Out:
# 이재명 더불어민주당 대표가 일 근로자의 날을 맞아 년 전 노동자들이 시간 노동 을 외치며 일어섰건만 년 대한민국에선 주 시간 노동 이 국가 정책으로 추진돼 땀 흘려 일하는 시민의 삶이 위태
#
# 세계적인 베스트셀러 부자 아빠 가난한 아빠 의 저자 로버트 기요사키가 미국 연방준비제도 연준 를 저격하고 나섰다 일 현지시간 기요사키는 자신의 트위터를 통해 연준이 미국 경제의 심장 역할을 하는 지역
#
# 진중권 박근혜 정권보다 퇴행적 박성민 민주당 분열 가능성 영상 윤석열 년을 말하다 영상 국민의힘을 말하다 영상 민주당을 말하다 년 월 일 치러지는 대 총선
#
# 잉글랜드 프리미어리그 에서 뛰고 있는 손흥민 토트넘 홋스퍼 의 반칙 상황을 무술 에 비유한 유명 해설가가 인종차별 논란에 휩싸였다 손흥민은 일 한국시간 에 열린 시즌 라운드
#
# 충북 보은군 속리산 법주사가 징수해 온 문화재 관람료가 폐지될 예정임에 따라 지역 관광경기 활성화 기대가 높아지고 있습니다 국가지정문화재 민간 소유자 또는 관리단체가 문화재 관람료를 감면하면 그 비용을 국가가 지원
#
# 배우 원빈 이나영 부부가 년 매입한 서울 강남구 청담동 건물이 억원을 호가하는 것으로 알려졌다 일 부동산 업계에 따르면 원빈과 이나영은 년 월 지하철 분당선 압구정로데오역에서 거
#
# 온건 성향이어서 당사자간 소통은 무리 없을 전망이지만 거대 여야 양강 대립 구도 속 운신의 폭 좁다는 지적도 사법리스크 따라 비주류 박광온 변수될수도 국민의힘과 더불어민주당이 나란히 새 원내사령탑을 뽑으면서 입법
#
# 정부가 저소득층 청년 저축액의 최대 배까지 같은 금액을 추가 지원하는 청년내일저축계좌 신규 가입자 모집이 일 시작된다 중위소득 이하 가구의 만 세 세 일하는 청년이이라면 청년내일저축계좌를 개설
#
# 때만 되면 포털 뉴스란에 심심찮게 등장하는 단어가 있습니다 수상택시입니다 그 옆에는 늘 함께 붙어다니는 말이 있습니다 서울시입니다 서울시는 년부터 서울의 교통혼잡을 완화하기 위한 대안으로 수상택
#
# 겉모습은 꼰대지만 누구보다 맛에 진심인 이우석 먹고놀기연구소 소장이 풀어내는 쉬운 미식 이번에는 호불호가 갈리기 십상인 매운탕 편으로 찾아왔습니다 이우석 먹고놀기연구소 소장은 횟집에서 회 뜨고 남은 생선으로 끓
#
# 간호법 제정에 반대하며 단식을 해온 곽지연 대한간호조무사협회 회장이 단식 농성에 돌입한 지 닷새만인 어제 병원으로 이송됐습니다 농성 현장을 찾은 조규홍 보건복지부 장관은 같은 간호 인력 간에도 협의가 이뤄지지 않
#
# 년 개월 넘게 해고 상태인 서울 중구 명동 세종호텔 해고노동자들의 천막농성장이 강제로 뜯겨나갔다 농성 인원이 적은 년 월 일 서울 중구청은 경찰까지 동원해 주변을 지키며 행정대집행 이란 이름으로 농성장
#
# 수원지검 평택지청 전경 평택의 한 아파트단지에서 초등학생을 흉기로 습격하고 달아난 고교생이 구속 기소됐다 수원지검 평
#
# 네이버가 불공정 논란이 일었던 뉴스콘텐츠제휴 약관을 전면 수정해 재공지했다 네이버는 일 오후 뉴스콘텐츠제휴 언론사들에 이메일을 보내 기존 약관 대신 추가 수정한 개정 약관으로 재동의를 구하고자 한다 며
#
# 송영길 전 대표가 내일 일 년 전당대회 돈 봉투 의혹 과 관련해 기자회견을 열 예정입니다 당시 자신의 경선 캠프에 몸담았던 관계자들을 대상으로 검찰의 강제수사가 이어지자 직접 반박에 나서기로 한 것으로
#
#
#
# 근력 운동 중 한 세트할 때 몇 번 동작을 반복하는가 대부분 번이라고 답할 것이다 이 숫자는 도대체 어디서 온 걸까 사실 번 이하로 해도 된다 번 이상으로 해도 된다 운동 목적에 따라 달라질
#
# 천연기념물 지정된 순천 승주 평지마을 이팝나무 장성 백양사 쌍계루 앞의 이팝나무 각진국사가 꽂은 지팡이가 자랐다는 전설이 전해진다 꽃이 활짝 핀 지난해 월 풍경이다 이돈삼 이팝나무꽃이 피고 있다 연둣
#
# 동원그룹 맥도날드 인수 포기 메뉴 하나도 글로벌 본사 허락 필요 년 맥도날드 매각 불발 때도 자율권 걸림돌 지적 업계 스타벅스와 달리 작은 것 하나도 본사 허락받아야 그룹 운영 당시
#
# 한은금융망에 신규 가입한 보험회사가 약 년 사이에 두 배나 증가한 것으로 나타났다 한국은행은 이례적이라는 평가를 내놨다 보험사는 보험상품의 만기가 길어 장기물 자산 중심으로 거래를 해왔으나 지난해 말 자금난에
#
# 인 가족이 주일 정도 해외에 함께 나가면 만원을 훌쩍 넘어가는 게 현실이다 여행객 주일이나 열흘간 해외에 갔다고 십몇만원 로밍요금 을 내야 하는 것은 과해 보인다 박윤규 과학기술정보통신부 차
#
# 제주도에 있을 때 먹었던 흑돼지와 냉면이 최애 음식이라고 말할 수 있어요 두 번째는 아무래도 한국인의 소울 푸드인 김치찌개죠 무슨 일이 있어도 김치찌개만 먹으면 기분 전환이 되는 느낌이랄까 세 번째로는 순댓국
#
# 지난 월 일 국회에서 상속세 과세체계 개편과 관련한 토론회가 열렸다 더불어민주당 정책위원회 수석부의장인 김병욱 송기헌 유동수 의원이 주최했다 토론회 명칭은 상속세 유산취득세 방식 긍정적 검토 토론회 다
#
# 모빌리티 구 쌍용자동차 가 전기버스 업체인 에디슨 모터스 인수에 열중입니다 에디슨 모터스는 한때 그룹과 쌍용차 인수를 두고 경쟁을 벌였던 곳입니다 에디슨 모터스는 쌍용차 인수 본 계약까지 체결했지만 인수금
#
# 소시에테제네랄 증권 발 주가 폭락 사태와 관련해 피해자라고 나선 가서 임창정이 이른바 조 축하 파티 에 이어 또 다른 고액 투자자 모임에도 임 씨가 나간 사실이 일 밝혀졌다 에 따르면 임창정은 지난
#
# 윤석열 대통령이 미국 백악관 국빈 만찬에서 아메리칸 파이 를 부른 모습이 여러 외신에도 보도되며 화제를 모으고 있다 윤 대통령은 미국 국빈 방문 중 지난 달 일 현지시간 열린 백악관
# 금융규제 방식은 포크레인식으로 모두 다 이렇게 엎어 버리는 방식인데 기술의 분야를 그런 식으로 규제를 하면 기술이 발전할 수 없겠지요 최화인 블록체인 에반젤리스트 이 대목이 지금 되게 좀 중요한 것 같은데
#
# 올해 전주국제영화제에서 공개된 다큐멘터리 영화 문재인입니다 일 개봉 는 잡초를 좋아하는 자연인 문재인의 일상과 문 전 대통령 주변 인사들의 입 을 빌린 대통령 문재인의 면모를 병치시킨다 문 전 대통령의 정
#
# 정권교체 예상 여론조사 크게 엇나가 대만 한숨 돌릴 듯 이재림 특파원 금전 외교를 앞세운 중국의 영향력 확대 의지도 중남미에 거세게 일렁이는 온건 좌파 물결 핑크 타이드 도 인구 만명의 남미 내륙
#
# 검거 전 보험금 지급 청구 소송 구속 수감 후에도 소송 이어가 가평 계곡 살인 으로 세상을 떠들썩하게 했던 이은해가 심에 이어 항소심에서도 무기징역을 선고 받았습니다 이은해의 내연남이자 공범인 조현수 역시 심
#
# 년 월 일 국회 본회의에서 대구경북신공항 건설을 위한 특별법 이 통과됐습니다 대구경북신공항은 현재 대구 도심에 있는 군 공항인 와 대구국제공항을 경북 의성군 비안면과 군위군 소보면으로 새롭게 옮기
#
# 일본의 중노년 싱글여성 단체인 와쿠와쿠 시니어 싱글즈 가 릿쿄대학 유자와 나오미 씨와 북경 협력으로 중고령 싱글여성의 생활실태를 조사했다 와쿠와쿠 두근두근이라는 뜻 는 년에 세 이상
#
# 정부가 문화유산을 활용한 게임 메타버스 창작을 지원하기 위해 무료로 개방한 문화재 데이터에 중국 누리꾼들의 댓글 테러 가 이어지고 있다 일 게임 업계 등에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플
#
# 정부가 메타버스 콘텐츠 창작자들을 위해 무료로 개방한 한국 전통문화 데이터가 일부 중국 누리꾼들의 댓글 테러로 몸살을 앓고 있습니다 오늘 일 게임업계에 따르면 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에
#
# 기사내용 요약 보도 분란 혐의 등으로 년형 선고 코로나 가 처음 유행한 중국 후베이성 우한 실태를 고발했던 시민이 년 만에 석방될 것이라고 통신이 일 현지시간 보도했다 통신은 이 시민의 친척
#
# 요즘 대강 사업의 주역들이 부쩍 대중 앞에 자주 등장하고 있다 이명박 전 대통령 이하 존칭 생략 은 며칠 전 측근 유인촌의 연극을 관람했고 앞으로 대강도 방문할 예정이라고 한다 대강 추진본부장이었던 심명필은
#
# 서울시는 청년에게 월세 최대 만원을 지원하는 년도 청년월세 대상자를 모집합니다 청년월세는 서울의 높은 주거비 부담을 덜어주기 위해 만 세 청년 만 천명에게 개월간 월세 최대 만원을
#
# 음상준 보건의료전문기자 간호법 제정안과 중범죄를 저지른 의료인 면허를 취소한다는 내용의 의료법 개정안 의료인면허 취소법 이 지난 일 국회 본회의를 통과했지만 그 후폭풍이 계속되고 있다 간호법 제정을 반대한
#
# 경기 이천시 시장 김경희 가 일 시 농산물 브랜드인 임금님표이천 상표 사용 년을 맞아 기념식과 함께 쌀밥데이 를 선포한다 시는 년 가짜 이천쌀 문제에 대응하고자 임금님표 이천쌀 상표를 사용하
#
# 윤석열 대통령의 박 일 국빈 방미 일정이 끝난 가운데 대통령의 미 의회 영어 연설에 관한 반응이 뜨거웠다 이와 관련 중요한 것은 외교 성과 라는 지적과 함께 외신의 보도 내용도 눈길을 끈다 태영호 국민의힘
#
# 올여름 엘니뇨의 발달로 남부지방을 중심으로 많은 비가 내릴 것으로 보인다 기상청은 현재 중립상태를 유지하고 있는 엘니뇨 라니냐 감시구역 열대태평양 남위 도 북위 도 서경 도 서경 도 지역 해수면 온도가
#
# 컵라면을 먹던 초등학생에게 흉기를 휘둘러 다치게 한 대가 재판에 넘겨졌다 일 수원지검 평택지청 형사 부는 살인미수 혐의로 군을 구속기소 했다고 밝혔다 군은 지난 달 일 경기도 평택시의 한 아
#
#
# 중국이 우리나라 반도체 산업에 대한 압박에 나섰다 원산지 점검과 통관 검사 강화 조치에 이어 우리 기업의 중국 수출 계약 취소 사례까지 등장 미 중 갈등으로 인해 국내 기업 피해가 가시화되는 것이 아니냐는 우려가
#
# 마이크로바이옴 시장의 게임체인저가 등장했다 투약 방법의 불편함이 마이크로바이옴 치료제의 한계로 지적됐는데 간편하게 먹는 방법의 마이크로바이옴 치료제가 세상에 나온 것이다 이에 마이크로바이옴 치료제 시장 성장은
#
# 윤희근 경찰청장이 계급 특진 임용을 내걸고 건폭 과 마약 수사 를 독려하면서 내부에서는 윗선 입맛에 맞는 수사만 할 것 이라는 우려의 목소리가 나오고 있습니다 윤 청장은 지난달 일 전북경찰청을 찾아 건
#
# 약사 면허증을 위조해 년 동안 가짜 약사 행세를 해온 대가 경찰에 검거됐습니다 제주경찰청 의료 안전사고 전문수사팀은 대 씨를 공문서위조 및 행사 사기와 약사법 위반 혐의 등으로 검찰에 송치했다고 밝혔
#
# 문 전 대통령의 퇴임 후 일상을 보여주는 다큐멘터리 영화 문재인입니다 가 일 전주 국제영화제에서 공개됐다 다큐는 문 전 대통령이 평산마을에 도착한 지난해 봄부터 가을까지 시간적 순서에 따라 반려견과 함께 마을
#
# 중국 네티즌들이 한복 음력 설에 이어 한옥이 중국 문화라는 황당 주장을 펼쳐 눈살을 찌푸리게 하고 있다 일 게임업계에 따르면 중국 네티즌들은 에픽게임즈가 운영하는 언리얼 엔진 마켓플레이스 에 올라온 한옥 애셋
#
# 국립공원 입장이 완전 무료화된다 그동안 국립공원 지역 내에 위치한 사찰에서 국가 지정 문화재관람 명목으로 등산객들로부터 입장료를 받아왔는데 대한불교조계종이 일 관람료를 면제한다고 밝혔다 면제 조치는 월
#
# 년간 폭력을 행사하고 교제를 강요한 여자친구에게 이별을 통보받자 승용차로 들이받고 흉기로 살해하려 한 대가 중형을 선고받았다 경남 창원지법 제 형사부 장유진 부장판사 는 살인미수와 특수상해 특수협박 등으로
#
# 더불어민주당 박광온 원내대표가 취임 일주일도 되지 않아 이른바 개딸들의 거센 공격을 받고 있다 이에 이재명 대표가 연휴 기간에 직접 페이스북에 글을 올려 개딸들에게 자제를 요청했으나 그들의 분노가 좀처럼 가라앉지
#
# 편집자주한국은 의료 가성비가 좋다고 하죠 아프면 예약 없이 원에 전문의를 보는 나라 흔치 않으니까요 그러나 건보 흑자 일부 의료인의 희생 덕에 양질의 의료를 누렸던 시대도 끝나 갑니다 미
#
#
#
# 한 서울대생이 억 만 원 상당의 미술 작품 속 바나나를 먹고 아침을 안 먹고 와서 배고파 먹었다 라고 한 사실이 알려졌습니다 서울대 미학과 재학생 노 모 씨는 지난달 일 리움미술관에서 진행한 마우리
#
# 서울특별시 동대문구 답십리 동 번지 호 통 반 년도 이상호씨 호적명 이대호 가족이 살았던 주소다 그리고 그해 실종 또는 유괴된 상호씨의 아들 이은권씨 당시 만 세 사진 가 년이 넘게
#
# 운동을 위해 시간과 비용을 들여 열심히 했는데도 몸의 변화가 없다면 자신의 운동 습관을 체크해 봐야 한다 특히 체중 허리 사이즈 근육의 양 등 중요 수치에 변화가 없다면 운동 효과에 대한 회의감마저 갖게 된
#
# 지난달 일 부산 영도구 청학동 스쿨존에서 짜리 원통형 화물에 치여 숨진 아이의 아빠가 온라인 커뮤니티에 자신의 심경을 올렸다 아빠는 생전 딸의 사랑스러웠던 여러 모습을 메모하듯이 남기며 딸을 추억했다

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'http://news.daum.net/politics'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'html.parser')

print(bs.find('h2', id='mainContent'),'\n')

print(bs.find_all('h2'))
# Out:
# <h2 class="screen_out" id="mainContent">정치</h2>
#
# [<h2 class="screen_out">뉴스 메인메뉴</h2>, <h2 class="screen_out" id="mainContent">정치</h2>, <h2 class="tit_direct">바로가기</h2>, <h2 class="screen_out">서비스 이용정보</h2>]

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'html.parser')

print(bs.find_all('h2'),'\n')
print(bs.find('h2',id='mainContent').text)

# %%
# A
url = 'http://news.daum.net/politics'

r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'html.parser')
title= bs.find('h2', id='mainContent').text
title
# Out:
# '정치'

# %%
# Q. 네이버 영화 랭킹 조회순 첫번째 영화제목을 출력하세요.

url ='https://serieson.naver.com/v3/movie/ranking/realtime'
bs.find('span',class_="Title_title__s9o0D").text # f12 들어가서 클래스가 어딘지 확인하면 된다 .
# Out:
# '던전 앤 드래곤: 도적들의 명예'

# %%
url = 'https://serieson.naver.com/v3/movie/ranking/realtime'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'html.parser')
print(bs.find('span',class_='Title_title__s9o0D').text)
# Out:
# 던전 앤 드래곤: 도적들의 명예

# %%
import requests
from bs4 import BeautifulSoup

url = "https://serieson.naver.com/v3/movie/ranking/realtime"

# HTTP GET 요청을 보냅니다.
response = requests.get(url)

# HTTP 요청이 성공적으로 전달되었다면, 웹사이트의 HTML 코드를 가져옵니다.
if response.status_code == 200:
    # HTML 코드를 파싱합니다.
    soup = BeautifulSoup(response.text, "html.parser")
# print(soup)
soup.find("span", class_="Title_title__s9o0D").text
# Out:
# '던전 앤 드래곤: 도적들의 명예'

# %% [markdown]
# ## 과제 5_0501
# 네이버 영화 랭킹 실시간 조회 데이터를 가져와서 TOP 10 영화를 아래와 같이 출력하여라.

# %%
1: 던전 앤 드래곤: 도적들의 명예
2: 존 윅
3: 존 윅 3: 파라벨룸

# %%
import requests
from bs4 import BeautifulSoup
req = requests.get("https://serieson.naver.com/v3/movie/ranking/realtime")
html = req.content.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
list = soup.find_all("span", class_="Title_title__s9o0D")
print(len(list))
for i, l in enumerate(list[:10]):
    print(f'{i+1}: {l.text}')

# %% [markdown]
# ## 과제 6_0501
# url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사 제목을 출력하세요.

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100" 
req = requests.get(url, headers=headers)   # GET방식으로 서비스 호출
soup = BeautifulSoup(req.content, "html.parser")
target = soup.select("#main_content > div > div > div > div > div> ul > li > div > a")
for element in target:
    print(element.text)

# %%
# 정규표현식을 사용 할 때

html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""
soup = BeautifulSoup(html, "html.parser")


li = soup.find_all(href=re.compile(r"^https://")) #http:// 로 시작하는 것만 골라서 담아줌
print(li,'\n')
for e in li: print(e.attrs['href'])
# Out:
# [<a href="https://example.com/fuga">fuga*</a>, <a href="https://example.com/foo">foo*</a>]
#
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ### CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
# select()
import requests as rq
from bs4 import BeautifulSoup

url = 'http://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html, 'lxml')

lines = bs.select('body > div > main > section > div.main-sub> div> ul > li> strong > a')
body = '\n'.join([line.text for line in lines])
print(body)
body
# Out:
# 용혜인 "'초단시간 노동자 권리찾기법' 발의 추진"
# 나라 곳간 우려는 뒷전... 재정소요 법안 '비용추계서 제출' 유명무실
# 5월 임시국회 시작…여야, '노란봉투법' 충돌 예고
# 민주당 “맞벌이 학부모 위한 주 4일제 적극 검토”
# 尹대통령, 한총리와 주례회동 취소…"방미 직후 사정 등 고려"
# 노동절에 노동자 갈라치는 대통령…“고용세습 뿌리 뽑겠다”
# '워싱턴 선언'에 아픈 곳 찔리자…북, 중·러 업고 사흘째 흠집내기
# 송영길 또 '2일 자진출석' 예고…안희정식 대응 닮은 꼴
# 영덕군, 원전 지원금 반환 행정소송 패소에 항소할 듯
# [단독]"김건희 여사 직접 사가"...방미때 돌려신은 '성수동 수제화'
# '용혜인 "\'초단시간 노동자 권리찾기법\' 발의 추진"\n나라 곳간 우려는 뒷전... 재정소요 법안 \'비용추계서 제출\' 유명무실\n5월 임시국회 시작…여야, \'노란봉투법\' 충돌 예고\n민주당 “맞벌이 학부모 위한 주 4일제 적극 검토”\n尹대통령, 한총리와 주례회동 취소…"방미 직후 사정 등 고려"\n노동절에 노동자 갈라치는 대통령…“고용세습 뿌리 뽑겠다”\n\'워싱턴 선언\'에 아픈 곳 찔리자…북, 중·러 업고 사흘째 흠집내기\n송영길 또 \'2일 자진출석\' 예고…안희정식 대응 닮은 꼴\n영덕군, 원전 지원금 반환 행정소송 패소에 항소할 듯\n[단독]"김건희 여사 직접 사가"...방미때 돌려신은 \'성수동 수제화\''

# %%
# Q. 한글만 출력하세요 ( 개행없이.)

line = bs.select_one('body > div > main > section > div.main-sub> div> ul > li> strong > a')
print(line.text)
# Out:
# 용혜인 "'초단시간 노동자 권리찾기법' 발의 추진"

# %%
# select_one()
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')

# lines = bs.select('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')
line = bs.select_one('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')

print(line.text)
# Out:
# 김기현 "당에 아픈 손가락 청년 문제…청년정책 컨트롤타워 되길"

# %%
# select()
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')

# lines = bs.select('body > div > main > section > div.main-sub > div > ul > li:nth-child(1) > strong > a')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
body = '\n'.join([line.text for line in lines])
print(body)
# Out:
# 김기현 "당에 아픈 손가락 청년 문제…청년정책 컨트롤타워 되길"
# 방미 효과에 尹지지율 반등 모멘텀…상승세로 이어질까[數싸움]
# 조태용 "'핵공유' 용어 오해 살 수 있어…'핵억제 동맹'이 정확"
# 부동산 투자이민제 유지..금액 상향  조정
# 사라진 ‘전작권 전환’ 논의…냉전기 대미의존형으로 퇴화하는 한미동맹
# 與 “KBS1 라디오 尹방미 보도, 친야 패널이 친여의 7배”
# 노동절에 분신한 건설노동자…노동계 “윤석열이 분신 불렀다”
# 일본 지지통신 "기시다 총리, 7~8일 방한 뜻 굳혀"
# 북한 "태양광 에너지 좋아요"…전력난 풀고자 에너지원 다변화
# [단독]尹 “바이든 부부와 전생에 깊은 인연 있는듯”…블레어하우스 떠나며 남긴 말

# %%
# Q. 한글만 출력하세요( 개행 없이)
texts = re.findall('[가-힣0-9]+',body)
print(' '.join(texts))
# Out:
# 김기현 당에 아픈 손가락 청년 문제 청년정책 컨트롤타워 되길 방미 효과에 지지율 반등 모멘텀 상승세로 이어질까 싸움 조태용 핵공유 용어 오해 살 수 있어 핵억제 동맹 이 정확 부동산 투자이민제 유지 금액 상향 조정 사라진 전작권 전환 논의 냉전기 대미의존형으로 퇴화하는 한미동맹 1 라디오 방미 보도 친야 패널이 친여의 7배 노동절에 분신한 건설노동자 노동계 윤석열이 분신 불렀다 일본 지지통신 기시다 총리 7 8일 방한 뜻 굳혀 북한 태양광 에너지 좋아요 전력난 풀고자 에너지원 다변화 단독 바이든 부부와 전생에 깊은 인연 있는듯 블레어하우스 떠나며 남긴 말

# %% [markdown]
# ## 과제7_0501.
# 네이버 뉴스 데이터 사회분야 데이터를 가져와서 다음을 수행하세요.
#
# - 첫번째 뉴스 제목과 href를 출력
# - 뉴스 전체 제목과 href를 출력(열방향)

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
for line in lines:
    print(line.text)
# Out:
# 김기현 "당에 아픈 손가락 청년 문제…청년정책 컨트롤타워 되길"
# 방미 효과에 尹지지율 반등 모멘텀…상승세로 이어질까[數싸움]
# 조태용 "'핵공유' 용어 오해 살 수 있어…'핵억제 동맹'이 정확"
# 부동산 투자이민제 유지..금액 상향  조정
# 사라진 ‘전작권 전환’ 논의…냉전기 대미의존형으로 퇴화하는 한미동맹
# 與 “KBS1 라디오 尹방미 보도, 친야 패널이 친여의 7배”
# 노동절에 분신한 건설노동자…노동계 “윤석열이 분신 불렀다”
# 일본 지지통신 "기시다 총리, 7~8일 방한 뜻 굳혀"
# 북한 "태양광 에너지 좋아요"…전력난 풀고자 에너지원 다변화
# [단독]尹 “바이든 부부와 전생에 깊은 인연 있는듯”…블레어하우스 떠나며 남긴 말

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102" # 네이버 뉴스 사회면 메인 페이지
req = requests.get(url, headers=headers)   # GET방식으로 서비스 호출
soup = BeautifulSoup(req.content, "html.parser")
# print(soup)

# %%
target = soup.select_one('#main_content > div > div._persist > div:nth-child(1) > div:nth-child(1) > div.cluster_body > ul > li:nth-child(1) > div.cluster_text > a')

print(target.text)
print(target['href'])

# %%
target = soup.select("#main_content > div > div._persist > div > div > div.cluster_body > ul > li > div.cluster_text > a")
for element in target:
    print(element.text)
    print(element['href']

# %%
# Q. https://news.daum.net/politics#1 에서 실시간 뉴스 제목을 가져와서 출력하세요.

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.daum.net/politics#1'
r = rq.get(url)
html = r.text
bs = BeautifulSoup(html,'lxml')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')
for line in lines:
    print(line.text)

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
url = "https://n.news.naver.com/mnews/article/032/0003161880?sid=101" # 네이버 기사 본문 페이지
req = requests.get(url, headers=headers)
soup = BeautifulSoup(req.content, "html.parser")
print(soup)

# %%
# 제목 추출 #title_area > span
target = soup.select_one("#title_area > span")
print(target)
print("-"*100)
target = target.text # tag를 떼고 추출
print(target)

# %% [markdown]
# ## 과제1_0502.
# url = "https://n.news.naver.com/mnews/article/032/0003161880?sid=101" 사이트에서 연예, 날씨, 스포츠, 프레미엄을 찾아서 출력하세요.

# %%
# 본문 추출 : #dic_area
target = soup.select_one("#dic_area")
print(target)
print("-"*100)
target = target.text
print(target)

# %%
# 이미지 주소 추출 : #img1
target = soup.select_one("#img1")
print(target)
print("-"*100)
target = target["data-src"]
print(target)

# %%
# 네이버 환율 가져오기 : #exchangeList > li.on > a.head.usd > div > span.value
from bs4 import BeautifulSoup
import urllib.request as req
# HTML 가져오기
url = "https://finance.naver.com/marketindex/"
res = req.urlopen(url)
# HTML 분석하기
soup = BeautifulSoup(res, "html.parser")
print(soup)

# %%
# 원하는 데이터 추출하기 
price = soup.select_one("#exchangeList > li.on > a.head.usd > div > span.value").string
print("usd/krw =", price)

# %%
import urllib
from bs4 import BeautifulSoup
response = urllib.request.urlopen('https://naver.com')
byte_data = response.read()
html = byte_data.decode('utf-8')
soup = BeautifulSoup(html, 'html.parser')
print(soup.find_all('a',{'class':'link_newsstand'}),'\n')
print(soup.find_all('a',{'class':'btn_sort'}))

# %%
nlists = soup.findAll('a',{'class':{'link_newsstand','btn_sort'}})
for n in nlists:
#     print(n.text)
    print(n.get_text())

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen('https://naver.com')
bs = BeautifulSoup(html,'html.parser')

hlists = bs.findAll({'h1','h2','h3','h4','h5','h6'},limit=5)
for h in hlists:
    print(h, '\n')

# %%
hlists = bs.findAll({'h1','h2','h3','h4','h5','h6'}, text='뉴스스탠드')
print(hlists)
